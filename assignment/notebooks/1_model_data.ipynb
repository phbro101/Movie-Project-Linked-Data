# %% [markdown]
# # TASK: Model the data in RDF
#
#
#
# ## Overview
# In this task, your assignment is to model the 'input_movie_data.csv' data set as Linked Open Data represented in RDF.
# This means, entities and relationships must be represented via IRIs. A good Linked Data best practice is to re-use existing RDF vocabularies for such a process.
#
# ## Task details
# 1. Re-use the schema.org vocabulary (https://schema.org/) to model the data in RDF.
# 2. Use self-defined valid URLs as IRIs to represent all entities, using your first- and last name as domain. For example, the movie “The Godfather” can be represented with http://firstname-lastname.org/resource/the_godfather
# > __HINT__: URLs must be valid, but do not have to resolve!
# 3. Re-using schema.org, find the classes of the corresponding instances and represent the instances with that class (or classes). For example, if we were re-using the DBpedia vocabulary, the movie “The Godfather” would be of type <http://dbpedia.org/ontology/Film> resulting in a triple representation: <br>
# `<http://firstname-lastname.org/resource/the_godfather> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/ontology/Film>`
#
# > Find such RDF classes in the schema.org vocabulary to specify the rdf:type properties for movie and person.
#
# 4. Re-using schema.org, find the appropriate object property specifying that a movie has a director.
# > __Hint__: Some movies have more than one director
# 5. In addition, find appropriate properties to describe
#   - the name of a movie including the English language tag,
#   - the publication year of a movie including the literal data type of year
#   >__HINT__: not xsd:date, see xsd definition for correct data type for year
#   - the name of a person
#   > __HINT__: Watch out for the correct domain and range of properties, as well as subclass relationships
#
# <br><br>
#
# ## Submission 1
#
# Save the data set that you have represented in RDF (in N3) to the output_data folder with the naming __movies_task_1.n3__.

# %% [markdown]
# <br>
#
# ## Your code

# %%
from rdflib import URIRef, Literal, Graph, Namespace
from rdflib.namespace import FOAF, RDF, RDFS, XSD, DC
import urllib
import csv
from datetime import datetime
from SPARQLWrapper import SPARQLWrapper, JSON, N3

# %%
# Defines further Namespaces
EX = Namespace("https://ex1.org/")
DBO = Namespace("http://dbpedia.org/ontology/")
RSC = Namespace("http://philip-broehl.org/resource/")
WD = Namespace("http://www.wikidata.org/entity/")
WDT = Namespace("http://www.wikidata.org/prop/direct/")
SCH = Namespace("https://schema.org/")

# %%
input_file = open("../input_data/input_movie_data.csv")
text = csv.reader(input_file, delimiter = ',')

g = Graph()
g.bind('foaf', FOAF)
g.bind('dbo', DBO)
g.bind("wd", WD)
g.bind("wdt", WDT)
g.bind("rsc", RSC)
g.bind("sch", SCH)
line_count = 0
for line in text:
    # first line does not contain data
    if line_count == 0:
        line_count += 1
    else:
        title = line[1]
        film_resource = title.lower().replace(' ', '_')  # just for valid URI format
        
        year = line[2]
        director = line[3]
        director_list = director.split(', ')  # there can be multiple directors
        
        g.add((URIRef(RSC[film_resource]), RDF.type, SCH.Movie))
        g.add((URIRef(RSC[film_resource]), RDFS.label, Literal(title, lang = 'en')))
        # WDT.P577 would be the property "publication date"
        g.add((URIRef(RSC[film_resource]), SCH.datePublished, Literal(year, datatype = XSD.gYear)))
        
        for director in director_list: 
            director_resource = director.lower().replace(' ', '_')
            g.add((URIRef(RSC[director_resource]), RDF.type, SCH.Person))
            g.add((URIRef(RSC[director_resource]), FOAF.name, Literal(director, lang = 'en')))        
            g.add((URIRef(RSC[film_resource]), SCH.director, URIRef(RSC[director_resource])))
        
print(g.serialize(format = "n3").decode("utf-8"))
g.serialize(destination = '../output_data/movies_task_1.n3', format = 'n3')
# Out:
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix rsc: <http://philip-broehl.org/resource/> .
# @prefix sch: <https://schema.org/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# rsc:12_angry_men a sch:Movie ;
#     rdfs:label "12 Angry Men"@en ;
#     sch:datePublished "1957-01-01"^^xsd:gYear ;
#     sch:director rsc:sidney_lumet .
#
# rsc:12_years_a_slave a sch:Movie ;
#     rdfs:label "12 Years a Slave"@en ;
#     sch:datePublished "2013-01-01"^^xsd:gYear ;
#     sch:director rsc:steve_mcqueen .
#
# rsc:2001:_a_space_odyssey a sch:Movie ;
#     rdfs:label "2001: A Space Odyssey"@en ;
#     sch:datePublished "1968-01-01"^^xsd:gYear ;
#     sch:director rsc:stanley_kubrick .
#
# rsc:a_beautiful_mind a sch:Movie ;
#     rdfs:label "A Beautiful Mind"@en ;
#     sch:datePublished "2001-01-01"^^xsd:gYear ;
#     sch:director rsc:ron_howard .
#
# rsc:a_christmas_story a sch:Movie ;
#     rdfs:label "A Christmas Story"@en ;
#     sch:datePublished "1983-01-01"^^xsd:gYear ;
#     sch:director rsc:bob_clark .
#
# rsc:a_clockwork_orange a sch:Movie ;
#     rdfs:label "A Clockwork Orange"@en ;
#     sch:datePublished "1971-01-01"^^xsd:gYear ;
#     sch:director rsc:stanley_kubrick .
#
# rsc:a_night_at_the_opera a sch:Movie ;
#     rdfs:label "A Night at the Opera"@en ;
#     sch:datePublished "1935-01-01"^^xsd:gYear ;
#     sch:director rsc:edmund_goulding,
#         rsc:sam_wood .
#
# rsc:a_streetcar_named_desire a sch:Movie ;
#     rdfs:label "A Streetcar Named Desire"@en ;
#     sch:datePublished "1951-01-01"^^xsd:gYear ;
#     sch:director rsc:elia_kazan .
#
# rsc:aladdin a sch:Movie ;
#     rdfs:label "Aladdin"@en ;
#     sch:datePublished "1992-01-01"^^xsd:gYear ;
#     sch:director rsc:john_musker,
#         rsc:ron_clements .
#
# rsc:alien a sch:Movie ;
#     rdfs:label "Alien"@en ;
#     sch:datePublished "1979-01-01"^^xsd:gYear ;
#     sch:director rsc:ridley_scott .
#
# rsc:aliens a sch:Movie ;
#     rdfs:label "Aliens"@en ;
#     sch:datePublished "1986-01-01"^^xsd:gYear ;
#     sch:director rsc:james_cameron .
#
# rsc:all_about_eve a sch:Movie ;
#     rdfs:label "All About Eve"@en ;
#     sch:datePublished "1950-01-01"^^xsd:gYear ;
#     sch:director rsc:joseph_l._mankiewicz .
#
# rsc:all_quiet_on_the_western_front a sch:Movie ;
#     rdfs:label "All Quiet on the Western Front"@en ;
#     sch:datePublished "1930-01-01"^^xsd:gYear ;
#     sch:director rsc:lewis_milestone .
#
# rsc:amadeus a sch:Movie ;
#     rdfs:label "Amadeus"@en ;
#     sch:datePublished "1984-01-01"^^xsd:gYear ;
#     sch:director rsc:milos_forman .
#
# rsc:american_beauty a sch:Movie ;
#     rdfs:label "American Beauty"@en ;
#     sch:datePublished "1999-01-01"^^xsd:gYear ;
#     sch:director rsc:sam_mendes .
#
# rsc:american_history_x a sch:Movie ;
#     rdfs:label "American History X"@en ;
#     sch:datePublished "1998-01-01"^^xsd:gYear ;
#     sch:director rsc:tony_kaye .
#
# rsc:anatomy_of_a_murder a sch:Movie ;
#     rdfs:label "Anatomy of a Murder"@en ;
#     sch:datePublished "1959-01-01"^^xsd:gYear ;
#     sch:director rsc:otto_preminger .
#
# rsc:annie_hall a sch:Movie ;
#     rdfs:label "Annie Hall"@en ;
#     sch:datePublished "1977-01-01"^^xsd:gYear ;
#     sch:director rsc:woody_allen .
#
# rsc:apocalypse_now a sch:Movie ;
#     rdfs:label "Apocalypse Now"@en ;
#     sch:datePublished "1979-01-01"^^xsd:gYear ;
#     sch:director rsc:francis_ford_coppola .
#
# rsc:arsenic_and_old_lace a sch:Movie ;
#     rdfs:label "Arsenic and Old Lace"@en ;
#     sch:datePublished "1944-01-01"^^xsd:gYear ;
#     sch:director rsc:frank_capra .
#
# rsc:baby_driver a sch:Movie ;
#     rdfs:label "Baby Driver"@en ;
#     sch:datePublished "2017-01-01"^^xsd:gYear ;
#     sch:director rsc:edgar_wright .
#
# rsc:back_to_the_future a sch:Movie ;
#     rdfs:label "Back to the Future"@en ;
#     sch:datePublished "1985-01-01"^^xsd:gYear ;
#     sch:director rsc:robert_zemeckis .
#
# rsc:barry_lyndon a sch:Movie ;
#     rdfs:label "Barry Lyndon"@en ;
#     sch:datePublished "1975-01-01"^^xsd:gYear ;
#     sch:director rsc:stanley_kubrick .
#
# rsc:batman_begins a sch:Movie ;
#     rdfs:label "Batman Begins"@en ;
#     sch:datePublished "2005-01-01"^^xsd:gYear ;
#     sch:director rsc:christopher_nolan .
#
# rsc:beauty_and_the_beast a sch:Movie ;
#     rdfs:label "Beauty and the Beast"@en ;
#     sch:datePublished "1991-01-01"^^xsd:gYear ;
#     sch:director rsc:gary_trousdale,
#         rsc:kirk_wise .
#
# rsc:before_sunrise a sch:Movie ;
#     rdfs:label "Before Sunrise"@en ;
#     sch:datePublished "1995-01-01"^^xsd:gYear ;
#     sch:director rsc:richard_linklater .
#
# rsc:before_sunset a sch:Movie ;
#     rdfs:label "Before Sunset"@en ;
#     sch:datePublished "2004-01-01"^^xsd:gYear ;
#     sch:director rsc:richard_linklater .
#
# rsc:ben-hur a sch:Movie ;
#     rdfs:label "Ben-Hur"@en ;
#     sch:datePublished "1959-01-01"^^xsd:gYear ;
#     sch:director rsc:william_wyler .
#
# rsc:big_fish a sch:Movie ;
#     rdfs:label "Big Fish"@en ;
#     sch:datePublished "2003-01-01"^^xsd:gYear ;
#     sch:director rsc:tim_burton .
#
# rsc:blade_runner a sch:Movie ;
#     rdfs:label "Blade Runner"@en ;
#     sch:datePublished "1982-01-01"^^xsd:gYear ;
#     sch:director rsc:ridley_scott .
#
# rsc:blood_diamond a sch:Movie ;
#     rdfs:label "Blood Diamond"@en ;
#     sch:datePublished "2006-01-01"^^xsd:gYear ;
#     sch:director rsc:edward_zwick .
#
# rsc:braveheart a sch:Movie ;
#     rdfs:label "Braveheart"@en ;
#     sch:datePublished "1995-01-01"^^xsd:gYear ;
#     sch:director rsc:mel_gibson .
#
# rsc:brief_encounter a sch:Movie ;
#     rdfs:label "Brief Encounter"@en ;
#     sch:datePublished "1945-01-01"^^xsd:gYear ;
#     sch:director rsc:david_lean .
#
# rsc:butch_cassidy_and_the_sundance_kid a sch:Movie ;
#     rdfs:label "Butch Cassidy and the Sundance Kid"@en ;
#     sch:datePublished "1969-01-01"^^xsd:gYear ;
#     sch:director rsc:george_roy_hill .
#
# rsc:casablanca a sch:Movie ;
#     rdfs:label "Casablanca"@en ;
#     sch:datePublished "1942-01-01"^^xsd:gYear ;
#     sch:director rsc:michael_curtiz .
#
# rsc:casino a sch:Movie ;
#     rdfs:label "Casino"@en ;
#     sch:datePublished "1995-01-01"^^xsd:gYear ;
#     sch:director rsc:martin_scorsese .
#
# rsc:cat_on_a_hot_tin_roof a sch:Movie ;
#     rdfs:label "Cat on a Hot Tin Roof"@en ;
#     sch:datePublished "1958-01-01"^^xsd:gYear ;
#     sch:director rsc:richard_brooks .
#
# rsc:catch_me_if_you_can a sch:Movie ;
#     rdfs:label "Catch Me If You Can"@en ;
#     sch:datePublished "2002-01-01"^^xsd:gYear ;
#     sch:director rsc:steven_spielberg .
#
# rsc:chinatown a sch:Movie ;
#     rdfs:label "Chinatown"@en ;
#     sch:datePublished "1974-01-01"^^xsd:gYear ;
#     sch:director rsc:roman_polanski .
#
# rsc:citizen_kane a sch:Movie ;
#     rdfs:label "Citizen Kane"@en ;
#     sch:datePublished "1941-01-01"^^xsd:gYear ;
#     sch:director rsc:orson_welles .
#
# rsc:city_lights a sch:Movie ;
#     rdfs:label "City Lights"@en ;
#     sch:datePublished "1931-01-01"^^xsd:gYear ;
#     sch:director rsc:charles_chaplin .
#
# rsc:cool_hand_luke a sch:Movie ;
#     rdfs:label "Cool Hand Luke"@en ;
#     sch:datePublished "1967-01-01"^^xsd:gYear ;
#     sch:director rsc:stuart_rosenberg .
#
# rsc:dead_poets_society a sch:Movie ;
#     rdfs:label "Dead Poets Society"@en ;
#     sch:datePublished "1989-01-01"^^xsd:gYear ;
#     sch:director rsc:peter_weir .
#
# rsc:deadpool a sch:Movie ;
#     rdfs:label "Deadpool"@en ;
#     sch:datePublished "2016-01-01"^^xsd:gYear ;
#     sch:director rsc:tim_miller .
#
# rsc:dial_m_for_murder a sch:Movie ;
#     rdfs:label "Dial M for Murder"@en ;
#     sch:datePublished "1954-01-01"^^xsd:gYear ;
#     sch:director rsc:alfred_hitchcock .
#
# rsc:die_hard a sch:Movie ;
#     rdfs:label "Die Hard"@en ;
#     sch:datePublished "1988-01-01"^^xsd:gYear ;
#     sch:director rsc:john_mctiernan .
#
# rsc:django_unchained a sch:Movie ;
#     rdfs:label "Django Unchained"@en ;
#     sch:datePublished "2012-01-01"^^xsd:gYear ;
#     sch:director rsc:quentin_tarantino .
#
# rsc:dog_day_afternoon a sch:Movie ;
#     rdfs:label "Dog Day Afternoon"@en ;
#     sch:datePublished "1975-01-01"^^xsd:gYear ;
#     sch:director rsc:sidney_lumet .
#
# rsc:dogville a sch:Movie ;
#     rdfs:label "Dogville"@en ;
#     sch:datePublished "2003-01-01"^^xsd:gYear ;
#     sch:director rsc:lars_von_trier .
#
# rsc:donnie_darko a sch:Movie ;
#     rdfs:label "Donnie Darko"@en ;
#     sch:datePublished "2001-01-01"^^xsd:gYear ;
#     sch:director rsc:richard_kelly .
#
# rsc:double_indemnity a sch:Movie ;
#     rdfs:label "Double Indemnity"@en ;
#     sch:datePublished "1944-01-01"^^xsd:gYear ;
#     sch:director rsc:billy_wilder .
#
# rsc:dr._strangelove_or:_how_i_learned_to_stop_worrying_and_love_the_bomb a sch:Movie ;
#     rdfs:label "Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb"@en ;
#     sch:datePublished "1964-01-01"^^xsd:gYear ;
#     sch:director rsc:stanley_kubrick .
#
# rsc:eternal_sunshine_of_the_spotless_mind a sch:Movie ;
#     rdfs:label "Eternal Sunshine of the Spotless Mind"@en ;
#     sch:datePublished "2004-01-01"^^xsd:gYear ;
#     sch:director rsc:michel_gondry .
#
# rsc:fargo a sch:Movie ;
#     rdfs:label "Fargo"@en ;
#     sch:datePublished "1996-01-01"^^xsd:gYear ;
#     sch:director rsc:ethan_coen,
#         rsc:joel_coen .
#
# rsc:fight_club a sch:Movie ;
#     rdfs:label "Fight Club"@en ;
#     sch:datePublished "1999-01-01"^^xsd:gYear ;
#     sch:director rsc:david_fincher .
#
# rsc:finding_nemo a sch:Movie ;
#     rdfs:label "Finding Nemo"@en ;
#     sch:datePublished "2003-01-01"^^xsd:gYear ;
#     sch:director rsc:andrew_stanton,
#         rsc:lee_unkrich .
#
# rsc:forrest_gump a sch:Movie ;
#     rdfs:label "Forrest Gump"@en ;
#     sch:datePublished "1994-01-01"^^xsd:gYear ;
#     sch:director rsc:robert_zemeckis .
#
# rsc:full_metal_jacket a sch:Movie ;
#     rdfs:label "Full Metal Jacket"@en ;
#     sch:datePublished "1987-01-01"^^xsd:gYear ;
#     sch:director rsc:stanley_kubrick .
#
# rsc:gandhi a sch:Movie ;
#     rdfs:label "Gandhi"@en ;
#     sch:datePublished "1982-01-01"^^xsd:gYear ;
#     sch:director rsc:richard_attenborough .
#
# rsc:gladiator a sch:Movie ;
#     rdfs:label "Gladiator"@en ;
#     sch:datePublished "2000-01-01"^^xsd:gYear ;
#     sch:director rsc:ridley_scott .
#
# rsc:gone_girl a sch:Movie ;
#     rdfs:label "Gone Girl"@en ;
#     sch:datePublished "2014-01-01"^^xsd:gYear ;
#     sch:director rsc:david_fincher .
#
# rsc:gone_with_the_wind a sch:Movie ;
#     rdfs:label "Gone with the Wind"@en ;
#     sch:datePublished "1939-01-01"^^xsd:gYear ;
#     sch:director rsc:george_cukor,
#         rsc:sam_wood,
#         rsc:victor_fleming .
#
# rsc:good_will_hunting a sch:Movie ;
#     rdfs:label "Good Will Hunting"@en ;
#     sch:datePublished "1997-01-01"^^xsd:gYear ;
#     sch:director rsc:gus_van_sant .
#
# rsc:goodfellas a sch:Movie ;
#     rdfs:label "Goodfellas"@en ;
#     sch:datePublished "1990-01-01"^^xsd:gYear ;
#     sch:director rsc:martin_scorsese .
#
# rsc:gran_torino a sch:Movie ;
#     rdfs:label "Gran Torino"@en ;
#     sch:datePublished "2008-01-01"^^xsd:gYear ;
#     sch:director rsc:clint_eastwood .
#
# rsc:groundhog_day a sch:Movie ;
#     rdfs:label "Groundhog Day"@en ;
#     sch:datePublished "1993-01-01"^^xsd:gYear ;
#     sch:director rsc:harold_ramis .
#
# rsc:guardians_of_the_galaxy a sch:Movie ;
#     rdfs:label "Guardians of the Galaxy"@en ;
#     sch:datePublished "2014-01-01"^^xsd:gYear ;
#     sch:director rsc:james_gunn .
#
# rsc:guardians_of_the_galaxy_vol._2 a sch:Movie ;
#     rdfs:label "Guardians of the Galaxy Vol. 2"@en ;
#     sch:datePublished "2017-01-01"^^xsd:gYear ;
#     sch:director rsc:james_gunn .
#
# <http://philip-broehl.org/resource/hachi:_a_dog's_tale> a sch:Movie ;
#     rdfs:label "Hachi: A Dog's Tale"@en ;
#     sch:datePublished "2009-01-01"^^xsd:gYear ;
#     sch:director <http://philip-broehl.org/resource/lasse_hallstrã¶m> .
#
# rsc:hacksaw_ridge a sch:Movie ;
#     rdfs:label "Hacksaw Ridge"@en ;
#     sch:datePublished "2016-01-01"^^xsd:gYear ;
#     sch:director rsc:mel_gibson .
#
# rsc:harry_potter_and_the_deathly_hallows:_part_2 a sch:Movie ;
#     rdfs:label "Harry Potter and the Deathly Hallows: Part 2"@en ;
#     sch:datePublished "2011-01-01"^^xsd:gYear ;
#     sch:director rsc:david_yates .
#
# rsc:harvey a sch:Movie ;
#     rdfs:label "Harvey"@en ;
#     sch:datePublished "1950-01-01"^^xsd:gYear ;
#     sch:director rsc:henry_koster .
#
# rsc:heat a sch:Movie ;
#     rdfs:label "Heat"@en ;
#     sch:datePublished "1995-01-01"^^xsd:gYear ;
#     sch:director rsc:michael_mann .
#
# rsc:high_noon a sch:Movie ;
#     rdfs:label "High Noon"@en ;
#     sch:datePublished "1952-01-01"^^xsd:gYear ;
#     sch:director rsc:fred_zinnemann .
#
# rsc:his_girl_friday a sch:Movie ;
#     rdfs:label "His Girl Friday"@en ;
#     sch:datePublished "1940-01-01"^^xsd:gYear ;
#     sch:director rsc:howard_hawks .
#
# rsc:hotel_rwanda a sch:Movie ;
#     rdfs:label "Hotel Rwanda"@en ;
#     sch:datePublished "2004-01-01"^^xsd:gYear ;
#     sch:director rsc:terry_george .
#
# rsc:how_to_train_your_dragon a sch:Movie ;
#     rdfs:label "How to Train Your Dragon"@en ;
#     sch:datePublished "2010-01-01"^^xsd:gYear ;
#     sch:director rsc:chris_sanders,
#         rsc:dean_deblois .
#
# rsc:in_the_name_of_the_father a sch:Movie ;
#     rdfs:label "In the Name of the Father"@en ;
#     sch:datePublished "1993-01-01"^^xsd:gYear ;
#     sch:director rsc:jim_sheridan .
#
# rsc:inception a sch:Movie ;
#     rdfs:label "Inception"@en ;
#     sch:datePublished "2010-01-01"^^xsd:gYear ;
#     sch:director rsc:christopher_nolan .
#
# rsc:indiana_jones_and_the_last_crusade a sch:Movie ;
#     rdfs:label "Indiana Jones and the Last Crusade"@en ;
#     sch:datePublished "1989-01-01"^^xsd:gYear ;
#     sch:director rsc:steven_spielberg .
#
# rsc:inglourious_basterds a sch:Movie ;
#     rdfs:label "Inglourious Basterds"@en ;
#     sch:datePublished "2009-01-01"^^xsd:gYear ;
#     sch:director rsc:eli_roth,
#         rsc:quentin_tarantino .
#
# rsc:inside_out a sch:Movie ;
#     rdfs:label "Inside Out"@en ;
#     sch:datePublished "2015-01-01"^^xsd:gYear ;
#     sch:director rsc:pete_docter,
#         rsc:ronnie_del_carmen .
#
# rsc:interstellar a sch:Movie ;
#     rdfs:label "Interstellar"@en ;
#     sch:datePublished "2014-01-01"^^xsd:gYear ;
#     sch:director rsc:christopher_nolan .
#
# rsc:into_the_wild a sch:Movie ;
#     rdfs:label "Into the Wild"@en ;
#     sch:datePublished "2007-01-01"^^xsd:gYear ;
#     sch:director rsc:sean_penn .
#
# <http://philip-broehl.org/resource/it's_a_wonderful_life> a sch:Movie ;
#     rdfs:label "It's a Wonderful Life"@en ;
#     sch:datePublished "1946-01-01"^^xsd:gYear ;
#     sch:director rsc:frank_capra .
#
# rsc:it_happened_one_night a sch:Movie ;
#     rdfs:label "It Happened One Night"@en ;
#     sch:datePublished "1934-01-01"^^xsd:gYear ;
#     sch:director rsc:frank_capra .
#
# rsc:jaws a sch:Movie ;
#     rdfs:label "Jaws"@en ;
#     sch:datePublished "1975-01-01"^^xsd:gYear ;
#     sch:director rsc:steven_spielberg .
#
# rsc:jfk a sch:Movie ;
#     rdfs:label "JFK"@en ;
#     sch:datePublished "1991-01-01"^^xsd:gYear ;
#     sch:director rsc:oliver_stone .
#
# rsc:judgment_at_nuremberg a sch:Movie ;
#     rdfs:label "Judgment at Nuremberg"@en ;
#     sch:datePublished "1961-01-01"^^xsd:gYear ;
#     sch:director rsc:stanley_kramer .
#
# rsc:jurassic_park a sch:Movie ;
#     rdfs:label "Jurassic Park"@en ;
#     sch:datePublished "1993-01-01"^^xsd:gYear ;
#     sch:director rsc:steven_spielberg .
#
# rsc:kill_bill:_vol._1 a sch:Movie ;
#     rdfs:label "Kill Bill: Vol. 1"@en ;
#     sch:datePublished "2003-01-01"^^xsd:gYear ;
#     sch:director rsc:quentin_tarantino .
#
# rsc:kind_hearts_and_coronets a sch:Movie ;
#     rdfs:label "Kind Hearts and Coronets"@en ;
#     sch:datePublished "1949-01-01"^^xsd:gYear ;
#     sch:director rsc:robert_hamer .
#
# rsc:l.a._confidential a sch:Movie ;
#     rdfs:label "L.A. Confidential"@en ;
#     sch:datePublished "1997-01-01"^^xsd:gYear ;
#     sch:director rsc:curtis_hanson .
#
# rsc:la_la_land a sch:Movie ;
#     rdfs:label "La La Land"@en ;
#     sch:datePublished "2016-01-01"^^xsd:gYear ;
#     sch:director rsc:damien_chazelle .
#
# rsc:laura a sch:Movie ;
#     rdfs:label "Laura"@en ;
#     sch:datePublished "1944-01-01"^^xsd:gYear ;
#     sch:director rsc:otto_preminger .
#
# rsc:lawrence_of_arabia a sch:Movie ;
#     rdfs:label "Lawrence of Arabia"@en ;
#     sch:datePublished "1962-01-01"^^xsd:gYear ;
#     sch:director rsc:david_lean .
#
# rsc:life_of_brian a sch:Movie ;
#     rdfs:label "Life of Brian"@en ;
#     sch:datePublished "1979-01-01"^^xsd:gYear ;
#     sch:director rsc:terry_jones .
#
# rsc:lion a sch:Movie ;
#     rdfs:label "Lion"@en ;
#     sch:datePublished "2016-01-01"^^xsd:gYear ;
#     sch:director rsc:garth_davis .
#
# <http://philip-broehl.org/resource/lock,_stock_and_two_smoking_barrels> a sch:Movie ;
#     rdfs:label "Lock, Stock and Two Smoking Barrels"@en ;
#     sch:datePublished "1998-01-01"^^xsd:gYear ;
#     sch:director rsc:guy_ritchie .
#
# rsc:logan a sch:Movie ;
#     rdfs:label "Logan"@en ;
#     sch:datePublished "2017-01-01"^^xsd:gYear ;
#     sch:director rsc:james_mangold .
#
# <http://philip-broehl.org/resource/lã©on:_the_professional> a sch:Movie ;
#     rdfs:label "LÃ©on: The Professional"@en ;
#     sch:datePublished "1994-01-01"^^xsd:gYear ;
#     sch:director rsc:luc_besson .
#
# rsc:mad_max:_fury_road a sch:Movie ;
#     rdfs:label "Mad Max: Fury Road"@en ;
#     sch:datePublished "2015-01-01"^^xsd:gYear ;
#     sch:director rsc:george_miller .
#
# rsc:magnolia a sch:Movie ;
#     rdfs:label "Magnolia"@en ;
#     sch:datePublished "1999-01-01"^^xsd:gYear ;
#     sch:director rsc:paul_thomas_anderson .
#
# rsc:mary_and_max a sch:Movie ;
#     rdfs:label "Mary and Max"@en ;
#     sch:datePublished "2009-01-01"^^xsd:gYear ;
#     sch:director rsc:adam_elliot .
#
# rsc:memento a sch:Movie ;
#     rdfs:label "Memento"@en ;
#     sch:datePublished "2000-01-01"^^xsd:gYear ;
#     sch:director rsc:christopher_nolan .
#
# rsc:million_dollar_baby a sch:Movie ;
#     rdfs:label "Million Dollar Baby"@en ;
#     sch:datePublished "2004-01-01"^^xsd:gYear ;
#     sch:director rsc:clint_eastwood .
#
# rsc:modern_times a sch:Movie ;
#     rdfs:label "Modern Times"@en ;
#     sch:datePublished "1936-01-01"^^xsd:gYear ;
#     sch:director rsc:charles_chaplin .
#
# <http://philip-broehl.org/resource/monsters,_inc.> a sch:Movie ;
#     rdfs:label "Monsters, Inc."@en ;
#     sch:datePublished "2001-01-01"^^xsd:gYear ;
#     sch:director rsc:david_silverman,
#         rsc:lee_unkrich,
#         rsc:pete_docter .
#
# rsc:monty_python_and_the_holy_grail a sch:Movie ;
#     rdfs:label "Monty Python and the Holy Grail"@en ;
#     sch:datePublished "1975-01-01"^^xsd:gYear ;
#     sch:director rsc:terry_gilliam,
#         rsc:terry_jones .
#
# rsc:mr._smith_goes_to_washington a sch:Movie ;
#     rdfs:label "Mr. Smith Goes to Washington"@en ;
#     sch:datePublished "1939-01-01"^^xsd:gYear ;
#     sch:director rsc:frank_capra .
#
# rsc:network a sch:Movie ;
#     rdfs:label "Network"@en ;
#     sch:datePublished "1976-01-01"^^xsd:gYear ;
#     sch:director rsc:sidney_lumet .
#
# rsc:no_country_for_old_men a sch:Movie ;
#     rdfs:label "No Country for Old Men"@en ;
#     sch:datePublished "2007-01-01"^^xsd:gYear ;
#     sch:director rsc:ethan_coen,
#         rsc:joel_coen .
#
# rsc:north_by_northwest a sch:Movie ;
#     rdfs:label "North by Northwest"@en ;
#     sch:datePublished "1959-01-01"^^xsd:gYear ;
#     sch:director rsc:alfred_hitchcock .
#
# rsc:notorious a sch:Movie ;
#     rdfs:label "Notorious"@en ;
#     sch:datePublished "1946-01-01"^^xsd:gYear ;
#     sch:director rsc:alfred_hitchcock .
#
# rsc:on_the_waterfront a sch:Movie ;
#     rdfs:label "On the Waterfront"@en ;
#     sch:datePublished "1954-01-01"^^xsd:gYear ;
#     sch:director rsc:elia_kazan .
#
# rsc:once_upon_a_time_in_america a sch:Movie ;
#     rdfs:label "Once Upon a Time in America"@en ;
#     sch:datePublished "1984-01-01"^^xsd:gYear ;
#     sch:director rsc:sergio_leone .
#
# <http://philip-broehl.org/resource/one_flew_over_the_cuckoo's_nest> a sch:Movie ;
#     rdfs:label "One Flew Over the Cuckoo's Nest"@en ;
#     sch:datePublished "1975-01-01"^^xsd:gYear ;
#     sch:director rsc:milos_forman .
#
# rsc:out_of_the_past a sch:Movie ;
#     rdfs:label "Out of the Past"@en ;
#     sch:datePublished "1947-01-01"^^xsd:gYear ;
#     sch:director rsc:jacques_tourneur .
#
# rsc:papillon a sch:Movie ;
#     rdfs:label "Papillon"@en ;
#     sch:datePublished "1973-01-01"^^xsd:gYear ;
#     sch:director rsc:franklin_j._schaffner .
#
# <http://philip-broehl.org/resource/paris,_texas> a sch:Movie ;
#     rdfs:label "Paris, Texas"@en ;
#     sch:datePublished "1984-01-01"^^xsd:gYear ;
#     sch:director rsc:wim_wenders .
#
# rsc:paths_of_glory a sch:Movie ;
#     rdfs:label "Paths of Glory"@en ;
#     sch:datePublished "1957-01-01"^^xsd:gYear ;
#     sch:director rsc:stanley_kubrick .
#
# rsc:patton a sch:Movie ;
#     rdfs:label "Patton"@en ;
#     sch:datePublished "1970-01-01"^^xsd:gYear ;
#     sch:director rsc:franklin_j._schaffner .
#
# rsc:pink_floyd:_the_wall a sch:Movie ;
#     rdfs:label "Pink Floyd: The Wall"@en ;
#     sch:datePublished "1982-01-01"^^xsd:gYear ;
#     sch:director rsc:alan_parker .
#
# rsc:pirates_of_the_caribbean:_the_curse_of_the_black_pearl a sch:Movie ;
#     rdfs:label "Pirates of the Caribbean: The Curse of the Black Pearl"@en ;
#     sch:datePublished "2003-01-01"^^xsd:gYear ;
#     sch:director rsc:gore_verbinski .
#
# rsc:platoon a sch:Movie ;
#     rdfs:label "Platoon"@en ;
#     sch:datePublished "1986-01-01"^^xsd:gYear ;
#     sch:director rsc:oliver_stone .
#
# rsc:prisoners a sch:Movie ;
#     rdfs:label "Prisoners"@en ;
#     sch:datePublished "2013-01-01"^^xsd:gYear ;
#     sch:director rsc:denis_villeneuve .
#
# rsc:psycho a sch:Movie ;
#     rdfs:label "Psycho"@en ;
#     sch:datePublished "1960-01-01"^^xsd:gYear ;
#     sch:director rsc:alfred_hitchcock .
#
# rsc:pulp_fiction a sch:Movie ;
#     rdfs:label "Pulp Fiction"@en ;
#     sch:datePublished "1994-01-01"^^xsd:gYear ;
#     sch:director rsc:quentin_tarantino .
#
# rsc:raging_bull a sch:Movie ;
#     rdfs:label "Raging Bull"@en ;
#     sch:datePublished "1980-01-01"^^xsd:gYear ;
#     sch:director rsc:martin_scorsese .
#
# rsc:raiders_of_the_lost_ark a sch:Movie ;
#     rdfs:label "Raiders of the Lost Ark"@en ;
#     sch:datePublished "1981-01-01"^^xsd:gYear ;
#     sch:director rsc:steven_spielberg .
#
# rsc:rain_man a sch:Movie ;
#     rdfs:label "Rain Man"@en ;
#     sch:datePublished "1988-01-01"^^xsd:gYear ;
#     sch:director rsc:barry_levinson .
#
# rsc:rear_window a sch:Movie ;
#     rdfs:label "Rear Window"@en ;
#     sch:datePublished "1954-01-01"^^xsd:gYear ;
#     sch:director rsc:alfred_hitchcock .
#
# rsc:rebecca a sch:Movie ;
#     rdfs:label "Rebecca"@en ;
#     sch:datePublished "1940-01-01"^^xsd:gYear ;
#     sch:director rsc:alfred_hitchcock .
#
# rsc:requiem_for_a_dream a sch:Movie ;
#     rdfs:label "Requiem for a Dream"@en ;
#     sch:datePublished "2000-01-01"^^xsd:gYear ;
#     sch:director rsc:darren_aronofsky .
#
# rsc:reservoir_dogs a sch:Movie ;
#     rdfs:label "Reservoir Dogs"@en ;
#     sch:datePublished "1992-01-01"^^xsd:gYear ;
#     sch:director rsc:quentin_tarantino .
#
# rsc:rio_bravo a sch:Movie ;
#     rdfs:label "Rio Bravo"@en ;
#     sch:datePublished "1959-01-01"^^xsd:gYear ;
#     sch:director rsc:howard_hawks .
#
# rsc:rocky a sch:Movie ;
#     rdfs:label "Rocky"@en ;
#     sch:datePublished "1976-01-01"^^xsd:gYear ;
#     sch:director rsc:john_g._avildsen .
#
# rsc:roman_holiday a sch:Movie ;
#     rdfs:label "Roman Holiday"@en ;
#     sch:datePublished "1953-01-01"^^xsd:gYear ;
#     sch:director rsc:william_wyler .
#
# rsc:room a sch:Movie ;
#     rdfs:label "Room"@en ;
#     sch:datePublished "2015-01-01"^^xsd:gYear ;
#     sch:director rsc:lenny_abrahamson .
#
# rsc:rope a sch:Movie ;
#     rdfs:label "Rope"@en ;
#     sch:datePublished "1948-01-01"^^xsd:gYear ;
#     sch:director rsc:alfred_hitchcock .
#
# rsc:rush a sch:Movie ;
#     rdfs:label "Rush"@en ;
#     sch:datePublished "2013-01-01"^^xsd:gYear ;
#     sch:director rsc:ron_howard .
#
# rsc:saving_private_ryan a sch:Movie ;
#     rdfs:label "Saving Private Ryan"@en ;
#     sch:datePublished "1998-01-01"^^xsd:gYear ;
#     sch:director rsc:steven_spielberg .
#
# rsc:scarface a sch:Movie ;
#     rdfs:label "Scarface"@en ;
#     sch:datePublished "1983-01-01"^^xsd:gYear ;
#     sch:director rsc:brian_de_palma .
#
# <http://philip-broehl.org/resource/schindler's_list> a sch:Movie ;
#     rdfs:label "Schindler's List"@en ;
#     sch:datePublished "1993-01-01"^^xsd:gYear ;
#     sch:director rsc:steven_spielberg .
#
# rsc:se7en a sch:Movie ;
#     rdfs:label "Se7en"@en ;
#     sch:datePublished "1995-01-01"^^xsd:gYear ;
#     sch:director rsc:david_fincher .
#
# rsc:short_term_12 a sch:Movie ;
#     rdfs:label "Short Term 12"@en ;
#     sch:datePublished "2013-01-01"^^xsd:gYear ;
#     sch:director rsc:destin_daniel_cretton .
#
# rsc:shutter_island a sch:Movie ;
#     rdfs:label "Shutter Island"@en ;
#     sch:datePublished "2010-01-01"^^xsd:gYear ;
#     sch:director rsc:martin_scorsese .
#
# rsc:sin_city a sch:Movie ;
#     rdfs:label "Sin City"@en ;
#     sch:datePublished "2005-01-01"^^xsd:gYear ;
#     sch:director rsc:frank_miller,
#         rsc:quentin_tarantino,
#         rsc:robert_rodriguez .
#
# <http://philip-broehl.org/resource/singin'_in_the_rain> a sch:Movie ;
#     rdfs:label "Singin' in the Rain"@en ;
#     sch:datePublished "1952-01-01"^^xsd:gYear ;
#     sch:director rsc:gene_kelly,
#         rsc:stanley_donen .
#
# rsc:sleuth a sch:Movie ;
#     rdfs:label "Sleuth"@en ;
#     sch:datePublished "1972-01-01"^^xsd:gYear ;
#     sch:director rsc:joseph_l._mankiewicz .
#
# rsc:sling_blade a sch:Movie ;
#     rdfs:label "Sling Blade"@en ;
#     sch:datePublished "1996-01-01"^^xsd:gYear ;
#     sch:director rsc:billy_bob_thornton .
#
# rsc:slumdog_millionaire a sch:Movie ;
#     rdfs:label "Slumdog Millionaire"@en ;
#     sch:datePublished "2008-01-01"^^xsd:gYear ;
#     sch:director rsc:danny_boyle,
#         rsc:loveleen_tandan .
#
# rsc:snatch a sch:Movie ;
#     rdfs:label "Snatch"@en ;
#     sch:datePublished "2000-01-01"^^xsd:gYear ;
#     sch:director rsc:guy_ritchie .
#
# rsc:some_like_it_hot a sch:Movie ;
#     rdfs:label "Some Like It Hot"@en ;
#     sch:datePublished "1959-01-01"^^xsd:gYear ;
#     sch:director rsc:billy_wilder .
#
# rsc:song_of_the_sea a sch:Movie ;
#     rdfs:label "Song of the Sea"@en ;
#     sch:datePublished "2014-01-01"^^xsd:gYear ;
#     sch:director rsc:tomm_moore .
#
# rsc:spider-man:_homecoming a sch:Movie ;
#     rdfs:label "Spider-Man: Homecoming"@en ;
#     sch:datePublished "2017-01-01"^^xsd:gYear ;
#     sch:director rsc:jon_watts .
#
# rsc:spotlight a sch:Movie ;
#     rdfs:label "Spotlight"@en ;
#     sch:datePublished "2015-01-01"^^xsd:gYear ;
#     sch:director rsc:tom_mccarthy .
#
# rsc:stalag_17 a sch:Movie ;
#     rdfs:label "Stalag 17"@en ;
#     sch:datePublished "1953-01-01"^^xsd:gYear ;
#     sch:director rsc:billy_wilder .
#
# rsc:stand_by_me a sch:Movie ;
#     rdfs:label "Stand by Me"@en ;
#     sch:datePublished "1986-01-01"^^xsd:gYear ;
#     sch:director rsc:rob_reiner .
#
# rsc:star_wars:_episode_iv_-_a_new_hope a sch:Movie ;
#     rdfs:label "Star Wars: Episode IV - A New Hope"@en ;
#     sch:datePublished "1977-01-01"^^xsd:gYear ;
#     sch:director rsc:george_lucas .
#
# rsc:star_wars:_episode_v_-_the_empire_strikes_back a sch:Movie ;
#     rdfs:label "Star Wars: Episode V - The Empire Strikes Back"@en ;
#     sch:datePublished "1980-01-01"^^xsd:gYear ;
#     sch:director rsc:irvin_kershner .
#
# rsc:star_wars:_episode_vi_-_return_of_the_jedi a sch:Movie ;
#     rdfs:label "Star Wars: Episode VI - Return of the Jedi"@en ;
#     sch:datePublished "1983-01-01"^^xsd:gYear ;
#     sch:director rsc:richard_marquand .
#
# rsc:star_wars:_the_force_awakens a sch:Movie ;
#     rdfs:label "Star Wars: The Force Awakens"@en ;
#     sch:datePublished "2015-01-01"^^xsd:gYear ;
#     sch:director rsc:j.j._abrams .
#
# rsc:strangers_on_a_train a sch:Movie ;
#     rdfs:label "Strangers on a Train"@en ;
#     sch:datePublished "1951-01-01"^^xsd:gYear ;
#     sch:director rsc:alfred_hitchcock .
#
# rsc:sunset_boulevard a sch:Movie ;
#     rdfs:label "Sunset Boulevard"@en ;
#     sch:datePublished "1950-01-01"^^xsd:gYear ;
#     sch:director rsc:billy_wilder .
#
# rsc:taxi_driver a sch:Movie ;
#     rdfs:label "Taxi Driver"@en ;
#     sch:datePublished "1976-01-01"^^xsd:gYear ;
#     sch:director rsc:martin_scorsese .
#
# rsc:terminator_2:_judgment_day a sch:Movie ;
#     rdfs:label "Terminator 2: Judgment Day"@en ;
#     sch:datePublished "1991-01-01"^^xsd:gYear ;
#     sch:director rsc:james_cameron .
#
# rsc:the_apartment a sch:Movie ;
#     rdfs:label "The Apartment"@en ;
#     sch:datePublished "1960-01-01"^^xsd:gYear ;
#     sch:director rsc:billy_wilder .
#
# rsc:the_avengers a sch:Movie ;
#     rdfs:label "The Avengers"@en ;
#     sch:datePublished "2012-01-01"^^xsd:gYear ;
#     sch:director rsc:joss_whedon .
#
# rsc:the_best_years_of_our_lives a sch:Movie ;
#     rdfs:label "The Best Years of Our Lives"@en ;
#     sch:datePublished "1946-01-01"^^xsd:gYear ;
#     sch:director rsc:william_wyler .
#
# rsc:the_big_lebowski a sch:Movie ;
#     rdfs:label "The Big Lebowski"@en ;
#     sch:datePublished "1998-01-01"^^xsd:gYear ;
#     sch:director rsc:ethan_coen,
#         rsc:joel_coen .
#
# rsc:the_big_sleep a sch:Movie ;
#     rdfs:label "The Big Sleep"@en ;
#     sch:datePublished "1946-01-01"^^xsd:gYear ;
#     sch:director rsc:howard_hawks .
#
# rsc:the_bourne_ultimatum a sch:Movie ;
#     rdfs:label "The Bourne Ultimatum"@en ;
#     sch:datePublished "2007-01-01"^^xsd:gYear ;
#     sch:director rsc:paul_greengrass .
#
# rsc:the_bridge_on_the_river_kwai a sch:Movie ;
#     rdfs:label "The Bridge on the River Kwai"@en ;
#     sch:datePublished "1957-01-01"^^xsd:gYear ;
#     sch:director rsc:david_lean .
#
# rsc:the_dark_knight a sch:Movie ;
#     rdfs:label "The Dark Knight"@en ;
#     sch:datePublished "2008-01-01"^^xsd:gYear ;
#     sch:director rsc:christopher_nolan .
#
# rsc:the_dark_knight_rises a sch:Movie ;
#     rdfs:label "The Dark Knight Rises"@en ;
#     sch:datePublished "2012-01-01"^^xsd:gYear ;
#     sch:director rsc:christopher_nolan .
#
# rsc:the_deer_hunter a sch:Movie ;
#     rdfs:label "The Deer Hunter"@en ;
#     sch:datePublished "1978-01-01"^^xsd:gYear ;
#     sch:director rsc:michael_cimino .
#
# rsc:the_departed a sch:Movie ;
#     rdfs:label "The Departed"@en ;
#     sch:datePublished "2006-01-01"^^xsd:gYear ;
#     sch:director rsc:martin_scorsese .
#
# rsc:the_elephant_man a sch:Movie ;
#     rdfs:label "The Elephant Man"@en ;
#     sch:datePublished "1980-01-01"^^xsd:gYear ;
#     sch:director rsc:david_lynch .
#
# rsc:the_exorcist a sch:Movie ;
#     rdfs:label "The Exorcist"@en ;
#     sch:datePublished "1973-01-01"^^xsd:gYear ;
#     sch:director rsc:william_friedkin .
#
# rsc:the_general a sch:Movie ;
#     rdfs:label "The General"@en ;
#     sch:datePublished "1926-01-01"^^xsd:gYear ;
#     sch:director rsc:buster_keaton,
#         rsc:clyde_bruckman .
#
# rsc:the_godfather a sch:Movie ;
#     rdfs:label "The Godfather"@en ;
#     sch:datePublished "1972-01-01"^^xsd:gYear ;
#     sch:director rsc:francis_ford_coppola .
#
# rsc:the_godfather:_part_ii a sch:Movie ;
#     rdfs:label "The Godfather: Part II"@en ;
#     sch:datePublished "1974-01-01"^^xsd:gYear ;
#     sch:director rsc:francis_ford_coppola .
#
# rsc:the_gold_rush a sch:Movie ;
#     rdfs:label "The Gold Rush"@en ;
#     sch:datePublished "1925-01-01"^^xsd:gYear ;
#     sch:director rsc:charles_chaplin .
#
# rsc:the_graduate a sch:Movie ;
#     rdfs:label "The Graduate"@en ;
#     sch:datePublished "1967-01-01"^^xsd:gYear ;
#     sch:director rsc:mike_nichols .
#
# rsc:the_grand_budapest_hotel a sch:Movie ;
#     rdfs:label "The Grand Budapest Hotel"@en ;
#     sch:datePublished "2014-01-01"^^xsd:gYear ;
#     sch:director rsc:wes_anderson .
#
# rsc:the_grapes_of_wrath a sch:Movie ;
#     rdfs:label "The Grapes of Wrath"@en ;
#     sch:datePublished "1940-01-01"^^xsd:gYear ;
#     sch:director rsc:john_ford .
#
# rsc:the_great_dictator a sch:Movie ;
#     rdfs:label "The Great Dictator"@en ;
#     sch:datePublished "1940-01-01"^^xsd:gYear ;
#     sch:director rsc:charles_chaplin .
#
# rsc:the_great_escape a sch:Movie ;
#     rdfs:label "The Great Escape"@en ;
#     sch:datePublished "1963-01-01"^^xsd:gYear ;
#     sch:director rsc:john_sturges .
#
# rsc:the_green_mile a sch:Movie ;
#     rdfs:label "The Green Mile"@en ;
#     sch:datePublished "1999-01-01"^^xsd:gYear ;
#     sch:director rsc:frank_darabont .
#
# rsc:the_help a sch:Movie ;
#     rdfs:label "The Help"@en ;
#     sch:datePublished "2011-01-01"^^xsd:gYear ;
#     sch:director rsc:tate_taylor .
#
# rsc:the_hustler a sch:Movie ;
#     rdfs:label "The Hustler"@en ;
#     sch:datePublished "1961-01-01"^^xsd:gYear ;
#     sch:director rsc:robert_rossen .
#
# rsc:the_imitation_game a sch:Movie ;
#     rdfs:label "The Imitation Game"@en ;
#     sch:datePublished "2014-01-01"^^xsd:gYear ;
#     sch:director rsc:morten_tyldum .
#
# rsc:the_kid a sch:Movie ;
#     rdfs:label "The Kid"@en ;
#     sch:datePublished "1921-01-01"^^xsd:gYear ;
#     sch:director rsc:charles_chaplin .
#
# rsc:the_killing a sch:Movie ;
#     rdfs:label "The Killing"@en ;
#     sch:datePublished "1956-01-01"^^xsd:gYear ;
#     sch:director rsc:stanley_kubrick .
#
# <http://philip-broehl.org/resource/the_king's_speech> a sch:Movie ;
#     rdfs:label "The King's Speech"@en ;
#     sch:datePublished "2010-01-01"^^xsd:gYear ;
#     sch:director rsc:tom_hooper .
#
# rsc:the_last_picture_show a sch:Movie ;
#     rdfs:label "The Last Picture Show"@en ;
#     sch:datePublished "1971-01-01"^^xsd:gYear ;
#     sch:director rsc:peter_bogdanovich .
#
# rsc:the_legend_of_1900 a sch:Movie ;
#     rdfs:label "The Legend of 1900"@en ;
#     sch:datePublished "1998-01-01"^^xsd:gYear ;
#     sch:director rsc:giuseppe_tornatore .
#
# rsc:the_lion_king a sch:Movie ;
#     rdfs:label "The Lion King"@en ;
#     sch:datePublished "1994-01-01"^^xsd:gYear ;
#     sch:director rsc:rob_minkoff,
#         rsc:roger_allers .
#
# rsc:the_lord_of_the_rings:_the_fellowship_of_the_ring a sch:Movie ;
#     rdfs:label "The Lord of the Rings: The Fellowship of the Ring"@en ;
#     sch:datePublished "2001-01-01"^^xsd:gYear ;
#     sch:director rsc:peter_jackson .
#
# rsc:the_lord_of_the_rings:_the_return_of_the_king a sch:Movie ;
#     rdfs:label "The Lord of the Rings: The Return of the King"@en ;
#     sch:datePublished "2003-01-01"^^xsd:gYear ;
#     sch:director rsc:peter_jackson .
#
# rsc:the_lord_of_the_rings:_the_two_towers a sch:Movie ;
#     rdfs:label "The Lord of the Rings: The Two Towers"@en ;
#     sch:datePublished "2002-01-01"^^xsd:gYear ;
#     sch:director rsc:peter_jackson .
#
# rsc:the_lost_weekend a sch:Movie ;
#     rdfs:label "The Lost Weekend"@en ;
#     sch:datePublished "1945-01-01"^^xsd:gYear ;
#     sch:director rsc:billy_wilder .
#
# rsc:the_maltese_falcon a sch:Movie ;
#     rdfs:label "The Maltese Falcon"@en ;
#     sch:datePublished "1941-01-01"^^xsd:gYear ;
#     sch:director rsc:john_huston .
#
# rsc:the_man_who_shot_liberty_valance a sch:Movie ;
#     rdfs:label "The Man Who Shot Liberty Valance"@en ;
#     sch:datePublished "1962-01-01"^^xsd:gYear ;
#     sch:director rsc:john_ford .
#
# rsc:the_manchurian_candidate a sch:Movie ;
#     rdfs:label "The Manchurian Candidate"@en ;
#     sch:datePublished "1962-01-01"^^xsd:gYear ;
#     sch:director rsc:john_frankenheimer .
#
# rsc:the_martian a sch:Movie ;
#     rdfs:label "The Martian"@en ;
#     sch:datePublished "2015-01-01"^^xsd:gYear ;
#     sch:director rsc:ridley_scott .
#
# rsc:the_matrix a sch:Movie ;
#     rdfs:label "The Matrix"@en ;
#     sch:datePublished "1999-01-01"^^xsd:gYear ;
#     sch:director rsc:lana_wachowski,
#         rsc:lilly_wachowski .
#
# rsc:the_message a sch:Movie ;
#     rdfs:label "The Message"@en ;
#     sch:datePublished "1976-01-01"^^xsd:gYear ;
#     sch:director rsc:moustapha_akkad .
#
# rsc:the_night_of_the_hunter a sch:Movie ;
#     rdfs:label "The Night of the Hunter"@en ;
#     sch:datePublished "1955-01-01"^^xsd:gYear ;
#     sch:director rsc:charles_laughton .
#
# rsc:the_nightmare_before_christmas a sch:Movie ;
#     rdfs:label "The Nightmare Before Christmas"@en ;
#     sch:datePublished "1993-01-01"^^xsd:gYear ;
#     sch:director rsc:henry_selick .
#
# rsc:the_philadelphia_story a sch:Movie ;
#     rdfs:label "The Philadelphia Story"@en ;
#     sch:datePublished "1940-01-01"^^xsd:gYear ;
#     sch:director rsc:george_cukor .
#
# rsc:the_pianist a sch:Movie ;
#     rdfs:label "The Pianist"@en ;
#     sch:datePublished "2002-01-01"^^xsd:gYear ;
#     sch:director rsc:roman_polanski .
#
# rsc:the_prestige a sch:Movie ;
#     rdfs:label "The Prestige"@en ;
#     sch:datePublished "2006-01-01"^^xsd:gYear ;
#     sch:director rsc:christopher_nolan .
#
# rsc:the_princess_bride a sch:Movie ;
#     rdfs:label "The Princess Bride"@en ;
#     sch:datePublished "1987-01-01"^^xsd:gYear ;
#     sch:director rsc:rob_reiner .
#
# rsc:the_revenant a sch:Movie ;
#     rdfs:label "The Revenant"@en ;
#     sch:datePublished "2015-01-01"^^xsd:gYear ;
#     sch:director <http://philip-broehl.org/resource/alejandro_gonzã¡lez_iã±ã¡rritu> .
#
# rsc:the_shawshank_redemption a sch:Movie ;
#     rdfs:label "The Shawshank Redemption"@en ;
#     sch:datePublished "1994-01-01"^^xsd:gYear ;
#     sch:director rsc:frank_darabont .
#
# rsc:the_shining a sch:Movie ;
#     rdfs:label "The Shining"@en ;
#     sch:datePublished "1980-01-01"^^xsd:gYear ;
#     sch:director rsc:stanley_kubrick .
#
# rsc:the_silence_of_the_lambs a sch:Movie ;
#     rdfs:label "The Silence of the Lambs"@en ;
#     sch:datePublished "1991-01-01"^^xsd:gYear ;
#     sch:director rsc:jonathan_demme .
#
# rsc:the_sixth_sense a sch:Movie ;
#     rdfs:label "The Sixth Sense"@en ;
#     sch:datePublished "1999-01-01"^^xsd:gYear ;
#     sch:director rsc:m._night_shyamalan .
#
# rsc:the_sting a sch:Movie ;
#     rdfs:label "The Sting"@en ;
#     sch:datePublished "1973-01-01"^^xsd:gYear ;
#     sch:director rsc:george_roy_hill .
#
# rsc:the_straight_story a sch:Movie ;
#     rdfs:label "The Straight Story"@en ;
#     sch:datePublished "1999-01-01"^^xsd:gYear ;
#     sch:director rsc:david_lynch .
#
# rsc:the_terminator a sch:Movie ;
#     rdfs:label "The Terminator"@en ;
#     sch:datePublished "1984-01-01"^^xsd:gYear ;
#     sch:director rsc:james_cameron .
#
# rsc:the_thing a sch:Movie ;
#     rdfs:label "The Thing"@en ;
#     sch:datePublished "1982-01-01"^^xsd:gYear ;
#     sch:director rsc:john_carpenter .
#
# rsc:the_third_man a sch:Movie ;
#     rdfs:label "The Third Man"@en ;
#     sch:datePublished "1949-01-01"^^xsd:gYear ;
#     sch:director rsc:carol_reed .
#
# rsc:the_treasure_of_the_sierra_madre a sch:Movie ;
#     rdfs:label "The Treasure of the Sierra Madre"@en ;
#     sch:datePublished "1948-01-01"^^xsd:gYear ;
#     sch:director rsc:john_huston .
#
# rsc:the_truman_show a sch:Movie ;
#     rdfs:label "The Truman Show"@en ;
#     sch:datePublished "1998-01-01"^^xsd:gYear ;
#     sch:director rsc:peter_weir .
#
# rsc:the_usual_suspects a sch:Movie ;
#     rdfs:label "The Usual Suspects"@en ;
#     sch:datePublished "1995-01-01"^^xsd:gYear ;
#     sch:director rsc:bryan_singer .
#
# rsc:the_wild_bunch a sch:Movie ;
#     rdfs:label "The Wild Bunch"@en ;
#     sch:datePublished "1969-01-01"^^xsd:gYear ;
#     sch:director rsc:sam_peckinpah .
#
# rsc:the_wizard_of_oz a sch:Movie ;
#     rdfs:label "The Wizard of Oz"@en ;
#     sch:datePublished "1939-01-01"^^xsd:gYear ;
#     sch:director rsc:george_cukor,
#         rsc:king_vidor,
#         rsc:mervyn_leroy,
#         rsc:norman_taurog,
#         rsc:victor_fleming .
#
# rsc:the_wolf_of_wall_street a sch:Movie ;
#     rdfs:label "The Wolf of Wall Street"@en ;
#     sch:datePublished "2013-01-01"^^xsd:gYear ;
#     sch:director rsc:martin_scorsese .
#
# rsc:there_will_be_blood a sch:Movie ;
#     rdfs:label "There Will Be Blood"@en ;
#     sch:datePublished "2007-01-01"^^xsd:gYear ;
#     sch:director rsc:paul_thomas_anderson .
#
# rsc:to_kill_a_mockingbird a sch:Movie ;
#     rdfs:label "To Kill a Mockingbird"@en ;
#     sch:datePublished "1962-01-01"^^xsd:gYear ;
#     sch:director rsc:robert_mulligan .
#
# rsc:touch_of_evil a sch:Movie ;
#     rdfs:label "Touch of Evil"@en ;
#     sch:datePublished "1958-01-01"^^xsd:gYear ;
#     sch:director rsc:orson_welles .
#
# rsc:toy_story a sch:Movie ;
#     rdfs:label "Toy Story"@en ;
#     sch:datePublished "1995-01-01"^^xsd:gYear ;
#     sch:director rsc:john_lasseter .
#
# rsc:toy_story_3 a sch:Movie ;
#     rdfs:label "Toy Story 3"@en ;
#     sch:datePublished "2010-01-01"^^xsd:gYear ;
#     sch:director rsc:lee_unkrich .
#
# rsc:trainspotting a sch:Movie ;
#     rdfs:label "Trainspotting"@en ;
#     sch:datePublished "1996-01-01"^^xsd:gYear ;
#     sch:director rsc:danny_boyle .
#
# rsc:twelve_monkeys a sch:Movie ;
#     rdfs:label "Twelve Monkeys"@en ;
#     sch:datePublished "1995-01-01"^^xsd:gYear ;
#     sch:director rsc:terry_gilliam .
#
# rsc:unforgiven a sch:Movie ;
#     rdfs:label "Unforgiven"@en ;
#     sch:datePublished "1992-01-01"^^xsd:gYear ;
#     sch:director rsc:clint_eastwood .
#
# rsc:up a sch:Movie ;
#     rdfs:label "Up"@en ;
#     sch:datePublished "2009-01-01"^^xsd:gYear ;
#     sch:director rsc:bob_peterson,
#         rsc:pete_docter .
#
# rsc:v_for_vendetta a sch:Movie ;
#     rdfs:label "V for Vendetta"@en ;
#     sch:datePublished "2005-01-01"^^xsd:gYear ;
#     sch:director rsc:james_mcteigue .
#
# rsc:vertigo a sch:Movie ;
#     rdfs:label "Vertigo"@en ;
#     sch:datePublished "1958-01-01"^^xsd:gYear ;
#     sch:director rsc:alfred_hitchcock .
#
# rsc:wallâ·e a sch:Movie ;
#     rdfs:label "WALLÂ·E"@en ;
#     sch:datePublished "2008-01-01"^^xsd:gYear ;
#     sch:director rsc:andrew_stanton .
#
# rsc:warrior a sch:Movie ;
#     rdfs:label "Warrior"@en ;
#     sch:datePublished "2011-01-01"^^xsd:gYear ;
#     sch:director <http://philip-broehl.org/resource/gavin_o'connor> .
#
# <http://philip-broehl.org/resource/what_ever_happened_to_baby_jane?> a sch:Movie ;
#     rdfs:label "What Ever Happened to Baby Jane?"@en ;
#     sch:datePublished "1962-01-01"^^xsd:gYear ;
#     sch:director rsc:robert_aldrich .
#
# rsc:whiplash a sch:Movie ;
#     rdfs:label "Whiplash"@en ;
#     sch:datePublished "2014-01-01"^^xsd:gYear ;
#     sch:director rsc:damien_chazelle .
#
# <http://philip-broehl.org/resource/who's_afraid_of_virginia_woolf?> a sch:Movie ;
#     rdfs:label "Who's Afraid of Virginia Woolf?"@en ;
#     sch:datePublished "1966-01-01"^^xsd:gYear ;
#     sch:director rsc:mike_nichols .
#
# rsc:witness_for_the_prosecution a sch:Movie ;
#     rdfs:label "Witness for the Prosecution"@en ;
#     sch:datePublished "1957-01-01"^^xsd:gYear ;
#     sch:director rsc:billy_wilder .
#
# rsc:young_frankenstein a sch:Movie ;
#     rdfs:label "Young Frankenstein"@en ;
#     sch:datePublished "1974-01-01"^^xsd:gYear ;
#     sch:director rsc:mel_brooks .
#
# rsc:zootopia a sch:Movie ;
#     rdfs:label "Zootopia"@en ;
#     sch:datePublished "2016-01-01"^^xsd:gYear ;
#     sch:director rsc:byron_howard,
#         rsc:jared_bush,
#         rsc:rich_moore .
#
# rsc:adam_elliot a sch:Person ;
#     foaf:name "Adam Elliot"@en .
#
# rsc:alan_parker a sch:Person ;
#     foaf:name "Alan Parker"@en .
#
# <http://philip-broehl.org/resource/alejandro_gonzã¡lez_iã±ã¡rritu> a sch:Person ;
#     foaf:name "Alejandro GonzÃ¡lez IÃ±Ã¡rritu"@en .
#
# rsc:barry_levinson a sch:Person ;
#     foaf:name "Barry Levinson"@en .
#
# rsc:billy_bob_thornton a sch:Person ;
#     foaf:name "Billy Bob Thornton"@en .
#
# rsc:bob_clark a sch:Person ;
#     foaf:name "Bob Clark"@en .
#
# rsc:bob_peterson a sch:Person ;
#     foaf:name "Bob Peterson"@en .
#
# rsc:brian_de_palma a sch:Person ;
#     foaf:name "Brian De Palma"@en .
#
# rsc:bryan_singer a sch:Person ;
#     foaf:name "Bryan Singer"@en .
#
# rsc:buster_keaton a sch:Person ;
#     foaf:name "Buster Keaton"@en .
#
# rsc:byron_howard a sch:Person ;
#     foaf:name "Byron Howard"@en .
#
# rsc:carol_reed a sch:Person ;
#     foaf:name "Carol Reed"@en .
#
# rsc:charles_laughton a sch:Person ;
#     foaf:name "Charles Laughton"@en .
#
# rsc:chris_sanders a sch:Person ;
#     foaf:name "Chris Sanders"@en .
#
# rsc:clyde_bruckman a sch:Person ;
#     foaf:name "Clyde Bruckman"@en .
#
# rsc:curtis_hanson a sch:Person ;
#     foaf:name "Curtis Hanson"@en .
#
# rsc:darren_aronofsky a sch:Person ;
#     foaf:name "Darren Aronofsky"@en .
#
# rsc:david_silverman a sch:Person ;
#     foaf:name "David Silverman"@en .
#
# rsc:david_yates a sch:Person ;
#     foaf:name "David Yates"@en .
#
# rsc:dean_deblois a sch:Person ;
#     foaf:name "Dean DeBlois"@en .
#
# rsc:denis_villeneuve a sch:Person ;
#     foaf:name "Denis Villeneuve"@en .
#
# rsc:destin_daniel_cretton a sch:Person ;
#     foaf:name "Destin Daniel Cretton"@en .
#
# rsc:edgar_wright a sch:Person ;
#     foaf:name "Edgar Wright"@en .
#
# rsc:edmund_goulding a sch:Person ;
#     foaf:name "Edmund Goulding"@en .
#
# rsc:edward_zwick a sch:Person ;
#     foaf:name "Edward Zwick"@en .
#
# rsc:eli_roth a sch:Person ;
#     foaf:name "Eli Roth"@en .
#
# rsc:frank_miller a sch:Person ;
#     foaf:name "Frank Miller"@en .
#
# rsc:fred_zinnemann a sch:Person ;
#     foaf:name "Fred Zinnemann"@en .
#
# rsc:garth_davis a sch:Person ;
#     foaf:name "Garth Davis"@en .
#
# rsc:gary_trousdale a sch:Person ;
#     foaf:name "Gary Trousdale"@en .
#
# <http://philip-broehl.org/resource/gavin_o'connor> a sch:Person ;
#     foaf:name "Gavin O'Connor"@en .
#
# rsc:gene_kelly a sch:Person ;
#     foaf:name "Gene Kelly"@en .
#
# rsc:george_lucas a sch:Person ;
#     foaf:name "George Lucas"@en .
#
# rsc:george_miller a sch:Person ;
#     foaf:name "George Miller"@en .
#
# rsc:giuseppe_tornatore a sch:Person ;
#     foaf:name "Giuseppe Tornatore"@en .
#
# rsc:gore_verbinski a sch:Person ;
#     foaf:name "Gore Verbinski"@en .
#
# rsc:gus_van_sant a sch:Person ;
#     foaf:name "Gus Van Sant"@en .
#
# rsc:harold_ramis a sch:Person ;
#     foaf:name "Harold Ramis"@en .
#
# rsc:henry_koster a sch:Person ;
#     foaf:name "Henry Koster"@en .
#
# rsc:henry_selick a sch:Person ;
#     foaf:name "Henry Selick"@en .
#
# rsc:irvin_kershner a sch:Person ;
#     foaf:name "Irvin Kershner"@en .
#
# rsc:j.j._abrams a sch:Person ;
#     foaf:name "J.J. Abrams"@en .
#
# rsc:jacques_tourneur a sch:Person ;
#     foaf:name "Jacques Tourneur"@en .
#
# rsc:james_mangold a sch:Person ;
#     foaf:name "James Mangold"@en .
#
# rsc:james_mcteigue a sch:Person ;
#     foaf:name "James McTeigue"@en .
#
# rsc:jared_bush a sch:Person ;
#     foaf:name "Jared Bush"@en .
#
# rsc:jim_sheridan a sch:Person ;
#     foaf:name "Jim Sheridan"@en .
#
# rsc:john_carpenter a sch:Person ;
#     foaf:name "John Carpenter"@en .
#
# rsc:john_frankenheimer a sch:Person ;
#     foaf:name "John Frankenheimer"@en .
#
# rsc:john_g._avildsen a sch:Person ;
#     foaf:name "John G. Avildsen"@en .
#
# rsc:john_lasseter a sch:Person ;
#     foaf:name "John Lasseter"@en .
#
# rsc:john_mctiernan a sch:Person ;
#     foaf:name "John McTiernan"@en .
#
# rsc:john_musker a sch:Person ;
#     foaf:name "John Musker"@en .
#
# rsc:john_sturges a sch:Person ;
#     foaf:name "John Sturges"@en .
#
# rsc:jon_watts a sch:Person ;
#     foaf:name "Jon Watts"@en .
#
# rsc:jonathan_demme a sch:Person ;
#     foaf:name "Jonathan Demme"@en .
#
# rsc:joss_whedon a sch:Person ;
#     foaf:name "Joss Whedon"@en .
#
# rsc:king_vidor a sch:Person ;
#     foaf:name "King Vidor"@en .
#
# rsc:kirk_wise a sch:Person ;
#     foaf:name "Kirk Wise"@en .
#
# rsc:lana_wachowski a sch:Person ;
#     foaf:name "Lana Wachowski"@en .
#
# rsc:lars_von_trier a sch:Person ;
#     foaf:name "Lars von Trier"@en .
#
# <http://philip-broehl.org/resource/lasse_hallstrã¶m> a sch:Person ;
#     foaf:name "Lasse HallstrÃ¶m"@en .
#
# rsc:lenny_abrahamson a sch:Person ;
#     foaf:name "Lenny Abrahamson"@en .
#
# rsc:lewis_milestone a sch:Person ;
#     foaf:name "Lewis Milestone"@en .
#
# rsc:lilly_wachowski a sch:Person ;
#     foaf:name "Lilly Wachowski"@en .
#
# rsc:loveleen_tandan a sch:Person ;
#     foaf:name "Loveleen Tandan"@en .
#
# rsc:luc_besson a sch:Person ;
#     foaf:name "Luc Besson"@en .
#
# rsc:m._night_shyamalan a sch:Person ;
#     foaf:name "M. Night Shyamalan"@en .
#
# rsc:mel_brooks a sch:Person ;
#     foaf:name "Mel Brooks"@en .
#
# rsc:mervyn_leroy a sch:Person ;
#     foaf:name "Mervyn LeRoy"@en .
#
# rsc:michael_cimino a sch:Person ;
#     foaf:name "Michael Cimino"@en .
#
# rsc:michael_curtiz a sch:Person ;
#     foaf:name "Michael Curtiz"@en .
#
# rsc:michael_mann a sch:Person ;
#     foaf:name "Michael Mann"@en .
#
# rsc:michel_gondry a sch:Person ;
#     foaf:name "Michel Gondry"@en .
#
# rsc:morten_tyldum a sch:Person ;
#     foaf:name "Morten Tyldum"@en .
#
# rsc:moustapha_akkad a sch:Person ;
#     foaf:name "Moustapha Akkad"@en .
#
# rsc:norman_taurog a sch:Person ;
#     foaf:name "Norman Taurog"@en .
#
# rsc:paul_greengrass a sch:Person ;
#     foaf:name "Paul Greengrass"@en .
#
# rsc:peter_bogdanovich a sch:Person ;
#     foaf:name "Peter Bogdanovich"@en .
#
# rsc:rich_moore a sch:Person ;
#     foaf:name "Rich Moore"@en .
#
# rsc:richard_attenborough a sch:Person ;
#     foaf:name "Richard Attenborough"@en .
#
# rsc:richard_brooks a sch:Person ;
#     foaf:name "Richard Brooks"@en .
#
# rsc:richard_kelly a sch:Person ;
#     foaf:name "Richard Kelly"@en .
#
# rsc:richard_marquand a sch:Person ;
#     foaf:name "Richard Marquand"@en .
#
# rsc:rob_minkoff a sch:Person ;
#     foaf:name "Rob Minkoff"@en .
#
# rsc:robert_aldrich a sch:Person ;
#     foaf:name "Robert Aldrich"@en .
#
# rsc:robert_hamer a sch:Person ;
#     foaf:name "Robert Hamer"@en .
#
# rsc:robert_mulligan a sch:Person ;
#     foaf:name "Robert Mulligan"@en .
#
# rsc:robert_rodriguez a sch:Person ;
#     foaf:name "Robert Rodriguez"@en .
#
# rsc:robert_rossen a sch:Person ;
#     foaf:name "Robert Rossen"@en .
#
# rsc:roger_allers a sch:Person ;
#     foaf:name "Roger Allers"@en .
#
# rsc:ron_clements a sch:Person ;
#     foaf:name "Ron Clements"@en .
#
# rsc:ronnie_del_carmen a sch:Person ;
#     foaf:name "Ronnie Del Carmen"@en .
#
# rsc:sam_mendes a sch:Person ;
#     foaf:name "Sam Mendes"@en .
#
# rsc:sam_peckinpah a sch:Person ;
#     foaf:name "Sam Peckinpah"@en .
#
# rsc:sean_penn a sch:Person ;
#     foaf:name "Sean Penn"@en .
#
# rsc:sergio_leone a sch:Person ;
#     foaf:name "Sergio Leone"@en .
#
# rsc:stanley_donen a sch:Person ;
#     foaf:name "Stanley Donen"@en .
#
# rsc:stanley_kramer a sch:Person ;
#     foaf:name "Stanley Kramer"@en .
#
# rsc:steve_mcqueen a sch:Person ;
#     foaf:name "Steve McQueen"@en .
#
# rsc:stuart_rosenberg a sch:Person ;
#     foaf:name "Stuart Rosenberg"@en .
#
# rsc:tate_taylor a sch:Person ;
#     foaf:name "Tate Taylor"@en .
#
# rsc:terry_george a sch:Person ;
#     foaf:name "Terry George"@en .
#
# rsc:tim_burton a sch:Person ;
#     foaf:name "Tim Burton"@en .
#
# rsc:tim_miller a sch:Person ;
#     foaf:name "Tim Miller"@en .
#
# rsc:tom_hooper a sch:Person ;
#     foaf:name "Tom Hooper"@en .
#
# rsc:tom_mccarthy a sch:Person ;
#     foaf:name "Tom McCarthy"@en .
#
# rsc:tomm_moore a sch:Person ;
#     foaf:name "Tomm Moore"@en .
#
# rsc:tony_kaye a sch:Person ;
#     foaf:name "Tony Kaye"@en .
#
# rsc:wes_anderson a sch:Person ;
#     foaf:name "Wes Anderson"@en .
#
# rsc:william_friedkin a sch:Person ;
#     foaf:name "William Friedkin"@en .
#
# rsc:wim_wenders a sch:Person ;
#     foaf:name "Wim Wenders"@en .
#
# rsc:woody_allen a sch:Person ;
#     foaf:name "Woody Allen"@en .
#
# rsc:andrew_stanton a sch:Person ;
#     foaf:name "Andrew Stanton"@en .
#
# rsc:damien_chazelle a sch:Person ;
#     foaf:name "Damien Chazelle"@en .
#
# rsc:danny_boyle a sch:Person ;
#     foaf:name "Danny Boyle"@en .
#
# rsc:david_lynch a sch:Person ;
#     foaf:name "David Lynch"@en .
#
# rsc:elia_kazan a sch:Person ;
#     foaf:name "Elia Kazan"@en .
#
# rsc:frank_darabont a sch:Person ;
#     foaf:name "Frank Darabont"@en .
#
# rsc:franklin_j._schaffner a sch:Person ;
#     foaf:name "Franklin J. Schaffner"@en .
#
# rsc:george_roy_hill a sch:Person ;
#     foaf:name "George Roy Hill"@en .
#
# rsc:guy_ritchie a sch:Person ;
#     foaf:name "Guy Ritchie"@en .
#
# rsc:james_gunn a sch:Person ;
#     foaf:name "James Gunn"@en .
#
# rsc:john_ford a sch:Person ;
#     foaf:name "John Ford"@en .
#
# rsc:john_huston a sch:Person ;
#     foaf:name "John Huston"@en .
#
# rsc:joseph_l._mankiewicz a sch:Person ;
#     foaf:name "Joseph L. Mankiewicz"@en .
#
# rsc:mel_gibson a sch:Person ;
#     foaf:name "Mel Gibson"@en .
#
# rsc:mike_nichols a sch:Person ;
#     foaf:name "Mike Nichols"@en .
#
# rsc:milos_forman a sch:Person ;
#     foaf:name "Milos Forman"@en .
#
# rsc:oliver_stone a sch:Person ;
#     foaf:name "Oliver Stone"@en .
#
# rsc:orson_welles a sch:Person ;
#     foaf:name "Orson Welles"@en .
#
# rsc:otto_preminger a sch:Person ;
#     foaf:name "Otto Preminger"@en .
#
# rsc:paul_thomas_anderson a sch:Person ;
#     foaf:name "Paul Thomas Anderson"@en .
#
# rsc:peter_weir a sch:Person ;
#     foaf:name "Peter Weir"@en .
#
# rsc:richard_linklater a sch:Person ;
#     foaf:name "Richard Linklater"@en .
#
# rsc:rob_reiner a sch:Person ;
#     foaf:name "Rob Reiner"@en .
#
# rsc:robert_zemeckis a sch:Person ;
#     foaf:name "Robert Zemeckis"@en .
#
# rsc:roman_polanski a sch:Person ;
#     foaf:name "Roman Polanski"@en .
#
# rsc:ron_howard a sch:Person ;
#     foaf:name "Ron Howard"@en .
#
# rsc:sam_wood a sch:Person ;
#     foaf:name "Sam Wood"@en .
#
# rsc:terry_gilliam a sch:Person ;
#     foaf:name "Terry Gilliam"@en .
#
# rsc:terry_jones a sch:Person ;
#     foaf:name "Terry Jones"@en .
#
# rsc:victor_fleming a sch:Person ;
#     foaf:name "Victor Fleming"@en .
#
# rsc:clint_eastwood a sch:Person ;
#     foaf:name "Clint Eastwood"@en .
#
# rsc:david_fincher a sch:Person ;
#     foaf:name "David Fincher"@en .
#
# rsc:david_lean a sch:Person ;
#     foaf:name "David Lean"@en .
#
# rsc:ethan_coen a sch:Person ;
#     foaf:name "Ethan Coen"@en .
#
# rsc:francis_ford_coppola a sch:Person ;
#     foaf:name "Francis Ford Coppola"@en .
#
# rsc:george_cukor a sch:Person ;
#     foaf:name "George Cukor"@en .
#
# rsc:howard_hawks a sch:Person ;
#     foaf:name "Howard Hawks"@en .
#
# rsc:james_cameron a sch:Person ;
#     foaf:name "James Cameron"@en .
#
# rsc:joel_coen a sch:Person ;
#     foaf:name "Joel Coen"@en .
#
# rsc:lee_unkrich a sch:Person ;
#     foaf:name "Lee Unkrich"@en .
#
# rsc:pete_docter a sch:Person ;
#     foaf:name "Pete Docter"@en .
#
# rsc:peter_jackson a sch:Person ;
#     foaf:name "Peter Jackson"@en .
#
# rsc:sidney_lumet a sch:Person ;
#     foaf:name "Sidney Lumet"@en .
#
# rsc:william_wyler a sch:Person ;
#     foaf:name "William Wyler"@en .
#
# rsc:frank_capra a sch:Person ;
#     foaf:name "Frank Capra"@en .
#
# rsc:ridley_scott a sch:Person ;
#     foaf:name "Ridley Scott"@en .
#
# rsc:charles_chaplin a sch:Person ;
#     foaf:name "Charles Chaplin"@en .
#
# rsc:quentin_tarantino a sch:Person ;
#     foaf:name "Quentin Tarantino"@en .
#
# rsc:billy_wilder a sch:Person ;
#     foaf:name "Billy Wilder"@en .
#
# rsc:christopher_nolan a sch:Person ;
#     foaf:name "Christopher Nolan"@en .
#
# rsc:martin_scorsese a sch:Person ;
#     foaf:name "Martin Scorsese"@en .
#
# rsc:steven_spielberg a sch:Person ;
#     foaf:name "Steven Spielberg"@en .
#
# rsc:stanley_kubrick a sch:Person ;
#     foaf:name "Stanley Kubrick"@en .
#
# rsc:alfred_hitchcock a sch:Person ;
#     foaf:name "Alfred Hitchcock"@en .
