# %% [markdown]
# # TASK: Model the data in RDF
#
#
#
# ## Overview
# In this task, your assignment is to model the 'input_movie_data.csv' data set as Linked Open Data represented in RDF.
# This means, entities and relationships must be represented via IRIs. A good Linked Data best practice is to re-use existing RDF vocabularies for such a process.
#
# ## Task details
# 1. Re-use the schema.org vocabulary (https://schema.org/) to model the data in RDF.
# 2. Use self-defined valid URLs as IRIs to represent all entities, using your first- and last name as domain. For example, the movie “The Godfather” can be represented with http://firstname-lastname.org/resource/the_godfather
# > __HINT__: URLs must be valid, but do not have to resolve!
# 3. Re-using schema.org, find the classes of the corresponding instances and represent the instances with that class (or classes). For example, if we were re-using the DBpedia vocabulary, the movie “The Godfather” would be of type <http://dbpedia.org/ontology/Film> resulting in a triple representation: <br>
# `<http://firstname-lastname.org/resource/the_godfather> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/ontology/Film>`
#
# > Find such RDF classes in the schema.org vocabulary to specify the rdf:type properties for movie and person.
#
# 4. Re-using schema.org, find the appropriate object property specifying that a movie has a director.
# > __Hint__: Some movies have more than one director
# 5. In addition, find appropriate properties to describe
#   - the name of a movie including the English language tag,
#   - the publication year of a movie including the literal data type of year
#   >__HINT__: not xsd:date, see xsd definition for correct data type for year
#   - the name of a person
#   > __HINT__: Watch out for the correct domain and range of properties, as well as subclass relationships
#
# <br><br>
#
# ## Submission 1
#
# Save the data set that you have represented in RDF (in N3) to the output_data folder with the naming __movies_task_1.n3__.

# %% [markdown]
# <br>
#
# ## Your code

# %%
# Example code

# %%
from rdflib import URIRef, Literal, Graph, Namespace
from rdflib.namespace import FOAF, RDF, RDFS, XSD, DC
import urllib
import csv
from datetime import datetime
from SPARQLWrapper import SPARQLWrapper, JSON, N3

# %%
# Defines further Namespaces
EX = Namespace("https://ex1.org/")
DBO = Namespace("http://dbpedia.org/ontology/")
RSC = Namespace("http://philip-broehl.org/resource/")

# %%
input_file = open("../input_data/input_movie_data.csv")
text = csv.reader(input_file, delimiter = ',')

g = Graph()
line_count = 0
for line in text:
    if line_count == 0:
        line_count += 1
    else:
        title = line[1]
        film_resource = title.lower().replace(' ', '_')  # just for valid URI format
        
        year = line[2]
        director = line[3]
        director_list = director.split(', ')  # there can be multiple directors
        
        g.add((URIRef(RSC[film_resource]), RDF.type, DBO.Film))
        g.add((URIRef(RSC[film_resource]), RDFS.label, Literal(title, lang = 'en')))
        g.add((URIRef(RSC[film_resource]), XSD.gYear, Literal(year)))
        
        for director in director_list: 
            director_resource = director.lower().replace(' ', '_')
            g.add((URIRef(RSC[director_resource]), RDF.type, DBO.Person))
            g.add((URIRef(RSC[director_resource]), FOAF.name, Literal(director, lang = 'en')))        
            g.add((URIRef(RSC[film_resource]), DBO.director, URIRef(RSC[director_resource])))
        
print(g.serialize(format="n3").decode("utf-8"))

g.serialize(destination='../output_data/movies_task_1.n3', format='n3')
# Out:
# @prefix ns1: <http://dbpedia.org/ontology/> .
# @prefix ns2: <http://xmlns.com/foaf/0.1/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://philip-broehl.org/resource/12_angry_men> a ns1:Film ;
#     rdfs:label "12 Angry Men"@en ;
#     ns1:director <http://philip-broehl.org/resource/sidney_lumet> ;
#     xsd:gYear "1957" .
#
# <http://philip-broehl.org/resource/12_years_a_slave> a ns1:Film ;
#     rdfs:label "12 Years a Slave"@en ;
#     ns1:director <http://philip-broehl.org/resource/steve_mcqueen> ;
#     xsd:gYear "2013" .
#
# <http://philip-broehl.org/resource/2001:_a_space_odyssey> a ns1:Film ;
#     rdfs:label "2001: A Space Odyssey"@en ;
#     ns1:director <http://philip-broehl.org/resource/stanley_kubrick> ;
#     xsd:gYear "1968" .
#
# <http://philip-broehl.org/resource/a_beautiful_mind> a ns1:Film ;
#     rdfs:label "A Beautiful Mind"@en ;
#     ns1:director <http://philip-broehl.org/resource/ron_howard> ;
#     xsd:gYear "2001" .
#
# <http://philip-broehl.org/resource/a_christmas_story> a ns1:Film ;
#     rdfs:label "A Christmas Story"@en ;
#     ns1:director <http://philip-broehl.org/resource/bob_clark> ;
#     xsd:gYear "1983" .
#
# <http://philip-broehl.org/resource/a_clockwork_orange> a ns1:Film ;
#     rdfs:label "A Clockwork Orange"@en ;
#     ns1:director <http://philip-broehl.org/resource/stanley_kubrick> ;
#     xsd:gYear "1971" .
#
# <http://philip-broehl.org/resource/a_night_at_the_opera> a ns1:Film ;
#     rdfs:label "A Night at the Opera"@en ;
#     ns1:director <http://philip-broehl.org/resource/edmund_goulding>,
#         <http://philip-broehl.org/resource/sam_wood> ;
#     xsd:gYear "1935" .
#
# <http://philip-broehl.org/resource/a_streetcar_named_desire> a ns1:Film ;
#     rdfs:label "A Streetcar Named Desire"@en ;
#     ns1:director <http://philip-broehl.org/resource/elia_kazan> ;
#     xsd:gYear "1951" .
#
# <http://philip-broehl.org/resource/aladdin> a ns1:Film ;
#     rdfs:label "Aladdin"@en ;
#     ns1:director <http://philip-broehl.org/resource/john_musker>,
#         <http://philip-broehl.org/resource/ron_clements> ;
#     xsd:gYear "1992" .
#
# <http://philip-broehl.org/resource/alien> a ns1:Film ;
#     rdfs:label "Alien"@en ;
#     ns1:director <http://philip-broehl.org/resource/ridley_scott> ;
#     xsd:gYear "1979" .
#
# <http://philip-broehl.org/resource/aliens> a ns1:Film ;
#     rdfs:label "Aliens"@en ;
#     ns1:director <http://philip-broehl.org/resource/james_cameron> ;
#     xsd:gYear "1986" .
#
# <http://philip-broehl.org/resource/all_about_eve> a ns1:Film ;
#     rdfs:label "All About Eve"@en ;
#     ns1:director <http://philip-broehl.org/resource/joseph_l._mankiewicz> ;
#     xsd:gYear "1950" .
#
# <http://philip-broehl.org/resource/all_quiet_on_the_western_front> a ns1:Film ;
#     rdfs:label "All Quiet on the Western Front"@en ;
#     ns1:director <http://philip-broehl.org/resource/lewis_milestone> ;
#     xsd:gYear "1930" .
#
# <http://philip-broehl.org/resource/amadeus> a ns1:Film ;
#     rdfs:label "Amadeus"@en ;
#     ns1:director <http://philip-broehl.org/resource/milos_forman> ;
#     xsd:gYear "1984" .
#
# <http://philip-broehl.org/resource/american_beauty> a ns1:Film ;
#     rdfs:label "American Beauty"@en ;
#     ns1:director <http://philip-broehl.org/resource/sam_mendes> ;
#     xsd:gYear "1999" .
#
# <http://philip-broehl.org/resource/american_history_x> a ns1:Film ;
#     rdfs:label "American History X"@en ;
#     ns1:director <http://philip-broehl.org/resource/tony_kaye> ;
#     xsd:gYear "1998" .
#
# <http://philip-broehl.org/resource/anatomy_of_a_murder> a ns1:Film ;
#     rdfs:label "Anatomy of a Murder"@en ;
#     ns1:director <http://philip-broehl.org/resource/otto_preminger> ;
#     xsd:gYear "1959" .
#
# <http://philip-broehl.org/resource/annie_hall> a ns1:Film ;
#     rdfs:label "Annie Hall"@en ;
#     ns1:director <http://philip-broehl.org/resource/woody_allen> ;
#     xsd:gYear "1977" .
#
# <http://philip-broehl.org/resource/apocalypse_now> a ns1:Film ;
#     rdfs:label "Apocalypse Now"@en ;
#     ns1:director <http://philip-broehl.org/resource/francis_ford_coppola> ;
#     xsd:gYear "1979" .
#
# <http://philip-broehl.org/resource/arsenic_and_old_lace> a ns1:Film ;
#     rdfs:label "Arsenic and Old Lace"@en ;
#     ns1:director <http://philip-broehl.org/resource/frank_capra> ;
#     xsd:gYear "1944" .
#
# <http://philip-broehl.org/resource/baby_driver> a ns1:Film ;
#     rdfs:label "Baby Driver"@en ;
#     ns1:director <http://philip-broehl.org/resource/edgar_wright> ;
#     xsd:gYear "2017" .
#
# <http://philip-broehl.org/resource/back_to_the_future> a ns1:Film ;
#     rdfs:label "Back to the Future"@en ;
#     ns1:director <http://philip-broehl.org/resource/robert_zemeckis> ;
#     xsd:gYear "1985" .
#
# <http://philip-broehl.org/resource/barry_lyndon> a ns1:Film ;
#     rdfs:label "Barry Lyndon"@en ;
#     ns1:director <http://philip-broehl.org/resource/stanley_kubrick> ;
#     xsd:gYear "1975" .
#
# <http://philip-broehl.org/resource/batman_begins> a ns1:Film ;
#     rdfs:label "Batman Begins"@en ;
#     ns1:director <http://philip-broehl.org/resource/christopher_nolan> ;
#     xsd:gYear "2005" .
#
# <http://philip-broehl.org/resource/beauty_and_the_beast> a ns1:Film ;
#     rdfs:label "Beauty and the Beast"@en ;
#     ns1:director <http://philip-broehl.org/resource/gary_trousdale>,
#         <http://philip-broehl.org/resource/kirk_wise> ;
#     xsd:gYear "1991" .
#
# <http://philip-broehl.org/resource/before_sunrise> a ns1:Film ;
#     rdfs:label "Before Sunrise"@en ;
#     ns1:director <http://philip-broehl.org/resource/richard_linklater> ;
#     xsd:gYear "1995" .
#
# <http://philip-broehl.org/resource/before_sunset> a ns1:Film ;
#     rdfs:label "Before Sunset"@en ;
#     ns1:director <http://philip-broehl.org/resource/richard_linklater> ;
#     xsd:gYear "2004" .
#
# <http://philip-broehl.org/resource/ben-hur> a ns1:Film ;
#     rdfs:label "Ben-Hur"@en ;
#     ns1:director <http://philip-broehl.org/resource/william_wyler> ;
#     xsd:gYear "1959" .
#
# <http://philip-broehl.org/resource/big_fish> a ns1:Film ;
#     rdfs:label "Big Fish"@en ;
#     ns1:director <http://philip-broehl.org/resource/tim_burton> ;
#     xsd:gYear "2003" .
#
# <http://philip-broehl.org/resource/blade_runner> a ns1:Film ;
#     rdfs:label "Blade Runner"@en ;
#     ns1:director <http://philip-broehl.org/resource/ridley_scott> ;
#     xsd:gYear "1982" .
#
# <http://philip-broehl.org/resource/blood_diamond> a ns1:Film ;
#     rdfs:label "Blood Diamond"@en ;
#     ns1:director <http://philip-broehl.org/resource/edward_zwick> ;
#     xsd:gYear "2006" .
#
# <http://philip-broehl.org/resource/braveheart> a ns1:Film ;
#     rdfs:label "Braveheart"@en ;
#     ns1:director <http://philip-broehl.org/resource/mel_gibson> ;
#     xsd:gYear "1995" .
#
# <http://philip-broehl.org/resource/brief_encounter> a ns1:Film ;
#     rdfs:label "Brief Encounter"@en ;
#     ns1:director <http://philip-broehl.org/resource/david_lean> ;
#     xsd:gYear "1945" .
#
# <http://philip-broehl.org/resource/butch_cassidy_and_the_sundance_kid> a ns1:Film ;
#     rdfs:label "Butch Cassidy and the Sundance Kid"@en ;
#     ns1:director <http://philip-broehl.org/resource/george_roy_hill> ;
#     xsd:gYear "1969" .
#
# <http://philip-broehl.org/resource/casablanca> a ns1:Film ;
#     rdfs:label "Casablanca"@en ;
#     ns1:director <http://philip-broehl.org/resource/michael_curtiz> ;
#     xsd:gYear "1942" .
#
# <http://philip-broehl.org/resource/casino> a ns1:Film ;
#     rdfs:label "Casino"@en ;
#     ns1:director <http://philip-broehl.org/resource/martin_scorsese> ;
#     xsd:gYear "1995" .
#
# <http://philip-broehl.org/resource/cat_on_a_hot_tin_roof> a ns1:Film ;
#     rdfs:label "Cat on a Hot Tin Roof"@en ;
#     ns1:director <http://philip-broehl.org/resource/richard_brooks> ;
#     xsd:gYear "1958" .
#
# <http://philip-broehl.org/resource/catch_me_if_you_can> a ns1:Film ;
#     rdfs:label "Catch Me If You Can"@en ;
#     ns1:director <http://philip-broehl.org/resource/steven_spielberg> ;
#     xsd:gYear "2002" .
#
# <http://philip-broehl.org/resource/chinatown> a ns1:Film ;
#     rdfs:label "Chinatown"@en ;
#     ns1:director <http://philip-broehl.org/resource/roman_polanski> ;
#     xsd:gYear "1974" .
#
# <http://philip-broehl.org/resource/citizen_kane> a ns1:Film ;
#     rdfs:label "Citizen Kane"@en ;
#     ns1:director <http://philip-broehl.org/resource/orson_welles> ;
#     xsd:gYear "1941" .
#
# <http://philip-broehl.org/resource/city_lights> a ns1:Film ;
#     rdfs:label "City Lights"@en ;
#     ns1:director <http://philip-broehl.org/resource/charles_chaplin> ;
#     xsd:gYear "1931" .
#
# <http://philip-broehl.org/resource/cool_hand_luke> a ns1:Film ;
#     rdfs:label "Cool Hand Luke"@en ;
#     ns1:director <http://philip-broehl.org/resource/stuart_rosenberg> ;
#     xsd:gYear "1967" .
#
# <http://philip-broehl.org/resource/dead_poets_society> a ns1:Film ;
#     rdfs:label "Dead Poets Society"@en ;
#     ns1:director <http://philip-broehl.org/resource/peter_weir> ;
#     xsd:gYear "1989" .
#
# <http://philip-broehl.org/resource/deadpool> a ns1:Film ;
#     rdfs:label "Deadpool"@en ;
#     ns1:director <http://philip-broehl.org/resource/tim_miller> ;
#     xsd:gYear "2016" .
#
# <http://philip-broehl.org/resource/dial_m_for_murder> a ns1:Film ;
#     rdfs:label "Dial M for Murder"@en ;
#     ns1:director <http://philip-broehl.org/resource/alfred_hitchcock> ;
#     xsd:gYear "1954" .
#
# <http://philip-broehl.org/resource/die_hard> a ns1:Film ;
#     rdfs:label "Die Hard"@en ;
#     ns1:director <http://philip-broehl.org/resource/john_mctiernan> ;
#     xsd:gYear "1988" .
#
# <http://philip-broehl.org/resource/django_unchained> a ns1:Film ;
#     rdfs:label "Django Unchained"@en ;
#     ns1:director <http://philip-broehl.org/resource/quentin_tarantino> ;
#     xsd:gYear "2012" .
#
# <http://philip-broehl.org/resource/dog_day_afternoon> a ns1:Film ;
#     rdfs:label "Dog Day Afternoon"@en ;
#     ns1:director <http://philip-broehl.org/resource/sidney_lumet> ;
#     xsd:gYear "1975" .
#
# <http://philip-broehl.org/resource/dogville> a ns1:Film ;
#     rdfs:label "Dogville"@en ;
#     ns1:director <http://philip-broehl.org/resource/lars_von_trier> ;
#     xsd:gYear "2003" .
#
# <http://philip-broehl.org/resource/donnie_darko> a ns1:Film ;
#     rdfs:label "Donnie Darko"@en ;
#     ns1:director <http://philip-broehl.org/resource/richard_kelly> ;
#     xsd:gYear "2001" .
#
# <http://philip-broehl.org/resource/double_indemnity> a ns1:Film ;
#     rdfs:label "Double Indemnity"@en ;
#     ns1:director <http://philip-broehl.org/resource/billy_wilder> ;
#     xsd:gYear "1944" .
#
# <http://philip-broehl.org/resource/dr._strangelove_or:_how_i_learned_to_stop_worrying_and_love_the_bomb> a ns1:Film ;
#     rdfs:label "Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb"@en ;
#     ns1:director <http://philip-broehl.org/resource/stanley_kubrick> ;
#     xsd:gYear "1964" .
#
# <http://philip-broehl.org/resource/eternal_sunshine_of_the_spotless_mind> a ns1:Film ;
#     rdfs:label "Eternal Sunshine of the Spotless Mind"@en ;
#     ns1:director <http://philip-broehl.org/resource/michel_gondry> ;
#     xsd:gYear "2004" .
#
# <http://philip-broehl.org/resource/fargo> a ns1:Film ;
#     rdfs:label "Fargo"@en ;
#     ns1:director <http://philip-broehl.org/resource/ethan_coen>,
#         <http://philip-broehl.org/resource/joel_coen> ;
#     xsd:gYear "1996" .
#
# <http://philip-broehl.org/resource/fight_club> a ns1:Film ;
#     rdfs:label "Fight Club"@en ;
#     ns1:director <http://philip-broehl.org/resource/david_fincher> ;
#     xsd:gYear "1999" .
#
# <http://philip-broehl.org/resource/finding_nemo> a ns1:Film ;
#     rdfs:label "Finding Nemo"@en ;
#     ns1:director <http://philip-broehl.org/resource/andrew_stanton>,
#         <http://philip-broehl.org/resource/lee_unkrich> ;
#     xsd:gYear "2003" .
#
# <http://philip-broehl.org/resource/forrest_gump> a ns1:Film ;
#     rdfs:label "Forrest Gump"@en ;
#     ns1:director <http://philip-broehl.org/resource/robert_zemeckis> ;
#     xsd:gYear "1994" .
#
# <http://philip-broehl.org/resource/full_metal_jacket> a ns1:Film ;
#     rdfs:label "Full Metal Jacket"@en ;
#     ns1:director <http://philip-broehl.org/resource/stanley_kubrick> ;
#     xsd:gYear "1987" .
#
# <http://philip-broehl.org/resource/gandhi> a ns1:Film ;
#     rdfs:label "Gandhi"@en ;
#     ns1:director <http://philip-broehl.org/resource/richard_attenborough> ;
#     xsd:gYear "1982" .
#
# <http://philip-broehl.org/resource/gladiator> a ns1:Film ;
#     rdfs:label "Gladiator"@en ;
#     ns1:director <http://philip-broehl.org/resource/ridley_scott> ;
#     xsd:gYear "2000" .
#
# <http://philip-broehl.org/resource/gone_girl> a ns1:Film ;
#     rdfs:label "Gone Girl"@en ;
#     ns1:director <http://philip-broehl.org/resource/david_fincher> ;
#     xsd:gYear "2014" .
#
# <http://philip-broehl.org/resource/gone_with_the_wind> a ns1:Film ;
#     rdfs:label "Gone with the Wind"@en ;
#     ns1:director <http://philip-broehl.org/resource/george_cukor>,
#         <http://philip-broehl.org/resource/sam_wood>,
#         <http://philip-broehl.org/resource/victor_fleming> ;
#     xsd:gYear "1939" .
#
# <http://philip-broehl.org/resource/good_will_hunting> a ns1:Film ;
#     rdfs:label "Good Will Hunting"@en ;
#     ns1:director <http://philip-broehl.org/resource/gus_van_sant> ;
#     xsd:gYear "1997" .
#
# <http://philip-broehl.org/resource/goodfellas> a ns1:Film ;
#     rdfs:label "Goodfellas"@en ;
#     ns1:director <http://philip-broehl.org/resource/martin_scorsese> ;
#     xsd:gYear "1990" .
#
# <http://philip-broehl.org/resource/gran_torino> a ns1:Film ;
#     rdfs:label "Gran Torino"@en ;
#     ns1:director <http://philip-broehl.org/resource/clint_eastwood> ;
#     xsd:gYear "2008" .
#
# <http://philip-broehl.org/resource/groundhog_day> a ns1:Film ;
#     rdfs:label "Groundhog Day"@en ;
#     ns1:director <http://philip-broehl.org/resource/harold_ramis> ;
#     xsd:gYear "1993" .
#
# <http://philip-broehl.org/resource/guardians_of_the_galaxy> a ns1:Film ;
#     rdfs:label "Guardians of the Galaxy"@en ;
#     ns1:director <http://philip-broehl.org/resource/james_gunn> ;
#     xsd:gYear "2014" .
#
# <http://philip-broehl.org/resource/guardians_of_the_galaxy_vol._2> a ns1:Film ;
#     rdfs:label "Guardians of the Galaxy Vol. 2"@en ;
#     ns1:director <http://philip-broehl.org/resource/james_gunn> ;
#     xsd:gYear "2017" .
#
# <http://philip-broehl.org/resource/hachi:_a_dog's_tale> a ns1:Film ;
#     rdfs:label "Hachi: A Dog's Tale"@en ;
#     ns1:director <http://philip-broehl.org/resource/lasse_hallstrã¶m> ;
#     xsd:gYear "2009" .
#
# <http://philip-broehl.org/resource/hacksaw_ridge> a ns1:Film ;
#     rdfs:label "Hacksaw Ridge"@en ;
#     ns1:director <http://philip-broehl.org/resource/mel_gibson> ;
#     xsd:gYear "2016" .
#
# <http://philip-broehl.org/resource/harry_potter_and_the_deathly_hallows:_part_2> a ns1:Film ;
#     rdfs:label "Harry Potter and the Deathly Hallows: Part 2"@en ;
#     ns1:director <http://philip-broehl.org/resource/david_yates> ;
#     xsd:gYear "2011" .
#
# <http://philip-broehl.org/resource/harvey> a ns1:Film ;
#     rdfs:label "Harvey"@en ;
#     ns1:director <http://philip-broehl.org/resource/henry_koster> ;
#     xsd:gYear "1950" .
#
# <http://philip-broehl.org/resource/heat> a ns1:Film ;
#     rdfs:label "Heat"@en ;
#     ns1:director <http://philip-broehl.org/resource/michael_mann> ;
#     xsd:gYear "1995" .
#
# <http://philip-broehl.org/resource/high_noon> a ns1:Film ;
#     rdfs:label "High Noon"@en ;
#     ns1:director <http://philip-broehl.org/resource/fred_zinnemann> ;
#     xsd:gYear "1952" .
#
# <http://philip-broehl.org/resource/his_girl_friday> a ns1:Film ;
#     rdfs:label "His Girl Friday"@en ;
#     ns1:director <http://philip-broehl.org/resource/howard_hawks> ;
#     xsd:gYear "1940" .
#
# <http://philip-broehl.org/resource/hotel_rwanda> a ns1:Film ;
#     rdfs:label "Hotel Rwanda"@en ;
#     ns1:director <http://philip-broehl.org/resource/terry_george> ;
#     xsd:gYear "2004" .
#
# <http://philip-broehl.org/resource/how_to_train_your_dragon> a ns1:Film ;
#     rdfs:label "How to Train Your Dragon"@en ;
#     ns1:director <http://philip-broehl.org/resource/chris_sanders>,
#         <http://philip-broehl.org/resource/dean_deblois> ;
#     xsd:gYear "2010" .
#
# <http://philip-broehl.org/resource/in_the_name_of_the_father> a ns1:Film ;
#     rdfs:label "In the Name of the Father"@en ;
#     ns1:director <http://philip-broehl.org/resource/jim_sheridan> ;
#     xsd:gYear "1993" .
#
# <http://philip-broehl.org/resource/inception> a ns1:Film ;
#     rdfs:label "Inception"@en ;
#     ns1:director <http://philip-broehl.org/resource/christopher_nolan> ;
#     xsd:gYear "2010" .
#
# <http://philip-broehl.org/resource/indiana_jones_and_the_last_crusade> a ns1:Film ;
#     rdfs:label "Indiana Jones and the Last Crusade"@en ;
#     ns1:director <http://philip-broehl.org/resource/steven_spielberg> ;
#     xsd:gYear "1989" .
#
# <http://philip-broehl.org/resource/inglourious_basterds> a ns1:Film ;
#     rdfs:label "Inglourious Basterds"@en ;
#     ns1:director <http://philip-broehl.org/resource/eli_roth>,
#         <http://philip-broehl.org/resource/quentin_tarantino> ;
#     xsd:gYear "2009" .
#
# <http://philip-broehl.org/resource/inside_out> a ns1:Film ;
#     rdfs:label "Inside Out"@en ;
#     ns1:director <http://philip-broehl.org/resource/pete_docter>,
#         <http://philip-broehl.org/resource/ronnie_del_carmen> ;
#     xsd:gYear "2015" .
#
# <http://philip-broehl.org/resource/interstellar> a ns1:Film ;
#     rdfs:label "Interstellar"@en ;
#     ns1:director <http://philip-broehl.org/resource/christopher_nolan> ;
#     xsd:gYear "2014" .
#
# <http://philip-broehl.org/resource/into_the_wild> a ns1:Film ;
#     rdfs:label "Into the Wild"@en ;
#     ns1:director <http://philip-broehl.org/resource/sean_penn> ;
#     xsd:gYear "2007" .
#
# <http://philip-broehl.org/resource/it's_a_wonderful_life> a ns1:Film ;
#     rdfs:label "It's a Wonderful Life"@en ;
#     ns1:director <http://philip-broehl.org/resource/frank_capra> ;
#     xsd:gYear "1946" .
#
# <http://philip-broehl.org/resource/it_happened_one_night> a ns1:Film ;
#     rdfs:label "It Happened One Night"@en ;
#     ns1:director <http://philip-broehl.org/resource/frank_capra> ;
#     xsd:gYear "1934" .
#
# <http://philip-broehl.org/resource/jaws> a ns1:Film ;
#     rdfs:label "Jaws"@en ;
#     ns1:director <http://philip-broehl.org/resource/steven_spielberg> ;
#     xsd:gYear "1975" .
#
# <http://philip-broehl.org/resource/jfk> a ns1:Film ;
#     rdfs:label "JFK"@en ;
#     ns1:director <http://philip-broehl.org/resource/oliver_stone> ;
#     xsd:gYear "1991" .
#
# <http://philip-broehl.org/resource/judgment_at_nuremberg> a ns1:Film ;
#     rdfs:label "Judgment at Nuremberg"@en ;
#     ns1:director <http://philip-broehl.org/resource/stanley_kramer> ;
#     xsd:gYear "1961" .
#
# <http://philip-broehl.org/resource/jurassic_park> a ns1:Film ;
#     rdfs:label "Jurassic Park"@en ;
#     ns1:director <http://philip-broehl.org/resource/steven_spielberg> ;
#     xsd:gYear "1993" .
#
# <http://philip-broehl.org/resource/kill_bill:_vol._1> a ns1:Film ;
#     rdfs:label "Kill Bill: Vol. 1"@en ;
#     ns1:director <http://philip-broehl.org/resource/quentin_tarantino> ;
#     xsd:gYear "2003" .
#
# <http://philip-broehl.org/resource/kind_hearts_and_coronets> a ns1:Film ;
#     rdfs:label "Kind Hearts and Coronets"@en ;
#     ns1:director <http://philip-broehl.org/resource/robert_hamer> ;
#     xsd:gYear "1949" .
#
# <http://philip-broehl.org/resource/l.a._confidential> a ns1:Film ;
#     rdfs:label "L.A. Confidential"@en ;
#     ns1:director <http://philip-broehl.org/resource/curtis_hanson> ;
#     xsd:gYear "1997" .
#
# <http://philip-broehl.org/resource/la_la_land> a ns1:Film ;
#     rdfs:label "La La Land"@en ;
#     ns1:director <http://philip-broehl.org/resource/damien_chazelle> ;
#     xsd:gYear "2016" .
#
# <http://philip-broehl.org/resource/laura> a ns1:Film ;
#     rdfs:label "Laura"@en ;
#     ns1:director <http://philip-broehl.org/resource/otto_preminger> ;
#     xsd:gYear "1944" .
#
# <http://philip-broehl.org/resource/lawrence_of_arabia> a ns1:Film ;
#     rdfs:label "Lawrence of Arabia"@en ;
#     ns1:director <http://philip-broehl.org/resource/david_lean> ;
#     xsd:gYear "1962" .
#
# <http://philip-broehl.org/resource/life_of_brian> a ns1:Film ;
#     rdfs:label "Life of Brian"@en ;
#     ns1:director <http://philip-broehl.org/resource/terry_jones> ;
#     xsd:gYear "1979" .
#
# <http://philip-broehl.org/resource/lion> a ns1:Film ;
#     rdfs:label "Lion"@en ;
#     ns1:director <http://philip-broehl.org/resource/garth_davis> ;
#     xsd:gYear "2016" .
#
# <http://philip-broehl.org/resource/lock,_stock_and_two_smoking_barrels> a ns1:Film ;
#     rdfs:label "Lock, Stock and Two Smoking Barrels"@en ;
#     ns1:director <http://philip-broehl.org/resource/guy_ritchie> ;
#     xsd:gYear "1998" .
#
# <http://philip-broehl.org/resource/logan> a ns1:Film ;
#     rdfs:label "Logan"@en ;
#     ns1:director <http://philip-broehl.org/resource/james_mangold> ;
#     xsd:gYear "2017" .
#
# <http://philip-broehl.org/resource/lã©on:_the_professional> a ns1:Film ;
#     rdfs:label "LÃ©on: The Professional"@en ;
#     ns1:director <http://philip-broehl.org/resource/luc_besson> ;
#     xsd:gYear "1994" .
#
# <http://philip-broehl.org/resource/mad_max:_fury_road> a ns1:Film ;
#     rdfs:label "Mad Max: Fury Road"@en ;
#     ns1:director <http://philip-broehl.org/resource/george_miller> ;
#     xsd:gYear "2015" .
#
# <http://philip-broehl.org/resource/magnolia> a ns1:Film ;
#     rdfs:label "Magnolia"@en ;
#     ns1:director <http://philip-broehl.org/resource/paul_thomas_anderson> ;
#     xsd:gYear "1999" .
#
# <http://philip-broehl.org/resource/mary_and_max> a ns1:Film ;
#     rdfs:label "Mary and Max"@en ;
#     ns1:director <http://philip-broehl.org/resource/adam_elliot> ;
#     xsd:gYear "2009" .
#
# <http://philip-broehl.org/resource/memento> a ns1:Film ;
#     rdfs:label "Memento"@en ;
#     ns1:director <http://philip-broehl.org/resource/christopher_nolan> ;
#     xsd:gYear "2000" .
#
# <http://philip-broehl.org/resource/million_dollar_baby> a ns1:Film ;
#     rdfs:label "Million Dollar Baby"@en ;
#     ns1:director <http://philip-broehl.org/resource/clint_eastwood> ;
#     xsd:gYear "2004" .
#
# <http://philip-broehl.org/resource/modern_times> a ns1:Film ;
#     rdfs:label "Modern Times"@en ;
#     ns1:director <http://philip-broehl.org/resource/charles_chaplin> ;
#     xsd:gYear "1936" .
#
# <http://philip-broehl.org/resource/monsters,_inc.> a ns1:Film ;
#     rdfs:label "Monsters, Inc."@en ;
#     ns1:director <http://philip-broehl.org/resource/david_silverman>,
#         <http://philip-broehl.org/resource/lee_unkrich>,
#         <http://philip-broehl.org/resource/pete_docter> ;
#     xsd:gYear "2001" .
#
# <http://philip-broehl.org/resource/monty_python_and_the_holy_grail> a ns1:Film ;
#     rdfs:label "Monty Python and the Holy Grail"@en ;
#     ns1:director <http://philip-broehl.org/resource/terry_gilliam>,
#         <http://philip-broehl.org/resource/terry_jones> ;
#     xsd:gYear "1975" .
#
# <http://philip-broehl.org/resource/mr._smith_goes_to_washington> a ns1:Film ;
#     rdfs:label "Mr. Smith Goes to Washington"@en ;
#     ns1:director <http://philip-broehl.org/resource/frank_capra> ;
#     xsd:gYear "1939" .
#
# <http://philip-broehl.org/resource/network> a ns1:Film ;
#     rdfs:label "Network"@en ;
#     ns1:director <http://philip-broehl.org/resource/sidney_lumet> ;
#     xsd:gYear "1976" .
#
# <http://philip-broehl.org/resource/no_country_for_old_men> a ns1:Film ;
#     rdfs:label "No Country for Old Men"@en ;
#     ns1:director <http://philip-broehl.org/resource/ethan_coen>,
#         <http://philip-broehl.org/resource/joel_coen> ;
#     xsd:gYear "2007" .
#
# <http://philip-broehl.org/resource/north_by_northwest> a ns1:Film ;
#     rdfs:label "North by Northwest"@en ;
#     ns1:director <http://philip-broehl.org/resource/alfred_hitchcock> ;
#     xsd:gYear "1959" .
#
# <http://philip-broehl.org/resource/notorious> a ns1:Film ;
#     rdfs:label "Notorious"@en ;
#     ns1:director <http://philip-broehl.org/resource/alfred_hitchcock> ;
#     xsd:gYear "1946" .
#
# <http://philip-broehl.org/resource/on_the_waterfront> a ns1:Film ;
#     rdfs:label "On the Waterfront"@en ;
#     ns1:director <http://philip-broehl.org/resource/elia_kazan> ;
#     xsd:gYear "1954" .
#
# <http://philip-broehl.org/resource/once_upon_a_time_in_america> a ns1:Film ;
#     rdfs:label "Once Upon a Time in America"@en ;
#     ns1:director <http://philip-broehl.org/resource/sergio_leone> ;
#     xsd:gYear "1984" .
#
# <http://philip-broehl.org/resource/one_flew_over_the_cuckoo's_nest> a ns1:Film ;
#     rdfs:label "One Flew Over the Cuckoo's Nest"@en ;
#     ns1:director <http://philip-broehl.org/resource/milos_forman> ;
#     xsd:gYear "1975" .
#
# <http://philip-broehl.org/resource/out_of_the_past> a ns1:Film ;
#     rdfs:label "Out of the Past"@en ;
#     ns1:director <http://philip-broehl.org/resource/jacques_tourneur> ;
#     xsd:gYear "1947" .
#
# <http://philip-broehl.org/resource/papillon> a ns1:Film ;
#     rdfs:label "Papillon"@en ;
#     ns1:director <http://philip-broehl.org/resource/franklin_j._schaffner> ;
#     xsd:gYear "1973" .
#
# <http://philip-broehl.org/resource/paris,_texas> a ns1:Film ;
#     rdfs:label "Paris, Texas"@en ;
#     ns1:director <http://philip-broehl.org/resource/wim_wenders> ;
#     xsd:gYear "1984" .
#
# <http://philip-broehl.org/resource/paths_of_glory> a ns1:Film ;
#     rdfs:label "Paths of Glory"@en ;
#     ns1:director <http://philip-broehl.org/resource/stanley_kubrick> ;
#     xsd:gYear "1957" .
#
# <http://philip-broehl.org/resource/patton> a ns1:Film ;
#     rdfs:label "Patton"@en ;
#     ns1:director <http://philip-broehl.org/resource/franklin_j._schaffner> ;
#     xsd:gYear "1970" .
#
# <http://philip-broehl.org/resource/pink_floyd:_the_wall> a ns1:Film ;
#     rdfs:label "Pink Floyd: The Wall"@en ;
#     ns1:director <http://philip-broehl.org/resource/alan_parker> ;
#     xsd:gYear "1982" .
#
# <http://philip-broehl.org/resource/pirates_of_the_caribbean:_the_curse_of_the_black_pearl> a ns1:Film ;
#     rdfs:label "Pirates of the Caribbean: The Curse of the Black Pearl"@en ;
#     ns1:director <http://philip-broehl.org/resource/gore_verbinski> ;
#     xsd:gYear "2003" .
#
# <http://philip-broehl.org/resource/platoon> a ns1:Film ;
#     rdfs:label "Platoon"@en ;
#     ns1:director <http://philip-broehl.org/resource/oliver_stone> ;
#     xsd:gYear "1986" .
#
# <http://philip-broehl.org/resource/prisoners> a ns1:Film ;
#     rdfs:label "Prisoners"@en ;
#     ns1:director <http://philip-broehl.org/resource/denis_villeneuve> ;
#     xsd:gYear "2013" .
#
# <http://philip-broehl.org/resource/psycho> a ns1:Film ;
#     rdfs:label "Psycho"@en ;
#     ns1:director <http://philip-broehl.org/resource/alfred_hitchcock> ;
#     xsd:gYear "1960" .
#
# <http://philip-broehl.org/resource/pulp_fiction> a ns1:Film ;
#     rdfs:label "Pulp Fiction"@en ;
#     ns1:director <http://philip-broehl.org/resource/quentin_tarantino> ;
#     xsd:gYear "1994" .
#
# <http://philip-broehl.org/resource/raging_bull> a ns1:Film ;
#     rdfs:label "Raging Bull"@en ;
#     ns1:director <http://philip-broehl.org/resource/martin_scorsese> ;
#     xsd:gYear "1980" .
#
# <http://philip-broehl.org/resource/raiders_of_the_lost_ark> a ns1:Film ;
#     rdfs:label "Raiders of the Lost Ark"@en ;
#     ns1:director <http://philip-broehl.org/resource/steven_spielberg> ;
#     xsd:gYear "1981" .
#
# <http://philip-broehl.org/resource/rain_man> a ns1:Film ;
#     rdfs:label "Rain Man"@en ;
#     ns1:director <http://philip-broehl.org/resource/barry_levinson> ;
#     xsd:gYear "1988" .
#
# <http://philip-broehl.org/resource/rear_window> a ns1:Film ;
#     rdfs:label "Rear Window"@en ;
#     ns1:director <http://philip-broehl.org/resource/alfred_hitchcock> ;
#     xsd:gYear "1954" .
#
# <http://philip-broehl.org/resource/rebecca> a ns1:Film ;
#     rdfs:label "Rebecca"@en ;
#     ns1:director <http://philip-broehl.org/resource/alfred_hitchcock> ;
#     xsd:gYear "1940" .
#
# <http://philip-broehl.org/resource/requiem_for_a_dream> a ns1:Film ;
#     rdfs:label "Requiem for a Dream"@en ;
#     ns1:director <http://philip-broehl.org/resource/darren_aronofsky> ;
#     xsd:gYear "2000" .
#
# <http://philip-broehl.org/resource/reservoir_dogs> a ns1:Film ;
#     rdfs:label "Reservoir Dogs"@en ;
#     ns1:director <http://philip-broehl.org/resource/quentin_tarantino> ;
#     xsd:gYear "1992" .
#
# <http://philip-broehl.org/resource/rio_bravo> a ns1:Film ;
#     rdfs:label "Rio Bravo"@en ;
#     ns1:director <http://philip-broehl.org/resource/howard_hawks> ;
#     xsd:gYear "1959" .
#
# <http://philip-broehl.org/resource/rocky> a ns1:Film ;
#     rdfs:label "Rocky"@en ;
#     ns1:director <http://philip-broehl.org/resource/john_g._avildsen> ;
#     xsd:gYear "1976" .
#
# <http://philip-broehl.org/resource/roman_holiday> a ns1:Film ;
#     rdfs:label "Roman Holiday"@en ;
#     ns1:director <http://philip-broehl.org/resource/william_wyler> ;
#     xsd:gYear "1953" .
#
# <http://philip-broehl.org/resource/room> a ns1:Film ;
#     rdfs:label "Room"@en ;
#     ns1:director <http://philip-broehl.org/resource/lenny_abrahamson> ;
#     xsd:gYear "2015" .
#
# <http://philip-broehl.org/resource/rope> a ns1:Film ;
#     rdfs:label "Rope"@en ;
#     ns1:director <http://philip-broehl.org/resource/alfred_hitchcock> ;
#     xsd:gYear "1948" .
#
# <http://philip-broehl.org/resource/rush> a ns1:Film ;
#     rdfs:label "Rush"@en ;
#     ns1:director <http://philip-broehl.org/resource/ron_howard> ;
#     xsd:gYear "2013" .
#
# <http://philip-broehl.org/resource/saving_private_ryan> a ns1:Film ;
#     rdfs:label "Saving Private Ryan"@en ;
#     ns1:director <http://philip-broehl.org/resource/steven_spielberg> ;
#     xsd:gYear "1998" .
#
# <http://philip-broehl.org/resource/scarface> a ns1:Film ;
#     rdfs:label "Scarface"@en ;
#     ns1:director <http://philip-broehl.org/resource/brian_de_palma> ;
#     xsd:gYear "1983" .
#
# <http://philip-broehl.org/resource/schindler's_list> a ns1:Film ;
#     rdfs:label "Schindler's List"@en ;
#     ns1:director <http://philip-broehl.org/resource/steven_spielberg> ;
#     xsd:gYear "1993" .
#
# <http://philip-broehl.org/resource/se7en> a ns1:Film ;
#     rdfs:label "Se7en"@en ;
#     ns1:director <http://philip-broehl.org/resource/david_fincher> ;
#     xsd:gYear "1995" .
#
# <http://philip-broehl.org/resource/short_term_12> a ns1:Film ;
#     rdfs:label "Short Term 12"@en ;
#     ns1:director <http://philip-broehl.org/resource/destin_daniel_cretton> ;
#     xsd:gYear "2013" .
#
# <http://philip-broehl.org/resource/shutter_island> a ns1:Film ;
#     rdfs:label "Shutter Island"@en ;
#     ns1:director <http://philip-broehl.org/resource/martin_scorsese> ;
#     xsd:gYear "2010" .
#
# <http://philip-broehl.org/resource/sin_city> a ns1:Film ;
#     rdfs:label "Sin City"@en ;
#     ns1:director <http://philip-broehl.org/resource/frank_miller>,
#         <http://philip-broehl.org/resource/quentin_tarantino>,
#         <http://philip-broehl.org/resource/robert_rodriguez> ;
#     xsd:gYear "2005" .
#
# <http://philip-broehl.org/resource/singin'_in_the_rain> a ns1:Film ;
#     rdfs:label "Singin' in the Rain"@en ;
#     ns1:director <http://philip-broehl.org/resource/gene_kelly>,
#         <http://philip-broehl.org/resource/stanley_donen> ;
#     xsd:gYear "1952" .
#
# <http://philip-broehl.org/resource/sleuth> a ns1:Film ;
#     rdfs:label "Sleuth"@en ;
#     ns1:director <http://philip-broehl.org/resource/joseph_l._mankiewicz> ;
#     xsd:gYear "1972" .
#
# <http://philip-broehl.org/resource/sling_blade> a ns1:Film ;
#     rdfs:label "Sling Blade"@en ;
#     ns1:director <http://philip-broehl.org/resource/billy_bob_thornton> ;
#     xsd:gYear "1996" .
#
# <http://philip-broehl.org/resource/slumdog_millionaire> a ns1:Film ;
#     rdfs:label "Slumdog Millionaire"@en ;
#     ns1:director <http://philip-broehl.org/resource/danny_boyle>,
#         <http://philip-broehl.org/resource/loveleen_tandan> ;
#     xsd:gYear "2008" .
#
# <http://philip-broehl.org/resource/snatch> a ns1:Film ;
#     rdfs:label "Snatch"@en ;
#     ns1:director <http://philip-broehl.org/resource/guy_ritchie> ;
#     xsd:gYear "2000" .
#
# <http://philip-broehl.org/resource/some_like_it_hot> a ns1:Film ;
#     rdfs:label "Some Like It Hot"@en ;
#     ns1:director <http://philip-broehl.org/resource/billy_wilder> ;
#     xsd:gYear "1959" .
#
# <http://philip-broehl.org/resource/song_of_the_sea> a ns1:Film ;
#     rdfs:label "Song of the Sea"@en ;
#     ns1:director <http://philip-broehl.org/resource/tomm_moore> ;
#     xsd:gYear "2014" .
#
# <http://philip-broehl.org/resource/spider-man:_homecoming> a ns1:Film ;
#     rdfs:label "Spider-Man: Homecoming"@en ;
#     ns1:director <http://philip-broehl.org/resource/jon_watts> ;
#     xsd:gYear "2017" .
#
# <http://philip-broehl.org/resource/spotlight> a ns1:Film ;
#     rdfs:label "Spotlight"@en ;
#     ns1:director <http://philip-broehl.org/resource/tom_mccarthy> ;
#     xsd:gYear "2015" .
#
# <http://philip-broehl.org/resource/stalag_17> a ns1:Film ;
#     rdfs:label "Stalag 17"@en ;
#     ns1:director <http://philip-broehl.org/resource/billy_wilder> ;
#     xsd:gYear "1953" .
#
# <http://philip-broehl.org/resource/stand_by_me> a ns1:Film ;
#     rdfs:label "Stand by Me"@en ;
#     ns1:director <http://philip-broehl.org/resource/rob_reiner> ;
#     xsd:gYear "1986" .
#
# <http://philip-broehl.org/resource/star_wars:_episode_iv_-_a_new_hope> a ns1:Film ;
#     rdfs:label "Star Wars: Episode IV - A New Hope"@en ;
#     ns1:director <http://philip-broehl.org/resource/george_lucas> ;
#     xsd:gYear "1977" .
#
# <http://philip-broehl.org/resource/star_wars:_episode_v_-_the_empire_strikes_back> a ns1:Film ;
#     rdfs:label "Star Wars: Episode V - The Empire Strikes Back"@en ;
#     ns1:director <http://philip-broehl.org/resource/irvin_kershner> ;
#     xsd:gYear "1980" .
#
# <http://philip-broehl.org/resource/star_wars:_episode_vi_-_return_of_the_jedi> a ns1:Film ;
#     rdfs:label "Star Wars: Episode VI - Return of the Jedi"@en ;
#     ns1:director <http://philip-broehl.org/resource/richard_marquand> ;
#     xsd:gYear "1983" .
#
# <http://philip-broehl.org/resource/star_wars:_the_force_awakens> a ns1:Film ;
#     rdfs:label "Star Wars: The Force Awakens"@en ;
#     ns1:director <http://philip-broehl.org/resource/j.j._abrams> ;
#     xsd:gYear "2015" .
#
# <http://philip-broehl.org/resource/strangers_on_a_train> a ns1:Film ;
#     rdfs:label "Strangers on a Train"@en ;
#     ns1:director <http://philip-broehl.org/resource/alfred_hitchcock> ;
#     xsd:gYear "1951" .
#
# <http://philip-broehl.org/resource/sunset_boulevard> a ns1:Film ;
#     rdfs:label "Sunset Boulevard"@en ;
#     ns1:director <http://philip-broehl.org/resource/billy_wilder> ;
#     xsd:gYear "1950" .
#
# <http://philip-broehl.org/resource/taxi_driver> a ns1:Film ;
#     rdfs:label "Taxi Driver"@en ;
#     ns1:director <http://philip-broehl.org/resource/martin_scorsese> ;
#     xsd:gYear "1976" .
#
# <http://philip-broehl.org/resource/terminator_2:_judgment_day> a ns1:Film ;
#     rdfs:label "Terminator 2: Judgment Day"@en ;
#     ns1:director <http://philip-broehl.org/resource/james_cameron> ;
#     xsd:gYear "1991" .
#
# <http://philip-broehl.org/resource/the_apartment> a ns1:Film ;
#     rdfs:label "The Apartment"@en ;
#     ns1:director <http://philip-broehl.org/resource/billy_wilder> ;
#     xsd:gYear "1960" .
#
# <http://philip-broehl.org/resource/the_avengers> a ns1:Film ;
#     rdfs:label "The Avengers"@en ;
#     ns1:director <http://philip-broehl.org/resource/joss_whedon> ;
#     xsd:gYear "2012" .
#
# <http://philip-broehl.org/resource/the_best_years_of_our_lives> a ns1:Film ;
#     rdfs:label "The Best Years of Our Lives"@en ;
#     ns1:director <http://philip-broehl.org/resource/william_wyler> ;
#     xsd:gYear "1946" .
#
# <http://philip-broehl.org/resource/the_big_lebowski> a ns1:Film ;
#     rdfs:label "The Big Lebowski"@en ;
#     ns1:director <http://philip-broehl.org/resource/ethan_coen>,
#         <http://philip-broehl.org/resource/joel_coen> ;
#     xsd:gYear "1998" .
#
# <http://philip-broehl.org/resource/the_big_sleep> a ns1:Film ;
#     rdfs:label "The Big Sleep"@en ;
#     ns1:director <http://philip-broehl.org/resource/howard_hawks> ;
#     xsd:gYear "1946" .
#
# <http://philip-broehl.org/resource/the_bourne_ultimatum> a ns1:Film ;
#     rdfs:label "The Bourne Ultimatum"@en ;
#     ns1:director <http://philip-broehl.org/resource/paul_greengrass> ;
#     xsd:gYear "2007" .
#
# <http://philip-broehl.org/resource/the_bridge_on_the_river_kwai> a ns1:Film ;
#     rdfs:label "The Bridge on the River Kwai"@en ;
#     ns1:director <http://philip-broehl.org/resource/david_lean> ;
#     xsd:gYear "1957" .
#
# <http://philip-broehl.org/resource/the_dark_knight> a ns1:Film ;
#     rdfs:label "The Dark Knight"@en ;
#     ns1:director <http://philip-broehl.org/resource/christopher_nolan> ;
#     xsd:gYear "2008" .
#
# <http://philip-broehl.org/resource/the_dark_knight_rises> a ns1:Film ;
#     rdfs:label "The Dark Knight Rises"@en ;
#     ns1:director <http://philip-broehl.org/resource/christopher_nolan> ;
#     xsd:gYear "2012" .
#
# <http://philip-broehl.org/resource/the_deer_hunter> a ns1:Film ;
#     rdfs:label "The Deer Hunter"@en ;
#     ns1:director <http://philip-broehl.org/resource/michael_cimino> ;
#     xsd:gYear "1978" .
#
# <http://philip-broehl.org/resource/the_departed> a ns1:Film ;
#     rdfs:label "The Departed"@en ;
#     ns1:director <http://philip-broehl.org/resource/martin_scorsese> ;
#     xsd:gYear "2006" .
#
# <http://philip-broehl.org/resource/the_elephant_man> a ns1:Film ;
#     rdfs:label "The Elephant Man"@en ;
#     ns1:director <http://philip-broehl.org/resource/david_lynch> ;
#     xsd:gYear "1980" .
#
# <http://philip-broehl.org/resource/the_exorcist> a ns1:Film ;
#     rdfs:label "The Exorcist"@en ;
#     ns1:director <http://philip-broehl.org/resource/william_friedkin> ;
#     xsd:gYear "1973" .
#
# <http://philip-broehl.org/resource/the_general> a ns1:Film ;
#     rdfs:label "The General"@en ;
#     ns1:director <http://philip-broehl.org/resource/buster_keaton>,
#         <http://philip-broehl.org/resource/clyde_bruckman> ;
#     xsd:gYear "1926" .
#
# <http://philip-broehl.org/resource/the_godfather> a ns1:Film ;
#     rdfs:label "The Godfather"@en ;
#     ns1:director <http://philip-broehl.org/resource/francis_ford_coppola> ;
#     xsd:gYear "1972" .
#
# <http://philip-broehl.org/resource/the_godfather:_part_ii> a ns1:Film ;
#     rdfs:label "The Godfather: Part II"@en ;
#     ns1:director <http://philip-broehl.org/resource/francis_ford_coppola> ;
#     xsd:gYear "1974" .
#
# <http://philip-broehl.org/resource/the_gold_rush> a ns1:Film ;
#     rdfs:label "The Gold Rush"@en ;
#     ns1:director <http://philip-broehl.org/resource/charles_chaplin> ;
#     xsd:gYear "1925" .
#
# <http://philip-broehl.org/resource/the_graduate> a ns1:Film ;
#     rdfs:label "The Graduate"@en ;
#     ns1:director <http://philip-broehl.org/resource/mike_nichols> ;
#     xsd:gYear "1967" .
#
# <http://philip-broehl.org/resource/the_grand_budapest_hotel> a ns1:Film ;
#     rdfs:label "The Grand Budapest Hotel"@en ;
#     ns1:director <http://philip-broehl.org/resource/wes_anderson> ;
#     xsd:gYear "2014" .
#
# <http://philip-broehl.org/resource/the_grapes_of_wrath> a ns1:Film ;
#     rdfs:label "The Grapes of Wrath"@en ;
#     ns1:director <http://philip-broehl.org/resource/john_ford> ;
#     xsd:gYear "1940" .
#
# <http://philip-broehl.org/resource/the_great_dictator> a ns1:Film ;
#     rdfs:label "The Great Dictator"@en ;
#     ns1:director <http://philip-broehl.org/resource/charles_chaplin> ;
#     xsd:gYear "1940" .
#
# <http://philip-broehl.org/resource/the_great_escape> a ns1:Film ;
#     rdfs:label "The Great Escape"@en ;
#     ns1:director <http://philip-broehl.org/resource/john_sturges> ;
#     xsd:gYear "1963" .
#
# <http://philip-broehl.org/resource/the_green_mile> a ns1:Film ;
#     rdfs:label "The Green Mile"@en ;
#     ns1:director <http://philip-broehl.org/resource/frank_darabont> ;
#     xsd:gYear "1999" .
#
# <http://philip-broehl.org/resource/the_help> a ns1:Film ;
#     rdfs:label "The Help"@en ;
#     ns1:director <http://philip-broehl.org/resource/tate_taylor> ;
#     xsd:gYear "2011" .
#
# <http://philip-broehl.org/resource/the_hustler> a ns1:Film ;
#     rdfs:label "The Hustler"@en ;
#     ns1:director <http://philip-broehl.org/resource/robert_rossen> ;
#     xsd:gYear "1961" .
#
# <http://philip-broehl.org/resource/the_imitation_game> a ns1:Film ;
#     rdfs:label "The Imitation Game"@en ;
#     ns1:director <http://philip-broehl.org/resource/morten_tyldum> ;
#     xsd:gYear "2014" .
#
# <http://philip-broehl.org/resource/the_kid> a ns1:Film ;
#     rdfs:label "The Kid"@en ;
#     ns1:director <http://philip-broehl.org/resource/charles_chaplin> ;
#     xsd:gYear "1921" .
#
# <http://philip-broehl.org/resource/the_killing> a ns1:Film ;
#     rdfs:label "The Killing"@en ;
#     ns1:director <http://philip-broehl.org/resource/stanley_kubrick> ;
#     xsd:gYear "1956" .
#
# <http://philip-broehl.org/resource/the_king's_speech> a ns1:Film ;
#     rdfs:label "The King's Speech"@en ;
#     ns1:director <http://philip-broehl.org/resource/tom_hooper> ;
#     xsd:gYear "2010" .
#
# <http://philip-broehl.org/resource/the_last_picture_show> a ns1:Film ;
#     rdfs:label "The Last Picture Show"@en ;
#     ns1:director <http://philip-broehl.org/resource/peter_bogdanovich> ;
#     xsd:gYear "1971" .
#
# <http://philip-broehl.org/resource/the_legend_of_1900> a ns1:Film ;
#     rdfs:label "The Legend of 1900"@en ;
#     ns1:director <http://philip-broehl.org/resource/giuseppe_tornatore> ;
#     xsd:gYear "1998" .
#
# <http://philip-broehl.org/resource/the_lion_king> a ns1:Film ;
#     rdfs:label "The Lion King"@en ;
#     ns1:director <http://philip-broehl.org/resource/rob_minkoff>,
#         <http://philip-broehl.org/resource/roger_allers> ;
#     xsd:gYear "1994" .
#
# <http://philip-broehl.org/resource/the_lord_of_the_rings:_the_fellowship_of_the_ring> a ns1:Film ;
#     rdfs:label "The Lord of the Rings: The Fellowship of the Ring"@en ;
#     ns1:director <http://philip-broehl.org/resource/peter_jackson> ;
#     xsd:gYear "2001" .
#
# <http://philip-broehl.org/resource/the_lord_of_the_rings:_the_return_of_the_king> a ns1:Film ;
#     rdfs:label "The Lord of the Rings: The Return of the King"@en ;
#     ns1:director <http://philip-broehl.org/resource/peter_jackson> ;
#     xsd:gYear "2003" .
#
# <http://philip-broehl.org/resource/the_lord_of_the_rings:_the_two_towers> a ns1:Film ;
#     rdfs:label "The Lord of the Rings: The Two Towers"@en ;
#     ns1:director <http://philip-broehl.org/resource/peter_jackson> ;
#     xsd:gYear "2002" .
#
# <http://philip-broehl.org/resource/the_lost_weekend> a ns1:Film ;
#     rdfs:label "The Lost Weekend"@en ;
#     ns1:director <http://philip-broehl.org/resource/billy_wilder> ;
#     xsd:gYear "1945" .
#
# <http://philip-broehl.org/resource/the_maltese_falcon> a ns1:Film ;
#     rdfs:label "The Maltese Falcon"@en ;
#     ns1:director <http://philip-broehl.org/resource/john_huston> ;
#     xsd:gYear "1941" .
#
# <http://philip-broehl.org/resource/the_man_who_shot_liberty_valance> a ns1:Film ;
#     rdfs:label "The Man Who Shot Liberty Valance"@en ;
#     ns1:director <http://philip-broehl.org/resource/john_ford> ;
#     xsd:gYear "1962" .
#
# <http://philip-broehl.org/resource/the_manchurian_candidate> a ns1:Film ;
#     rdfs:label "The Manchurian Candidate"@en ;
#     ns1:director <http://philip-broehl.org/resource/john_frankenheimer> ;
#     xsd:gYear "1962" .
#
# <http://philip-broehl.org/resource/the_martian> a ns1:Film ;
#     rdfs:label "The Martian"@en ;
#     ns1:director <http://philip-broehl.org/resource/ridley_scott> ;
#     xsd:gYear "2015" .
#
# <http://philip-broehl.org/resource/the_matrix> a ns1:Film ;
#     rdfs:label "The Matrix"@en ;
#     ns1:director <http://philip-broehl.org/resource/lana_wachowski>,
#         <http://philip-broehl.org/resource/lilly_wachowski> ;
#     xsd:gYear "1999" .
#
# <http://philip-broehl.org/resource/the_message> a ns1:Film ;
#     rdfs:label "The Message"@en ;
#     ns1:director <http://philip-broehl.org/resource/moustapha_akkad> ;
#     xsd:gYear "1976" .
#
# <http://philip-broehl.org/resource/the_night_of_the_hunter> a ns1:Film ;
#     rdfs:label "The Night of the Hunter"@en ;
#     ns1:director <http://philip-broehl.org/resource/charles_laughton> ;
#     xsd:gYear "1955" .
#
# <http://philip-broehl.org/resource/the_nightmare_before_christmas> a ns1:Film ;
#     rdfs:label "The Nightmare Before Christmas"@en ;
#     ns1:director <http://philip-broehl.org/resource/henry_selick> ;
#     xsd:gYear "1993" .
#
# <http://philip-broehl.org/resource/the_philadelphia_story> a ns1:Film ;
#     rdfs:label "The Philadelphia Story"@en ;
#     ns1:director <http://philip-broehl.org/resource/george_cukor> ;
#     xsd:gYear "1940" .
#
# <http://philip-broehl.org/resource/the_pianist> a ns1:Film ;
#     rdfs:label "The Pianist"@en ;
#     ns1:director <http://philip-broehl.org/resource/roman_polanski> ;
#     xsd:gYear "2002" .
#
# <http://philip-broehl.org/resource/the_prestige> a ns1:Film ;
#     rdfs:label "The Prestige"@en ;
#     ns1:director <http://philip-broehl.org/resource/christopher_nolan> ;
#     xsd:gYear "2006" .
#
# <http://philip-broehl.org/resource/the_princess_bride> a ns1:Film ;
#     rdfs:label "The Princess Bride"@en ;
#     ns1:director <http://philip-broehl.org/resource/rob_reiner> ;
#     xsd:gYear "1987" .
#
# <http://philip-broehl.org/resource/the_revenant> a ns1:Film ;
#     rdfs:label "The Revenant"@en ;
#     ns1:director <http://philip-broehl.org/resource/alejandro_gonzã¡lez_iã±ã¡rritu> ;
#     xsd:gYear "2015" .
#
# <http://philip-broehl.org/resource/the_shawshank_redemption> a ns1:Film ;
#     rdfs:label "The Shawshank Redemption"@en ;
#     ns1:director <http://philip-broehl.org/resource/frank_darabont> ;
#     xsd:gYear "1994" .
#
# <http://philip-broehl.org/resource/the_shining> a ns1:Film ;
#     rdfs:label "The Shining"@en ;
#     ns1:director <http://philip-broehl.org/resource/stanley_kubrick> ;
#     xsd:gYear "1980" .
#
# <http://philip-broehl.org/resource/the_silence_of_the_lambs> a ns1:Film ;
#     rdfs:label "The Silence of the Lambs"@en ;
#     ns1:director <http://philip-broehl.org/resource/jonathan_demme> ;
#     xsd:gYear "1991" .
#
# <http://philip-broehl.org/resource/the_sixth_sense> a ns1:Film ;
#     rdfs:label "The Sixth Sense"@en ;
#     ns1:director <http://philip-broehl.org/resource/m._night_shyamalan> ;
#     xsd:gYear "1999" .
#
# <http://philip-broehl.org/resource/the_sting> a ns1:Film ;
#     rdfs:label "The Sting"@en ;
#     ns1:director <http://philip-broehl.org/resource/george_roy_hill> ;
#     xsd:gYear "1973" .
#
# <http://philip-broehl.org/resource/the_straight_story> a ns1:Film ;
#     rdfs:label "The Straight Story"@en ;
#     ns1:director <http://philip-broehl.org/resource/david_lynch> ;
#     xsd:gYear "1999" .
#
# <http://philip-broehl.org/resource/the_terminator> a ns1:Film ;
#     rdfs:label "The Terminator"@en ;
#     ns1:director <http://philip-broehl.org/resource/james_cameron> ;
#     xsd:gYear "1984" .
#
# <http://philip-broehl.org/resource/the_thing> a ns1:Film ;
#     rdfs:label "The Thing"@en ;
#     ns1:director <http://philip-broehl.org/resource/john_carpenter> ;
#     xsd:gYear "1982" .
#
# <http://philip-broehl.org/resource/the_third_man> a ns1:Film ;
#     rdfs:label "The Third Man"@en ;
#     ns1:director <http://philip-broehl.org/resource/carol_reed> ;
#     xsd:gYear "1949" .
#
# <http://philip-broehl.org/resource/the_treasure_of_the_sierra_madre> a ns1:Film ;
#     rdfs:label "The Treasure of the Sierra Madre"@en ;
#     ns1:director <http://philip-broehl.org/resource/john_huston> ;
#     xsd:gYear "1948" .
#
# <http://philip-broehl.org/resource/the_truman_show> a ns1:Film ;
#     rdfs:label "The Truman Show"@en ;
#     ns1:director <http://philip-broehl.org/resource/peter_weir> ;
#     xsd:gYear "1998" .
#
# <http://philip-broehl.org/resource/the_usual_suspects> a ns1:Film ;
#     rdfs:label "The Usual Suspects"@en ;
#     ns1:director <http://philip-broehl.org/resource/bryan_singer> ;
#     xsd:gYear "1995" .
#
# <http://philip-broehl.org/resource/the_wild_bunch> a ns1:Film ;
#     rdfs:label "The Wild Bunch"@en ;
#     ns1:director <http://philip-broehl.org/resource/sam_peckinpah> ;
#     xsd:gYear "1969" .
#
# <http://philip-broehl.org/resource/the_wizard_of_oz> a ns1:Film ;
#     rdfs:label "The Wizard of Oz"@en ;
#     ns1:director <http://philip-broehl.org/resource/george_cukor>,
#         <http://philip-broehl.org/resource/king_vidor>,
#         <http://philip-broehl.org/resource/mervyn_leroy>,
#         <http://philip-broehl.org/resource/norman_taurog>,
#         <http://philip-broehl.org/resource/victor_fleming> ;
#     xsd:gYear "1939" .
#
# <http://philip-broehl.org/resource/the_wolf_of_wall_street> a ns1:Film ;
#     rdfs:label "The Wolf of Wall Street"@en ;
#     ns1:director <http://philip-broehl.org/resource/martin_scorsese> ;
#     xsd:gYear "2013" .
#
# <http://philip-broehl.org/resource/there_will_be_blood> a ns1:Film ;
#     rdfs:label "There Will Be Blood"@en ;
#     ns1:director <http://philip-broehl.org/resource/paul_thomas_anderson> ;
#     xsd:gYear "2007" .
#
# <http://philip-broehl.org/resource/to_kill_a_mockingbird> a ns1:Film ;
#     rdfs:label "To Kill a Mockingbird"@en ;
# ...
#     ns2:name "Brian De Palma"@en .
#
# <http://philip-broehl.org/resource/bryan_singer> a ns1:Person ;
#     ns2:name "Bryan Singer"@en .
#
# <http://philip-broehl.org/resource/buster_keaton> a ns1:Person ;
#     ns2:name "Buster Keaton"@en .
#
# <http://philip-broehl.org/resource/byron_howard> a ns1:Person ;
#     ns2:name "Byron Howard"@en .
#
# <http://philip-broehl.org/resource/carol_reed> a ns1:Person ;
#     ns2:name "Carol Reed"@en .
#
# <http://philip-broehl.org/resource/charles_laughton> a ns1:Person ;
#     ns2:name "Charles Laughton"@en .
#
# <http://philip-broehl.org/resource/chris_sanders> a ns1:Person ;
#     ns2:name "Chris Sanders"@en .
#
# <http://philip-broehl.org/resource/clyde_bruckman> a ns1:Person ;
#     ns2:name "Clyde Bruckman"@en .
#
# <http://philip-broehl.org/resource/curtis_hanson> a ns1:Person ;
#     ns2:name "Curtis Hanson"@en .
#
# <http://philip-broehl.org/resource/darren_aronofsky> a ns1:Person ;
#     ns2:name "Darren Aronofsky"@en .
#
# <http://philip-broehl.org/resource/david_silverman> a ns1:Person ;
#     ns2:name "David Silverman"@en .
#
# <http://philip-broehl.org/resource/david_yates> a ns1:Person ;
#     ns2:name "David Yates"@en .
#
# <http://philip-broehl.org/resource/dean_deblois> a ns1:Person ;
#     ns2:name "Dean DeBlois"@en .
#
# <http://philip-broehl.org/resource/denis_villeneuve> a ns1:Person ;
#     ns2:name "Denis Villeneuve"@en .
#
# <http://philip-broehl.org/resource/destin_daniel_cretton> a ns1:Person ;
#     ns2:name "Destin Daniel Cretton"@en .
#
# <http://philip-broehl.org/resource/edgar_wright> a ns1:Person ;
#     ns2:name "Edgar Wright"@en .
#
# <http://philip-broehl.org/resource/edmund_goulding> a ns1:Person ;
#     ns2:name "Edmund Goulding"@en .
#
# <http://philip-broehl.org/resource/edward_zwick> a ns1:Person ;
#     ns2:name "Edward Zwick"@en .
#
# <http://philip-broehl.org/resource/eli_roth> a ns1:Person ;
#     ns2:name "Eli Roth"@en .
#
# <http://philip-broehl.org/resource/frank_miller> a ns1:Person ;
#     ns2:name "Frank Miller"@en .
#
# <http://philip-broehl.org/resource/fred_zinnemann> a ns1:Person ;
#     ns2:name "Fred Zinnemann"@en .
#
# <http://philip-broehl.org/resource/garth_davis> a ns1:Person ;
#     ns2:name "Garth Davis"@en .
#
# <http://philip-broehl.org/resource/gary_trousdale> a ns1:Person ;
#     ns2:name "Gary Trousdale"@en .
#
# <http://philip-broehl.org/resource/gavin_o'connor> a ns1:Person ;
#     ns2:name "Gavin O'Connor"@en .
#
# <http://philip-broehl.org/resource/gene_kelly> a ns1:Person ;
#     ns2:name "Gene Kelly"@en .
#
# <http://philip-broehl.org/resource/george_lucas> a ns1:Person ;
#     ns2:name "George Lucas"@en .
#
# <http://philip-broehl.org/resource/george_miller> a ns1:Person ;
#     ns2:name "George Miller"@en .
#
# <http://philip-broehl.org/resource/giuseppe_tornatore> a ns1:Person ;
#     ns2:name "Giuseppe Tornatore"@en .
#
# <http://philip-broehl.org/resource/gore_verbinski> a ns1:Person ;
#     ns2:name "Gore Verbinski"@en .
#
# <http://philip-broehl.org/resource/gus_van_sant> a ns1:Person ;
#     ns2:name "Gus Van Sant"@en .
#
# <http://philip-broehl.org/resource/harold_ramis> a ns1:Person ;
#     ns2:name "Harold Ramis"@en .
#
# <http://philip-broehl.org/resource/henry_koster> a ns1:Person ;
#     ns2:name "Henry Koster"@en .
#
# <http://philip-broehl.org/resource/henry_selick> a ns1:Person ;
#     ns2:name "Henry Selick"@en .
#
# <http://philip-broehl.org/resource/irvin_kershner> a ns1:Person ;
#     ns2:name "Irvin Kershner"@en .
#
# <http://philip-broehl.org/resource/j.j._abrams> a ns1:Person ;
#     ns2:name "J.J. Abrams"@en .
#
# <http://philip-broehl.org/resource/jacques_tourneur> a ns1:Person ;
#     ns2:name "Jacques Tourneur"@en .
#
# <http://philip-broehl.org/resource/james_mangold> a ns1:Person ;
#     ns2:name "James Mangold"@en .
#
# <http://philip-broehl.org/resource/james_mcteigue> a ns1:Person ;
#     ns2:name "James McTeigue"@en .
#
# <http://philip-broehl.org/resource/jared_bush> a ns1:Person ;
#     ns2:name "Jared Bush"@en .
#
# <http://philip-broehl.org/resource/jim_sheridan> a ns1:Person ;
#     ns2:name "Jim Sheridan"@en .
#
# <http://philip-broehl.org/resource/john_carpenter> a ns1:Person ;
#     ns2:name "John Carpenter"@en .
#
# <http://philip-broehl.org/resource/john_frankenheimer> a ns1:Person ;
#     ns2:name "John Frankenheimer"@en .
#
# <http://philip-broehl.org/resource/john_g._avildsen> a ns1:Person ;
#     ns2:name "John G. Avildsen"@en .
#
# <http://philip-broehl.org/resource/john_lasseter> a ns1:Person ;
#     ns2:name "John Lasseter"@en .
#
# <http://philip-broehl.org/resource/john_mctiernan> a ns1:Person ;
#     ns2:name "John McTiernan"@en .
#
# <http://philip-broehl.org/resource/john_musker> a ns1:Person ;
#     ns2:name "John Musker"@en .
#
# <http://philip-broehl.org/resource/john_sturges> a ns1:Person ;
#     ns2:name "John Sturges"@en .
#
# <http://philip-broehl.org/resource/jon_watts> a ns1:Person ;
#     ns2:name "Jon Watts"@en .
#
# <http://philip-broehl.org/resource/jonathan_demme> a ns1:Person ;
#     ns2:name "Jonathan Demme"@en .
#
# <http://philip-broehl.org/resource/joss_whedon> a ns1:Person ;
#     ns2:name "Joss Whedon"@en .
#
# <http://philip-broehl.org/resource/king_vidor> a ns1:Person ;
#     ns2:name "King Vidor"@en .
#
# <http://philip-broehl.org/resource/kirk_wise> a ns1:Person ;
#     ns2:name "Kirk Wise"@en .
#
# <http://philip-broehl.org/resource/lana_wachowski> a ns1:Person ;
#     ns2:name "Lana Wachowski"@en .
#
# <http://philip-broehl.org/resource/lars_von_trier> a ns1:Person ;
#     ns2:name "Lars von Trier"@en .
#
# <http://philip-broehl.org/resource/lasse_hallstrã¶m> a ns1:Person ;
#     ns2:name "Lasse HallstrÃ¶m"@en .
#
# <http://philip-broehl.org/resource/lenny_abrahamson> a ns1:Person ;
#     ns2:name "Lenny Abrahamson"@en .
#
# <http://philip-broehl.org/resource/lewis_milestone> a ns1:Person ;
#     ns2:name "Lewis Milestone"@en .
#
# <http://philip-broehl.org/resource/lilly_wachowski> a ns1:Person ;
#     ns2:name "Lilly Wachowski"@en .
#
# <http://philip-broehl.org/resource/loveleen_tandan> a ns1:Person ;
#     ns2:name "Loveleen Tandan"@en .
#
# <http://philip-broehl.org/resource/luc_besson> a ns1:Person ;
#     ns2:name "Luc Besson"@en .
#
# <http://philip-broehl.org/resource/m._night_shyamalan> a ns1:Person ;
#     ns2:name "M. Night Shyamalan"@en .
#
# <http://philip-broehl.org/resource/mel_brooks> a ns1:Person ;
#     ns2:name "Mel Brooks"@en .
#
# <http://philip-broehl.org/resource/mervyn_leroy> a ns1:Person ;
#     ns2:name "Mervyn LeRoy"@en .
#
# <http://philip-broehl.org/resource/michael_cimino> a ns1:Person ;
#     ns2:name "Michael Cimino"@en .
#
# <http://philip-broehl.org/resource/michael_curtiz> a ns1:Person ;
#     ns2:name "Michael Curtiz"@en .
#
# <http://philip-broehl.org/resource/michael_mann> a ns1:Person ;
#     ns2:name "Michael Mann"@en .
#
# <http://philip-broehl.org/resource/michel_gondry> a ns1:Person ;
#     ns2:name "Michel Gondry"@en .
#
# <http://philip-broehl.org/resource/morten_tyldum> a ns1:Person ;
#     ns2:name "Morten Tyldum"@en .
#
# <http://philip-broehl.org/resource/moustapha_akkad> a ns1:Person ;
#     ns2:name "Moustapha Akkad"@en .
#
# <http://philip-broehl.org/resource/norman_taurog> a ns1:Person ;
#     ns2:name "Norman Taurog"@en .
#
# <http://philip-broehl.org/resource/paul_greengrass> a ns1:Person ;
#     ns2:name "Paul Greengrass"@en .
#
# <http://philip-broehl.org/resource/peter_bogdanovich> a ns1:Person ;
#     ns2:name "Peter Bogdanovich"@en .
#
# <http://philip-broehl.org/resource/rich_moore> a ns1:Person ;
#     ns2:name "Rich Moore"@en .
#
# <http://philip-broehl.org/resource/richard_attenborough> a ns1:Person ;
#     ns2:name "Richard Attenborough"@en .
#
# <http://philip-broehl.org/resource/richard_brooks> a ns1:Person ;
#     ns2:name "Richard Brooks"@en .
#
# <http://philip-broehl.org/resource/richard_kelly> a ns1:Person ;
#     ns2:name "Richard Kelly"@en .
#
# <http://philip-broehl.org/resource/richard_marquand> a ns1:Person ;
#     ns2:name "Richard Marquand"@en .
#
# <http://philip-broehl.org/resource/rob_minkoff> a ns1:Person ;
#     ns2:name "Rob Minkoff"@en .
#
# <http://philip-broehl.org/resource/robert_aldrich> a ns1:Person ;
#     ns2:name "Robert Aldrich"@en .
#
# <http://philip-broehl.org/resource/robert_hamer> a ns1:Person ;
#     ns2:name "Robert Hamer"@en .
#
# <http://philip-broehl.org/resource/robert_mulligan> a ns1:Person ;
#     ns2:name "Robert Mulligan"@en .
#
# <http://philip-broehl.org/resource/robert_rodriguez> a ns1:Person ;
#     ns2:name "Robert Rodriguez"@en .
#
# <http://philip-broehl.org/resource/robert_rossen> a ns1:Person ;
#     ns2:name "Robert Rossen"@en .
#
# <http://philip-broehl.org/resource/roger_allers> a ns1:Person ;
#     ns2:name "Roger Allers"@en .
#
# <http://philip-broehl.org/resource/ron_clements> a ns1:Person ;
#     ns2:name "Ron Clements"@en .
#
# <http://philip-broehl.org/resource/ronnie_del_carmen> a ns1:Person ;
#     ns2:name "Ronnie Del Carmen"@en .
#
# <http://philip-broehl.org/resource/sam_mendes> a ns1:Person ;
#     ns2:name "Sam Mendes"@en .
#
# <http://philip-broehl.org/resource/sam_peckinpah> a ns1:Person ;
#     ns2:name "Sam Peckinpah"@en .
#
# <http://philip-broehl.org/resource/sean_penn> a ns1:Person ;
#     ns2:name "Sean Penn"@en .
#
# <http://philip-broehl.org/resource/sergio_leone> a ns1:Person ;
#     ns2:name "Sergio Leone"@en .
#
# <http://philip-broehl.org/resource/stanley_donen> a ns1:Person ;
#     ns2:name "Stanley Donen"@en .
#
# <http://philip-broehl.org/resource/stanley_kramer> a ns1:Person ;
#     ns2:name "Stanley Kramer"@en .
#
# <http://philip-broehl.org/resource/steve_mcqueen> a ns1:Person ;
#     ns2:name "Steve McQueen"@en .
#
# <http://philip-broehl.org/resource/stuart_rosenberg> a ns1:Person ;
#     ns2:name "Stuart Rosenberg"@en .
#
# <http://philip-broehl.org/resource/tate_taylor> a ns1:Person ;
#     ns2:name "Tate Taylor"@en .
#
# <http://philip-broehl.org/resource/terry_george> a ns1:Person ;
#     ns2:name "Terry George"@en .
#
# <http://philip-broehl.org/resource/tim_burton> a ns1:Person ;
#     ns2:name "Tim Burton"@en .
#
# <http://philip-broehl.org/resource/tim_miller> a ns1:Person ;
#     ns2:name "Tim Miller"@en .
#
# <http://philip-broehl.org/resource/tom_hooper> a ns1:Person ;
#     ns2:name "Tom Hooper"@en .
#
# <http://philip-broehl.org/resource/tom_mccarthy> a ns1:Person ;
#     ns2:name "Tom McCarthy"@en .
#
# <http://philip-broehl.org/resource/tomm_moore> a ns1:Person ;
#     ns2:name "Tomm Moore"@en .
#
# <http://philip-broehl.org/resource/tony_kaye> a ns1:Person ;
#     ns2:name "Tony Kaye"@en .
#
# <http://philip-broehl.org/resource/wes_anderson> a ns1:Person ;
#     ns2:name "Wes Anderson"@en .
#
# <http://philip-broehl.org/resource/william_friedkin> a ns1:Person ;
#     ns2:name "William Friedkin"@en .
#
# <http://philip-broehl.org/resource/wim_wenders> a ns1:Person ;
#     ns2:name "Wim Wenders"@en .
#
# <http://philip-broehl.org/resource/woody_allen> a ns1:Person ;
#     ns2:name "Woody Allen"@en .
#
# <http://philip-broehl.org/resource/andrew_stanton> a ns1:Person ;
#     ns2:name "Andrew Stanton"@en .
#
# <http://philip-broehl.org/resource/damien_chazelle> a ns1:Person ;
#     ns2:name "Damien Chazelle"@en .
#
# <http://philip-broehl.org/resource/danny_boyle> a ns1:Person ;
#     ns2:name "Danny Boyle"@en .
#
# <http://philip-broehl.org/resource/david_lynch> a ns1:Person ;
#     ns2:name "David Lynch"@en .
#
# <http://philip-broehl.org/resource/elia_kazan> a ns1:Person ;
#     ns2:name "Elia Kazan"@en .
#
# <http://philip-broehl.org/resource/frank_darabont> a ns1:Person ;
#     ns2:name "Frank Darabont"@en .
#
# <http://philip-broehl.org/resource/franklin_j._schaffner> a ns1:Person ;
#     ns2:name "Franklin J. Schaffner"@en .
#
# <http://philip-broehl.org/resource/george_roy_hill> a ns1:Person ;
#     ns2:name "George Roy Hill"@en .
#
# <http://philip-broehl.org/resource/guy_ritchie> a ns1:Person ;
#     ns2:name "Guy Ritchie"@en .
#
# <http://philip-broehl.org/resource/james_gunn> a ns1:Person ;
#     ns2:name "James Gunn"@en .
#
# <http://philip-broehl.org/resource/john_ford> a ns1:Person ;
#     ns2:name "John Ford"@en .
#
# <http://philip-broehl.org/resource/john_huston> a ns1:Person ;
#     ns2:name "John Huston"@en .
#
# <http://philip-broehl.org/resource/joseph_l._mankiewicz> a ns1:Person ;
#     ns2:name "Joseph L. Mankiewicz"@en .
#
# <http://philip-broehl.org/resource/mel_gibson> a ns1:Person ;
#     ns2:name "Mel Gibson"@en .
#
# <http://philip-broehl.org/resource/mike_nichols> a ns1:Person ;
#     ns2:name "Mike Nichols"@en .
#
# <http://philip-broehl.org/resource/milos_forman> a ns1:Person ;
#     ns2:name "Milos Forman"@en .
#
# <http://philip-broehl.org/resource/oliver_stone> a ns1:Person ;
#     ns2:name "Oliver Stone"@en .
#
# <http://philip-broehl.org/resource/orson_welles> a ns1:Person ;
#     ns2:name "Orson Welles"@en .
#
# <http://philip-broehl.org/resource/otto_preminger> a ns1:Person ;
#     ns2:name "Otto Preminger"@en .
#
# <http://philip-broehl.org/resource/paul_thomas_anderson> a ns1:Person ;
#     ns2:name "Paul Thomas Anderson"@en .
#
# <http://philip-broehl.org/resource/peter_weir> a ns1:Person ;
#     ns2:name "Peter Weir"@en .
#
# <http://philip-broehl.org/resource/richard_linklater> a ns1:Person ;
#     ns2:name "Richard Linklater"@en .
#
# <http://philip-broehl.org/resource/rob_reiner> a ns1:Person ;
#     ns2:name "Rob Reiner"@en .
#
# <http://philip-broehl.org/resource/robert_zemeckis> a ns1:Person ;
#     ns2:name "Robert Zemeckis"@en .
#
# <http://philip-broehl.org/resource/roman_polanski> a ns1:Person ;
#     ns2:name "Roman Polanski"@en .
#
# <http://philip-broehl.org/resource/ron_howard> a ns1:Person ;
#     ns2:name "Ron Howard"@en .
#
# <http://philip-broehl.org/resource/sam_wood> a ns1:Person ;
#     ns2:name "Sam Wood"@en .
#
# <http://philip-broehl.org/resource/terry_gilliam> a ns1:Person ;
#     ns2:name "Terry Gilliam"@en .
#
# <http://philip-broehl.org/resource/terry_jones> a ns1:Person ;
#     ns2:name "Terry Jones"@en .
#
# <http://philip-broehl.org/resource/victor_fleming> a ns1:Person ;
#     ns2:name "Victor Fleming"@en .
#
# <http://philip-broehl.org/resource/clint_eastwood> a ns1:Person ;
#     ns2:name "Clint Eastwood"@en .
#
# <http://philip-broehl.org/resource/david_fincher> a ns1:Person ;
#     ns2:name "David Fincher"@en .
#
# <http://philip-broehl.org/resource/david_lean> a ns1:Person ;
#     ns2:name "David Lean"@en .
#
# <http://philip-broehl.org/resource/ethan_coen> a ns1:Person ;
#     ns2:name "Ethan Coen"@en .
#
# <http://philip-broehl.org/resource/francis_ford_coppola> a ns1:Person ;
#     ns2:name "Francis Ford Coppola"@en .
#
# <http://philip-broehl.org/resource/george_cukor> a ns1:Person ;
#     ns2:name "George Cukor"@en .
#
# <http://philip-broehl.org/resource/howard_hawks> a ns1:Person ;
#     ns2:name "Howard Hawks"@en .
#
# <http://philip-broehl.org/resource/james_cameron> a ns1:Person ;
#     ns2:name "James Cameron"@en .
#
# <http://philip-broehl.org/resource/joel_coen> a ns1:Person ;
#     ns2:name "Joel Coen"@en .
#
# <http://philip-broehl.org/resource/lee_unkrich> a ns1:Person ;
#     ns2:name "Lee Unkrich"@en .
#
# <http://philip-broehl.org/resource/pete_docter> a ns1:Person ;
#     ns2:name "Pete Docter"@en .
#
# <http://philip-broehl.org/resource/peter_jackson> a ns1:Person ;
#     ns2:name "Peter Jackson"@en .
#
# <http://philip-broehl.org/resource/sidney_lumet> a ns1:Person ;
#     ns2:name "Sidney Lumet"@en .
#
# <http://philip-broehl.org/resource/william_wyler> a ns1:Person ;
#     ns2:name "William Wyler"@en .
#
# <http://philip-broehl.org/resource/frank_capra> a ns1:Person ;
#     ns2:name "Frank Capra"@en .
#
# <http://philip-broehl.org/resource/ridley_scott> a ns1:Person ;
#     ns2:name "Ridley Scott"@en .
#
# <http://philip-broehl.org/resource/charles_chaplin> a ns1:Person ;
#     ns2:name "Charles Chaplin"@en .
#
# <http://philip-broehl.org/resource/quentin_tarantino> a ns1:Person ;
#     ns2:name "Quentin Tarantino"@en .
#
# <http://philip-broehl.org/resource/billy_wilder> a ns1:Person ;
#     ns2:name "Billy Wilder"@en .
#
# <http://philip-broehl.org/resource/christopher_nolan> a ns1:Person ;
#     ns2:name "Christopher Nolan"@en .
#
# <http://philip-broehl.org/resource/martin_scorsese> a ns1:Person ;
#     ns2:name "Martin Scorsese"@en .
#
# <http://philip-broehl.org/resource/steven_spielberg> a ns1:Person ;
#     ns2:name "Steven Spielberg"@en .
#
# <http://philip-broehl.org/resource/stanley_kubrick> a ns1:Person ;
#     ns2:name "Stanley Kubrick"@en .
#
# <http://philip-broehl.org/resource/alfred_hitchcock> a ns1:Person ;
#     ns2:name "Alfred Hitchcock"@en .

# %%
FOAF.title
# Out:
# rdflib.term.URIRef('http://xmlns.com/foaf/0.1/title')

# %%
s = "Hubert, Peter, Heike"
s = s.split(', ')
s[0].lower().replace('u', 'ooo')
# Out:
# 'hooobert'
