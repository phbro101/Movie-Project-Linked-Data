# %% [markdown]
# # TASK: Model the data in RDF
#
#
#
# ## Overview
# In this task, your assignment is to model the 'input_movie_data.csv' data set as Linked Open Data represented in RDF.
# This means, entities and relationships must be represented via IRIs. A good Linked Data best practice is to re-use existing RDF vocabularies for such a process.
#
# ## Task details
# 1. Re-use the schema.org vocabulary (https://schema.org/) to model the data in RDF.
# 2. Use self-defined valid URLs as IRIs to represent all entities, using your first- and last name as domain. For example, the movie “The Godfather” can be represented with http://firstname-lastname.org/resource/the_godfather
# > __HINT__: URLs must be valid, but do not have to resolve!
# 3. Re-using schema.org, find the classes of the corresponding instances and represent the instances with that class (or classes). For example, if we were re-using the DBpedia vocabulary, the movie “The Godfather” would be of type <http://dbpedia.org/ontology/Film> resulting in a triple representation: <br>
# `<http://firstname-lastname.org/resource/the_godfather> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://dbpedia.org/ontology/Film>`
#
# > Find such RDF classes in the schema.org vocabulary to specify the rdf:type properties for movie and person.
#
# 4. Re-using schema.org, find the appropriate object property specifying that a movie has a director.
# > __Hint__: Some movies have more than one director
# 5. In addition, find appropriate properties to describe
#   - the name of a movie including the English language tag,
#   - the publication year of a movie including the literal data type of year
#   >__HINT__: not xsd:date, see xsd definition for correct data type for year
#   - the name of a person
#   > __HINT__: Watch out for the correct domain and range of properties, as well as subclass relationships
#
# <br><br>
#
# ## Submission 1
#
# Save the data set that you have represented in RDF (in N3) to the output_data folder with the naming __movies_task_1.n3__.

# %% [markdown]
# <br>
#
# ## Your code

# %%
from rdflib import URIRef, Literal, Graph, Namespace
from rdflib.namespace import FOAF, RDF, RDFS, XSD, DC
import urllib
import csv
from datetime import datetime
from SPARQLWrapper import SPARQLWrapper, JSON, N3

# %%
# Defines further Namespaces
EX = Namespace("https://ex1.org/")
DBO = Namespace("http://dbpedia.org/ontology/")
RSC = Namespace("http://philip-broehl.org/resource/")
WD = Namespace("http://www.wikidata.org/entity/")
WDT = Namespace("http://www.wikidata.org/prop/direct/")

# %%
input_file = open("../input_data/input_movie_data.csv")
text = csv.reader(input_file, delimiter = ',')

g = Graph()
g.bind('foaf', FOAF)
g.bind('dbo', DBO)
g.bind("wd", WD)
g.bind("wdt", WDT)
g.bind("rsc", RSC)
line_count = 0
for line in text:
    # first line does not contain data
    if line_count == 0:
        line_count += 1
    else:
        title = line[1]
        film_resource = title.lower().replace(' ', '_')  # just for valid URI format
        
        year = line[2]
        director = line[3]
        director_list = director.split(', ')  # there can be multiple directors
        
        g.add((URIRef(RSC[film_resource]), RDF.type, DBO.Film))
        g.add((URIRef(RSC[film_resource]), RDFS.label, Literal(title, lang = 'en')))
        # P577 is the property "publication data"
        g.add((URIRef(RSC[film_resource]), WDT.P577, Literal(year, datatype = XSD.gYear)))
        
        for director in director_list: 
            director_resource = director.lower().replace(' ', '_')
            g.add((URIRef(RSC[director_resource]), RDF.type, DBO.Person))
            g.add((URIRef(RSC[director_resource]), FOAF.name, Literal(director, lang = 'en')))        
            g.add((URIRef(RSC[film_resource]), DBO.director, URIRef(RSC[director_resource])))
        
print(g.serialize(format = "n3").decode("utf-8"))
g.serialize(destination = '../output_data/movies_task_1.n3', format = 'n3')
# Out:
# @prefix dbo: <http://dbpedia.org/ontology/> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix rsc: <http://philip-broehl.org/resource/> .
# @prefix wdt: <http://www.wikidata.org/prop/direct/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# rsc:12_angry_men a dbo:Film ;
#     rdfs:label "12 Angry Men"@en ;
#     dbo:director rsc:sidney_lumet ;
#     wdt:P577 "1957-01-01"^^xsd:gYear .
#
# rsc:12_years_a_slave a dbo:Film ;
#     rdfs:label "12 Years a Slave"@en ;
#     dbo:director rsc:steve_mcqueen ;
#     wdt:P577 "2013-01-01"^^xsd:gYear .
#
# rsc:2001:_a_space_odyssey a dbo:Film ;
#     rdfs:label "2001: A Space Odyssey"@en ;
#     dbo:director rsc:stanley_kubrick ;
#     wdt:P577 "1968-01-01"^^xsd:gYear .
#
# rsc:a_beautiful_mind a dbo:Film ;
#     rdfs:label "A Beautiful Mind"@en ;
#     dbo:director rsc:ron_howard ;
#     wdt:P577 "2001-01-01"^^xsd:gYear .
#
# rsc:a_christmas_story a dbo:Film ;
#     rdfs:label "A Christmas Story"@en ;
#     dbo:director rsc:bob_clark ;
#     wdt:P577 "1983-01-01"^^xsd:gYear .
#
# rsc:a_clockwork_orange a dbo:Film ;
#     rdfs:label "A Clockwork Orange"@en ;
#     dbo:director rsc:stanley_kubrick ;
#     wdt:P577 "1971-01-01"^^xsd:gYear .
#
# rsc:a_night_at_the_opera a dbo:Film ;
#     rdfs:label "A Night at the Opera"@en ;
#     dbo:director rsc:edmund_goulding,
#         rsc:sam_wood ;
#     wdt:P577 "1935-01-01"^^xsd:gYear .
#
# rsc:a_streetcar_named_desire a dbo:Film ;
#     rdfs:label "A Streetcar Named Desire"@en ;
#     dbo:director rsc:elia_kazan ;
#     wdt:P577 "1951-01-01"^^xsd:gYear .
#
# rsc:aladdin a dbo:Film ;
#     rdfs:label "Aladdin"@en ;
#     dbo:director rsc:john_musker,
#         rsc:ron_clements ;
#     wdt:P577 "1992-01-01"^^xsd:gYear .
#
# rsc:alien a dbo:Film ;
#     rdfs:label "Alien"@en ;
#     dbo:director rsc:ridley_scott ;
#     wdt:P577 "1979-01-01"^^xsd:gYear .
#
# rsc:aliens a dbo:Film ;
#     rdfs:label "Aliens"@en ;
#     dbo:director rsc:james_cameron ;
#     wdt:P577 "1986-01-01"^^xsd:gYear .
#
# rsc:all_about_eve a dbo:Film ;
#     rdfs:label "All About Eve"@en ;
#     dbo:director rsc:joseph_l._mankiewicz ;
#     wdt:P577 "1950-01-01"^^xsd:gYear .
#
# rsc:all_quiet_on_the_western_front a dbo:Film ;
#     rdfs:label "All Quiet on the Western Front"@en ;
#     dbo:director rsc:lewis_milestone ;
#     wdt:P577 "1930-01-01"^^xsd:gYear .
#
# rsc:amadeus a dbo:Film ;
#     rdfs:label "Amadeus"@en ;
#     dbo:director rsc:milos_forman ;
#     wdt:P577 "1984-01-01"^^xsd:gYear .
#
# rsc:american_beauty a dbo:Film ;
#     rdfs:label "American Beauty"@en ;
#     dbo:director rsc:sam_mendes ;
#     wdt:P577 "1999-01-01"^^xsd:gYear .
#
# rsc:american_history_x a dbo:Film ;
#     rdfs:label "American History X"@en ;
#     dbo:director rsc:tony_kaye ;
#     wdt:P577 "1998-01-01"^^xsd:gYear .
#
# rsc:anatomy_of_a_murder a dbo:Film ;
#     rdfs:label "Anatomy of a Murder"@en ;
#     dbo:director rsc:otto_preminger ;
#     wdt:P577 "1959-01-01"^^xsd:gYear .
#
# rsc:annie_hall a dbo:Film ;
#     rdfs:label "Annie Hall"@en ;
#     dbo:director rsc:woody_allen ;
#     wdt:P577 "1977-01-01"^^xsd:gYear .
#
# rsc:apocalypse_now a dbo:Film ;
#     rdfs:label "Apocalypse Now"@en ;
#     dbo:director rsc:francis_ford_coppola ;
#     wdt:P577 "1979-01-01"^^xsd:gYear .
#
# rsc:arsenic_and_old_lace a dbo:Film ;
#     rdfs:label "Arsenic and Old Lace"@en ;
#     dbo:director rsc:frank_capra ;
#     wdt:P577 "1944-01-01"^^xsd:gYear .
#
# rsc:baby_driver a dbo:Film ;
#     rdfs:label "Baby Driver"@en ;
#     dbo:director rsc:edgar_wright ;
#     wdt:P577 "2017-01-01"^^xsd:gYear .
#
# rsc:back_to_the_future a dbo:Film ;
#     rdfs:label "Back to the Future"@en ;
#     dbo:director rsc:robert_zemeckis ;
#     wdt:P577 "1985-01-01"^^xsd:gYear .
#
# rsc:barry_lyndon a dbo:Film ;
#     rdfs:label "Barry Lyndon"@en ;
#     dbo:director rsc:stanley_kubrick ;
#     wdt:P577 "1975-01-01"^^xsd:gYear .
#
# rsc:batman_begins a dbo:Film ;
#     rdfs:label "Batman Begins"@en ;
#     dbo:director rsc:christopher_nolan ;
#     wdt:P577 "2005-01-01"^^xsd:gYear .
#
# rsc:beauty_and_the_beast a dbo:Film ;
#     rdfs:label "Beauty and the Beast"@en ;
#     dbo:director rsc:gary_trousdale,
#         rsc:kirk_wise ;
#     wdt:P577 "1991-01-01"^^xsd:gYear .
#
# rsc:before_sunrise a dbo:Film ;
#     rdfs:label "Before Sunrise"@en ;
#     dbo:director rsc:richard_linklater ;
#     wdt:P577 "1995-01-01"^^xsd:gYear .
#
# rsc:before_sunset a dbo:Film ;
#     rdfs:label "Before Sunset"@en ;
#     dbo:director rsc:richard_linklater ;
#     wdt:P577 "2004-01-01"^^xsd:gYear .
#
# rsc:ben-hur a dbo:Film ;
#     rdfs:label "Ben-Hur"@en ;
#     dbo:director rsc:william_wyler ;
#     wdt:P577 "1959-01-01"^^xsd:gYear .
#
# rsc:big_fish a dbo:Film ;
#     rdfs:label "Big Fish"@en ;
#     dbo:director rsc:tim_burton ;
#     wdt:P577 "2003-01-01"^^xsd:gYear .
#
# rsc:blade_runner a dbo:Film ;
#     rdfs:label "Blade Runner"@en ;
#     dbo:director rsc:ridley_scott ;
#     wdt:P577 "1982-01-01"^^xsd:gYear .
#
# rsc:blood_diamond a dbo:Film ;
#     rdfs:label "Blood Diamond"@en ;
#     dbo:director rsc:edward_zwick ;
#     wdt:P577 "2006-01-01"^^xsd:gYear .
#
# rsc:braveheart a dbo:Film ;
#     rdfs:label "Braveheart"@en ;
#     dbo:director rsc:mel_gibson ;
#     wdt:P577 "1995-01-01"^^xsd:gYear .
#
# rsc:brief_encounter a dbo:Film ;
#     rdfs:label "Brief Encounter"@en ;
#     dbo:director rsc:david_lean ;
#     wdt:P577 "1945-01-01"^^xsd:gYear .
#
# rsc:butch_cassidy_and_the_sundance_kid a dbo:Film ;
#     rdfs:label "Butch Cassidy and the Sundance Kid"@en ;
#     dbo:director rsc:george_roy_hill ;
#     wdt:P577 "1969-01-01"^^xsd:gYear .
#
# rsc:casablanca a dbo:Film ;
#     rdfs:label "Casablanca"@en ;
#     dbo:director rsc:michael_curtiz ;
#     wdt:P577 "1942-01-01"^^xsd:gYear .
#
# rsc:casino a dbo:Film ;
#     rdfs:label "Casino"@en ;
#     dbo:director rsc:martin_scorsese ;
#     wdt:P577 "1995-01-01"^^xsd:gYear .
#
# rsc:cat_on_a_hot_tin_roof a dbo:Film ;
#     rdfs:label "Cat on a Hot Tin Roof"@en ;
#     dbo:director rsc:richard_brooks ;
#     wdt:P577 "1958-01-01"^^xsd:gYear .
#
# rsc:catch_me_if_you_can a dbo:Film ;
#     rdfs:label "Catch Me If You Can"@en ;
#     dbo:director rsc:steven_spielberg ;
#     wdt:P577 "2002-01-01"^^xsd:gYear .
#
# rsc:chinatown a dbo:Film ;
#     rdfs:label "Chinatown"@en ;
#     dbo:director rsc:roman_polanski ;
#     wdt:P577 "1974-01-01"^^xsd:gYear .
#
# rsc:citizen_kane a dbo:Film ;
#     rdfs:label "Citizen Kane"@en ;
#     dbo:director rsc:orson_welles ;
#     wdt:P577 "1941-01-01"^^xsd:gYear .
#
# rsc:city_lights a dbo:Film ;
#     rdfs:label "City Lights"@en ;
#     dbo:director rsc:charles_chaplin ;
#     wdt:P577 "1931-01-01"^^xsd:gYear .
#
# rsc:cool_hand_luke a dbo:Film ;
#     rdfs:label "Cool Hand Luke"@en ;
#     dbo:director rsc:stuart_rosenberg ;
#     wdt:P577 "1967-01-01"^^xsd:gYear .
#
# rsc:dead_poets_society a dbo:Film ;
#     rdfs:label "Dead Poets Society"@en ;
#     dbo:director rsc:peter_weir ;
#     wdt:P577 "1989-01-01"^^xsd:gYear .
#
# rsc:deadpool a dbo:Film ;
#     rdfs:label "Deadpool"@en ;
#     dbo:director rsc:tim_miller ;
#     wdt:P577 "2016-01-01"^^xsd:gYear .
#
# rsc:dial_m_for_murder a dbo:Film ;
#     rdfs:label "Dial M for Murder"@en ;
#     dbo:director rsc:alfred_hitchcock ;
#     wdt:P577 "1954-01-01"^^xsd:gYear .
#
# rsc:die_hard a dbo:Film ;
#     rdfs:label "Die Hard"@en ;
#     dbo:director rsc:john_mctiernan ;
#     wdt:P577 "1988-01-01"^^xsd:gYear .
#
# rsc:django_unchained a dbo:Film ;
#     rdfs:label "Django Unchained"@en ;
#     dbo:director rsc:quentin_tarantino ;
#     wdt:P577 "2012-01-01"^^xsd:gYear .
#
# rsc:dog_day_afternoon a dbo:Film ;
#     rdfs:label "Dog Day Afternoon"@en ;
#     dbo:director rsc:sidney_lumet ;
#     wdt:P577 "1975-01-01"^^xsd:gYear .
#
# rsc:dogville a dbo:Film ;
#     rdfs:label "Dogville"@en ;
#     dbo:director rsc:lars_von_trier ;
#     wdt:P577 "2003-01-01"^^xsd:gYear .
#
# rsc:donnie_darko a dbo:Film ;
#     rdfs:label "Donnie Darko"@en ;
#     dbo:director rsc:richard_kelly ;
#     wdt:P577 "2001-01-01"^^xsd:gYear .
#
# rsc:double_indemnity a dbo:Film ;
#     rdfs:label "Double Indemnity"@en ;
#     dbo:director rsc:billy_wilder ;
#     wdt:P577 "1944-01-01"^^xsd:gYear .
#
# rsc:dr._strangelove_or:_how_i_learned_to_stop_worrying_and_love_the_bomb a dbo:Film ;
#     rdfs:label "Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb"@en ;
#     dbo:director rsc:stanley_kubrick ;
#     wdt:P577 "1964-01-01"^^xsd:gYear .
#
# rsc:eternal_sunshine_of_the_spotless_mind a dbo:Film ;
#     rdfs:label "Eternal Sunshine of the Spotless Mind"@en ;
#     dbo:director rsc:michel_gondry ;
#     wdt:P577 "2004-01-01"^^xsd:gYear .
#
# rsc:fargo a dbo:Film ;
#     rdfs:label "Fargo"@en ;
#     dbo:director rsc:ethan_coen,
#         rsc:joel_coen ;
#     wdt:P577 "1996-01-01"^^xsd:gYear .
#
# rsc:fight_club a dbo:Film ;
#     rdfs:label "Fight Club"@en ;
#     dbo:director rsc:david_fincher ;
#     wdt:P577 "1999-01-01"^^xsd:gYear .
#
# rsc:finding_nemo a dbo:Film ;
#     rdfs:label "Finding Nemo"@en ;
#     dbo:director rsc:andrew_stanton,
#         rsc:lee_unkrich ;
#     wdt:P577 "2003-01-01"^^xsd:gYear .
#
# rsc:forrest_gump a dbo:Film ;
#     rdfs:label "Forrest Gump"@en ;
#     dbo:director rsc:robert_zemeckis ;
#     wdt:P577 "1994-01-01"^^xsd:gYear .
#
# rsc:full_metal_jacket a dbo:Film ;
#     rdfs:label "Full Metal Jacket"@en ;
#     dbo:director rsc:stanley_kubrick ;
#     wdt:P577 "1987-01-01"^^xsd:gYear .
#
# rsc:gandhi a dbo:Film ;
#     rdfs:label "Gandhi"@en ;
#     dbo:director rsc:richard_attenborough ;
#     wdt:P577 "1982-01-01"^^xsd:gYear .
#
# rsc:gladiator a dbo:Film ;
#     rdfs:label "Gladiator"@en ;
#     dbo:director rsc:ridley_scott ;
#     wdt:P577 "2000-01-01"^^xsd:gYear .
#
# rsc:gone_girl a dbo:Film ;
#     rdfs:label "Gone Girl"@en ;
#     dbo:director rsc:david_fincher ;
#     wdt:P577 "2014-01-01"^^xsd:gYear .
#
# rsc:gone_with_the_wind a dbo:Film ;
#     rdfs:label "Gone with the Wind"@en ;
#     dbo:director rsc:george_cukor,
#         rsc:sam_wood,
#         rsc:victor_fleming ;
#     wdt:P577 "1939-01-01"^^xsd:gYear .
#
# rsc:good_will_hunting a dbo:Film ;
#     rdfs:label "Good Will Hunting"@en ;
#     dbo:director rsc:gus_van_sant ;
#     wdt:P577 "1997-01-01"^^xsd:gYear .
#
# rsc:goodfellas a dbo:Film ;
#     rdfs:label "Goodfellas"@en ;
#     dbo:director rsc:martin_scorsese ;
#     wdt:P577 "1990-01-01"^^xsd:gYear .
#
# rsc:gran_torino a dbo:Film ;
#     rdfs:label "Gran Torino"@en ;
#     dbo:director rsc:clint_eastwood ;
#     wdt:P577 "2008-01-01"^^xsd:gYear .
#
# rsc:groundhog_day a dbo:Film ;
#     rdfs:label "Groundhog Day"@en ;
#     dbo:director rsc:harold_ramis ;
#     wdt:P577 "1993-01-01"^^xsd:gYear .
#
# rsc:guardians_of_the_galaxy a dbo:Film ;
#     rdfs:label "Guardians of the Galaxy"@en ;
#     dbo:director rsc:james_gunn ;
#     wdt:P577 "2014-01-01"^^xsd:gYear .
#
# rsc:guardians_of_the_galaxy_vol._2 a dbo:Film ;
#     rdfs:label "Guardians of the Galaxy Vol. 2"@en ;
#     dbo:director rsc:james_gunn ;
#     wdt:P577 "2017-01-01"^^xsd:gYear .
#
# <http://philip-broehl.org/resource/hachi:_a_dog's_tale> a dbo:Film ;
#     rdfs:label "Hachi: A Dog's Tale"@en ;
#     dbo:director <http://philip-broehl.org/resource/lasse_hallstrã¶m> ;
#     wdt:P577 "2009-01-01"^^xsd:gYear .
#
# rsc:hacksaw_ridge a dbo:Film ;
#     rdfs:label "Hacksaw Ridge"@en ;
#     dbo:director rsc:mel_gibson ;
#     wdt:P577 "2016-01-01"^^xsd:gYear .
#
# rsc:harry_potter_and_the_deathly_hallows:_part_2 a dbo:Film ;
#     rdfs:label "Harry Potter and the Deathly Hallows: Part 2"@en ;
#     dbo:director rsc:david_yates ;
#     wdt:P577 "2011-01-01"^^xsd:gYear .
#
# rsc:harvey a dbo:Film ;
#     rdfs:label "Harvey"@en ;
#     dbo:director rsc:henry_koster ;
#     wdt:P577 "1950-01-01"^^xsd:gYear .
#
# rsc:heat a dbo:Film ;
#     rdfs:label "Heat"@en ;
#     dbo:director rsc:michael_mann ;
#     wdt:P577 "1995-01-01"^^xsd:gYear .
#
# rsc:high_noon a dbo:Film ;
#     rdfs:label "High Noon"@en ;
#     dbo:director rsc:fred_zinnemann ;
#     wdt:P577 "1952-01-01"^^xsd:gYear .
#
# rsc:his_girl_friday a dbo:Film ;
#     rdfs:label "His Girl Friday"@en ;
#     dbo:director rsc:howard_hawks ;
#     wdt:P577 "1940-01-01"^^xsd:gYear .
#
# rsc:hotel_rwanda a dbo:Film ;
#     rdfs:label "Hotel Rwanda"@en ;
#     dbo:director rsc:terry_george ;
#     wdt:P577 "2004-01-01"^^xsd:gYear .
#
# rsc:how_to_train_your_dragon a dbo:Film ;
#     rdfs:label "How to Train Your Dragon"@en ;
#     dbo:director rsc:chris_sanders,
#         rsc:dean_deblois ;
#     wdt:P577 "2010-01-01"^^xsd:gYear .
#
# rsc:in_the_name_of_the_father a dbo:Film ;
#     rdfs:label "In the Name of the Father"@en ;
#     dbo:director rsc:jim_sheridan ;
#     wdt:P577 "1993-01-01"^^xsd:gYear .
#
# rsc:inception a dbo:Film ;
#     rdfs:label "Inception"@en ;
#     dbo:director rsc:christopher_nolan ;
#     wdt:P577 "2010-01-01"^^xsd:gYear .
#
# rsc:indiana_jones_and_the_last_crusade a dbo:Film ;
#     rdfs:label "Indiana Jones and the Last Crusade"@en ;
#     dbo:director rsc:steven_spielberg ;
#     wdt:P577 "1989-01-01"^^xsd:gYear .
#
# rsc:inglourious_basterds a dbo:Film ;
#     rdfs:label "Inglourious Basterds"@en ;
#     dbo:director rsc:eli_roth,
#         rsc:quentin_tarantino ;
#     wdt:P577 "2009-01-01"^^xsd:gYear .
#
# rsc:inside_out a dbo:Film ;
#     rdfs:label "Inside Out"@en ;
#     dbo:director rsc:pete_docter,
#         rsc:ronnie_del_carmen ;
#     wdt:P577 "2015-01-01"^^xsd:gYear .
#
# rsc:interstellar a dbo:Film ;
#     rdfs:label "Interstellar"@en ;
#     dbo:director rsc:christopher_nolan ;
#     wdt:P577 "2014-01-01"^^xsd:gYear .
#
# rsc:into_the_wild a dbo:Film ;
#     rdfs:label "Into the Wild"@en ;
#     dbo:director rsc:sean_penn ;
#     wdt:P577 "2007-01-01"^^xsd:gYear .
#
# <http://philip-broehl.org/resource/it's_a_wonderful_life> a dbo:Film ;
#     rdfs:label "It's a Wonderful Life"@en ;
#     dbo:director rsc:frank_capra ;
#     wdt:P577 "1946-01-01"^^xsd:gYear .
#
# rsc:it_happened_one_night a dbo:Film ;
#     rdfs:label "It Happened One Night"@en ;
#     dbo:director rsc:frank_capra ;
#     wdt:P577 "1934-01-01"^^xsd:gYear .
#
# rsc:jaws a dbo:Film ;
#     rdfs:label "Jaws"@en ;
#     dbo:director rsc:steven_spielberg ;
#     wdt:P577 "1975-01-01"^^xsd:gYear .
#
# rsc:jfk a dbo:Film ;
#     rdfs:label "JFK"@en ;
#     dbo:director rsc:oliver_stone ;
#     wdt:P577 "1991-01-01"^^xsd:gYear .
#
# rsc:judgment_at_nuremberg a dbo:Film ;
#     rdfs:label "Judgment at Nuremberg"@en ;
#     dbo:director rsc:stanley_kramer ;
#     wdt:P577 "1961-01-01"^^xsd:gYear .
#
# rsc:jurassic_park a dbo:Film ;
#     rdfs:label "Jurassic Park"@en ;
#     dbo:director rsc:steven_spielberg ;
#     wdt:P577 "1993-01-01"^^xsd:gYear .
#
# rsc:kill_bill:_vol._1 a dbo:Film ;
#     rdfs:label "Kill Bill: Vol. 1"@en ;
#     dbo:director rsc:quentin_tarantino ;
#     wdt:P577 "2003-01-01"^^xsd:gYear .
#
# rsc:kind_hearts_and_coronets a dbo:Film ;
#     rdfs:label "Kind Hearts and Coronets"@en ;
#     dbo:director rsc:robert_hamer ;
#     wdt:P577 "1949-01-01"^^xsd:gYear .
#
# rsc:l.a._confidential a dbo:Film ;
#     rdfs:label "L.A. Confidential"@en ;
#     dbo:director rsc:curtis_hanson ;
#     wdt:P577 "1997-01-01"^^xsd:gYear .
#
# rsc:la_la_land a dbo:Film ;
#     rdfs:label "La La Land"@en ;
#     dbo:director rsc:damien_chazelle ;
#     wdt:P577 "2016-01-01"^^xsd:gYear .
#
# rsc:laura a dbo:Film ;
#     rdfs:label "Laura"@en ;
#     dbo:director rsc:otto_preminger ;
#     wdt:P577 "1944-01-01"^^xsd:gYear .
#
# rsc:lawrence_of_arabia a dbo:Film ;
#     rdfs:label "Lawrence of Arabia"@en ;
#     dbo:director rsc:david_lean ;
#     wdt:P577 "1962-01-01"^^xsd:gYear .
#
# rsc:life_of_brian a dbo:Film ;
#     rdfs:label "Life of Brian"@en ;
#     dbo:director rsc:terry_jones ;
#     wdt:P577 "1979-01-01"^^xsd:gYear .
#
# rsc:lion a dbo:Film ;
#     rdfs:label "Lion"@en ;
#     dbo:director rsc:garth_davis ;
#     wdt:P577 "2016-01-01"^^xsd:gYear .
#
# <http://philip-broehl.org/resource/lock,_stock_and_two_smoking_barrels> a dbo:Film ;
#     rdfs:label "Lock, Stock and Two Smoking Barrels"@en ;
#     dbo:director rsc:guy_ritchie ;
#     wdt:P577 "1998-01-01"^^xsd:gYear .
#
# rsc:logan a dbo:Film ;
#     rdfs:label "Logan"@en ;
#     dbo:director rsc:james_mangold ;
#     wdt:P577 "2017-01-01"^^xsd:gYear .
#
# <http://philip-broehl.org/resource/lã©on:_the_professional> a dbo:Film ;
#     rdfs:label "LÃ©on: The Professional"@en ;
#     dbo:director rsc:luc_besson ;
#     wdt:P577 "1994-01-01"^^xsd:gYear .
#
# rsc:mad_max:_fury_road a dbo:Film ;
#     rdfs:label "Mad Max: Fury Road"@en ;
#     dbo:director rsc:george_miller ;
#     wdt:P577 "2015-01-01"^^xsd:gYear .
#
# rsc:magnolia a dbo:Film ;
#     rdfs:label "Magnolia"@en ;
#     dbo:director rsc:paul_thomas_anderson ;
#     wdt:P577 "1999-01-01"^^xsd:gYear .
#
# rsc:mary_and_max a dbo:Film ;
#     rdfs:label "Mary and Max"@en ;
#     dbo:director rsc:adam_elliot ;
#     wdt:P577 "2009-01-01"^^xsd:gYear .
#
# rsc:memento a dbo:Film ;
#     rdfs:label "Memento"@en ;
#     dbo:director rsc:christopher_nolan ;
#     wdt:P577 "2000-01-01"^^xsd:gYear .
#
# rsc:million_dollar_baby a dbo:Film ;
#     rdfs:label "Million Dollar Baby"@en ;
#     dbo:director rsc:clint_eastwood ;
#     wdt:P577 "2004-01-01"^^xsd:gYear .
#
# rsc:modern_times a dbo:Film ;
#     rdfs:label "Modern Times"@en ;
#     dbo:director rsc:charles_chaplin ;
#     wdt:P577 "1936-01-01"^^xsd:gYear .
#
# <http://philip-broehl.org/resource/monsters,_inc.> a dbo:Film ;
#     rdfs:label "Monsters, Inc."@en ;
#     dbo:director rsc:david_silverman,
#         rsc:lee_unkrich,
#         rsc:pete_docter ;
#     wdt:P577 "2001-01-01"^^xsd:gYear .
#
# rsc:monty_python_and_the_holy_grail a dbo:Film ;
#     rdfs:label "Monty Python and the Holy Grail"@en ;
#     dbo:director rsc:terry_gilliam,
#         rsc:terry_jones ;
#     wdt:P577 "1975-01-01"^^xsd:gYear .
#
# rsc:mr._smith_goes_to_washington a dbo:Film ;
#     rdfs:label "Mr. Smith Goes to Washington"@en ;
#     dbo:director rsc:frank_capra ;
#     wdt:P577 "1939-01-01"^^xsd:gYear .
#
# rsc:network a dbo:Film ;
#     rdfs:label "Network"@en ;
#     dbo:director rsc:sidney_lumet ;
#     wdt:P577 "1976-01-01"^^xsd:gYear .
#
# rsc:no_country_for_old_men a dbo:Film ;
#     rdfs:label "No Country for Old Men"@en ;
#     dbo:director rsc:ethan_coen,
#         rsc:joel_coen ;
#     wdt:P577 "2007-01-01"^^xsd:gYear .
#
# rsc:north_by_northwest a dbo:Film ;
#     rdfs:label "North by Northwest"@en ;
#     dbo:director rsc:alfred_hitchcock ;
#     wdt:P577 "1959-01-01"^^xsd:gYear .
#
# rsc:notorious a dbo:Film ;
#     rdfs:label "Notorious"@en ;
#     dbo:director rsc:alfred_hitchcock ;
#     wdt:P577 "1946-01-01"^^xsd:gYear .
#
# rsc:on_the_waterfront a dbo:Film ;
#     rdfs:label "On the Waterfront"@en ;
#     dbo:director rsc:elia_kazan ;
#     wdt:P577 "1954-01-01"^^xsd:gYear .
#
# rsc:once_upon_a_time_in_america a dbo:Film ;
#     rdfs:label "Once Upon a Time in America"@en ;
#     dbo:director rsc:sergio_leone ;
#     wdt:P577 "1984-01-01"^^xsd:gYear .
#
# <http://philip-broehl.org/resource/one_flew_over_the_cuckoo's_nest> a dbo:Film ;
#     rdfs:label "One Flew Over the Cuckoo's Nest"@en ;
#     dbo:director rsc:milos_forman ;
#     wdt:P577 "1975-01-01"^^xsd:gYear .
#
# rsc:out_of_the_past a dbo:Film ;
#     rdfs:label "Out of the Past"@en ;
#     dbo:director rsc:jacques_tourneur ;
#     wdt:P577 "1947-01-01"^^xsd:gYear .
#
# rsc:papillon a dbo:Film ;
#     rdfs:label "Papillon"@en ;
#     dbo:director rsc:franklin_j._schaffner ;
#     wdt:P577 "1973-01-01"^^xsd:gYear .
#
# <http://philip-broehl.org/resource/paris,_texas> a dbo:Film ;
#     rdfs:label "Paris, Texas"@en ;
#     dbo:director rsc:wim_wenders ;
#     wdt:P577 "1984-01-01"^^xsd:gYear .
#
# rsc:paths_of_glory a dbo:Film ;
#     rdfs:label "Paths of Glory"@en ;
#     dbo:director rsc:stanley_kubrick ;
#     wdt:P577 "1957-01-01"^^xsd:gYear .
#
# rsc:patton a dbo:Film ;
#     rdfs:label "Patton"@en ;
#     dbo:director rsc:franklin_j._schaffner ;
#     wdt:P577 "1970-01-01"^^xsd:gYear .
#
# rsc:pink_floyd:_the_wall a dbo:Film ;
#     rdfs:label "Pink Floyd: The Wall"@en ;
#     dbo:director rsc:alan_parker ;
#     wdt:P577 "1982-01-01"^^xsd:gYear .
#
# rsc:pirates_of_the_caribbean:_the_curse_of_the_black_pearl a dbo:Film ;
#     rdfs:label "Pirates of the Caribbean: The Curse of the Black Pearl"@en ;
#     dbo:director rsc:gore_verbinski ;
#     wdt:P577 "2003-01-01"^^xsd:gYear .
#
# rsc:platoon a dbo:Film ;
#     rdfs:label "Platoon"@en ;
#     dbo:director rsc:oliver_stone ;
#     wdt:P577 "1986-01-01"^^xsd:gYear .
#
# rsc:prisoners a dbo:Film ;
#     rdfs:label "Prisoners"@en ;
#     dbo:director rsc:denis_villeneuve ;
#     wdt:P577 "2013-01-01"^^xsd:gYear .
#
# rsc:psycho a dbo:Film ;
#     rdfs:label "Psycho"@en ;
#     dbo:director rsc:alfred_hitchcock ;
#     wdt:P577 "1960-01-01"^^xsd:gYear .
#
# rsc:pulp_fiction a dbo:Film ;
#     rdfs:label "Pulp Fiction"@en ;
#     dbo:director rsc:quentin_tarantino ;
#     wdt:P577 "1994-01-01"^^xsd:gYear .
#
# rsc:raging_bull a dbo:Film ;
#     rdfs:label "Raging Bull"@en ;
#     dbo:director rsc:martin_scorsese ;
#     wdt:P577 "1980-01-01"^^xsd:gYear .
#
# rsc:raiders_of_the_lost_ark a dbo:Film ;
#     rdfs:label "Raiders of the Lost Ark"@en ;
#     dbo:director rsc:steven_spielberg ;
#     wdt:P577 "1981-01-01"^^xsd:gYear .
#
# rsc:rain_man a dbo:Film ;
#     rdfs:label "Rain Man"@en ;
#     dbo:director rsc:barry_levinson ;
#     wdt:P577 "1988-01-01"^^xsd:gYear .
#
# rsc:rear_window a dbo:Film ;
#     rdfs:label "Rear Window"@en ;
#     dbo:director rsc:alfred_hitchcock ;
#     wdt:P577 "1954-01-01"^^xsd:gYear .
#
# rsc:rebecca a dbo:Film ;
#     rdfs:label "Rebecca"@en ;
#     dbo:director rsc:alfred_hitchcock ;
#     wdt:P577 "1940-01-01"^^xsd:gYear .
#
# rsc:requiem_for_a_dream a dbo:Film ;
#     rdfs:label "Requiem for a Dream"@en ;
#     dbo:director rsc:darren_aronofsky ;
#     wdt:P577 "2000-01-01"^^xsd:gYear .
#
# rsc:reservoir_dogs a dbo:Film ;
#     rdfs:label "Reservoir Dogs"@en ;
#     dbo:director rsc:quentin_tarantino ;
#     wdt:P577 "1992-01-01"^^xsd:gYear .
#
# rsc:rio_bravo a dbo:Film ;
#     rdfs:label "Rio Bravo"@en ;
#     dbo:director rsc:howard_hawks ;
#     wdt:P577 "1959-01-01"^^xsd:gYear .
#
# rsc:rocky a dbo:Film ;
#     rdfs:label "Rocky"@en ;
#     dbo:director rsc:john_g._avildsen ;
#     wdt:P577 "1976-01-01"^^xsd:gYear .
#
# rsc:roman_holiday a dbo:Film ;
#     rdfs:label "Roman Holiday"@en ;
#     dbo:director rsc:william_wyler ;
#     wdt:P577 "1953-01-01"^^xsd:gYear .
#
# rsc:room a dbo:Film ;
#     rdfs:label "Room"@en ;
#     dbo:director rsc:lenny_abrahamson ;
#     wdt:P577 "2015-01-01"^^xsd:gYear .
#
# rsc:rope a dbo:Film ;
#     rdfs:label "Rope"@en ;
#     dbo:director rsc:alfred_hitchcock ;
#     wdt:P577 "1948-01-01"^^xsd:gYear .
#
# rsc:rush a dbo:Film ;
#     rdfs:label "Rush"@en ;
#     dbo:director rsc:ron_howard ;
#     wdt:P577 "2013-01-01"^^xsd:gYear .
#
# rsc:saving_private_ryan a dbo:Film ;
#     rdfs:label "Saving Private Ryan"@en ;
#     dbo:director rsc:steven_spielberg ;
#     wdt:P577 "1998-01-01"^^xsd:gYear .
#
# rsc:scarface a dbo:Film ;
#     rdfs:label "Scarface"@en ;
#     dbo:director rsc:brian_de_palma ;
#     wdt:P577 "1983-01-01"^^xsd:gYear .
#
# <http://philip-broehl.org/resource/schindler's_list> a dbo:Film ;
#     rdfs:label "Schindler's List"@en ;
#     dbo:director rsc:steven_spielberg ;
#     wdt:P577 "1993-01-01"^^xsd:gYear .
#
# rsc:se7en a dbo:Film ;
#     rdfs:label "Se7en"@en ;
#     dbo:director rsc:david_fincher ;
#     wdt:P577 "1995-01-01"^^xsd:gYear .
#
# rsc:short_term_12 a dbo:Film ;
#     rdfs:label "Short Term 12"@en ;
#     dbo:director rsc:destin_daniel_cretton ;
#     wdt:P577 "2013-01-01"^^xsd:gYear .
#
# rsc:shutter_island a dbo:Film ;
#     rdfs:label "Shutter Island"@en ;
#     dbo:director rsc:martin_scorsese ;
#     wdt:P577 "2010-01-01"^^xsd:gYear .
#
# rsc:sin_city a dbo:Film ;
#     rdfs:label "Sin City"@en ;
#     dbo:director rsc:frank_miller,
#         rsc:quentin_tarantino,
#         rsc:robert_rodriguez ;
#     wdt:P577 "2005-01-01"^^xsd:gYear .
#
# <http://philip-broehl.org/resource/singin'_in_the_rain> a dbo:Film ;
#     rdfs:label "Singin' in the Rain"@en ;
#     dbo:director rsc:gene_kelly,
#         rsc:stanley_donen ;
#     wdt:P577 "1952-01-01"^^xsd:gYear .
#
# rsc:sleuth a dbo:Film ;
#     rdfs:label "Sleuth"@en ;
#     dbo:director rsc:joseph_l._mankiewicz ;
#     wdt:P577 "1972-01-01"^^xsd:gYear .
#
# rsc:sling_blade a dbo:Film ;
#     rdfs:label "Sling Blade"@en ;
#     dbo:director rsc:billy_bob_thornton ;
#     wdt:P577 "1996-01-01"^^xsd:gYear .
#
# rsc:slumdog_millionaire a dbo:Film ;
#     rdfs:label "Slumdog Millionaire"@en ;
#     dbo:director rsc:danny_boyle,
#         rsc:loveleen_tandan ;
#     wdt:P577 "2008-01-01"^^xsd:gYear .
#
# rsc:snatch a dbo:Film ;
#     rdfs:label "Snatch"@en ;
#     dbo:director rsc:guy_ritchie ;
#     wdt:P577 "2000-01-01"^^xsd:gYear .
#
# rsc:some_like_it_hot a dbo:Film ;
#     rdfs:label "Some Like It Hot"@en ;
#     dbo:director rsc:billy_wilder ;
#     wdt:P577 "1959-01-01"^^xsd:gYear .
#
# rsc:song_of_the_sea a dbo:Film ;
#     rdfs:label "Song of the Sea"@en ;
#     dbo:director rsc:tomm_moore ;
#     wdt:P577 "2014-01-01"^^xsd:gYear .
#
# rsc:spider-man:_homecoming a dbo:Film ;
#     rdfs:label "Spider-Man: Homecoming"@en ;
#     dbo:director rsc:jon_watts ;
#     wdt:P577 "2017-01-01"^^xsd:gYear .
#
# rsc:spotlight a dbo:Film ;
#     rdfs:label "Spotlight"@en ;
#     dbo:director rsc:tom_mccarthy ;
#     wdt:P577 "2015-01-01"^^xsd:gYear .
#
# rsc:stalag_17 a dbo:Film ;
#     rdfs:label "Stalag 17"@en ;
#     dbo:director rsc:billy_wilder ;
#     wdt:P577 "1953-01-01"^^xsd:gYear .
#
# rsc:stand_by_me a dbo:Film ;
#     rdfs:label "Stand by Me"@en ;
#     dbo:director rsc:rob_reiner ;
#     wdt:P577 "1986-01-01"^^xsd:gYear .
#
# rsc:star_wars:_episode_iv_-_a_new_hope a dbo:Film ;
#     rdfs:label "Star Wars: Episode IV - A New Hope"@en ;
#     dbo:director rsc:george_lucas ;
#     wdt:P577 "1977-01-01"^^xsd:gYear .
#
# rsc:star_wars:_episode_v_-_the_empire_strikes_back a dbo:Film ;
#     rdfs:label "Star Wars: Episode V - The Empire Strikes Back"@en ;
#     dbo:director rsc:irvin_kershner ;
#     wdt:P577 "1980-01-01"^^xsd:gYear .
#
# rsc:star_wars:_episode_vi_-_return_of_the_jedi a dbo:Film ;
#     rdfs:label "Star Wars: Episode VI - Return of the Jedi"@en ;
#     dbo:director rsc:richard_marquand ;
#     wdt:P577 "1983-01-01"^^xsd:gYear .
#
# rsc:star_wars:_the_force_awakens a dbo:Film ;
#     rdfs:label "Star Wars: The Force Awakens"@en ;
#     dbo:director rsc:j.j._abrams ;
#     wdt:P577 "2015-01-01"^^xsd:gYear .
#
# rsc:strangers_on_a_train a dbo:Film ;
#     rdfs:label "Strangers on a Train"@en ;
#     dbo:director rsc:alfred_hitchcock ;
#     wdt:P577 "1951-01-01"^^xsd:gYear .
#
# rsc:sunset_boulevard a dbo:Film ;
#     rdfs:label "Sunset Boulevard"@en ;
#     dbo:director rsc:billy_wilder ;
#     wdt:P577 "1950-01-01"^^xsd:gYear .
#
# rsc:taxi_driver a dbo:Film ;
#     rdfs:label "Taxi Driver"@en ;
#     dbo:director rsc:martin_scorsese ;
#     wdt:P577 "1976-01-01"^^xsd:gYear .
#
# rsc:terminator_2:_judgment_day a dbo:Film ;
#     rdfs:label "Terminator 2: Judgment Day"@en ;
#     dbo:director rsc:james_cameron ;
#     wdt:P577 "1991-01-01"^^xsd:gYear .
#
# rsc:the_apartment a dbo:Film ;
#     rdfs:label "The Apartment"@en ;
#     dbo:director rsc:billy_wilder ;
#     wdt:P577 "1960-01-01"^^xsd:gYear .
#
# rsc:the_avengers a dbo:Film ;
#     rdfs:label "The Avengers"@en ;
#     dbo:director rsc:joss_whedon ;
#     wdt:P577 "2012-01-01"^^xsd:gYear .
#
# rsc:the_best_years_of_our_lives a dbo:Film ;
#     rdfs:label "The Best Years of Our Lives"@en ;
#     dbo:director rsc:william_wyler ;
#     wdt:P577 "1946-01-01"^^xsd:gYear .
#
# rsc:the_big_lebowski a dbo:Film ;
#     rdfs:label "The Big Lebowski"@en ;
#     dbo:director rsc:ethan_coen,
#         rsc:joel_coen ;
#     wdt:P577 "1998-01-01"^^xsd:gYear .
#
# rsc:the_big_sleep a dbo:Film ;
#     rdfs:label "The Big Sleep"@en ;
#     dbo:director rsc:howard_hawks ;
#     wdt:P577 "1946-01-01"^^xsd:gYear .
#
# rsc:the_bourne_ultimatum a dbo:Film ;
#     rdfs:label "The Bourne Ultimatum"@en ;
#     dbo:director rsc:paul_greengrass ;
#     wdt:P577 "2007-01-01"^^xsd:gYear .
#
# rsc:the_bridge_on_the_river_kwai a dbo:Film ;
#     rdfs:label "The Bridge on the River Kwai"@en ;
#     dbo:director rsc:david_lean ;
#     wdt:P577 "1957-01-01"^^xsd:gYear .
#
# rsc:the_dark_knight a dbo:Film ;
#     rdfs:label "The Dark Knight"@en ;
#     dbo:director rsc:christopher_nolan ;
#     wdt:P577 "2008-01-01"^^xsd:gYear .
#
# rsc:the_dark_knight_rises a dbo:Film ;
#     rdfs:label "The Dark Knight Rises"@en ;
#     dbo:director rsc:christopher_nolan ;
#     wdt:P577 "2012-01-01"^^xsd:gYear .
#
# rsc:the_deer_hunter a dbo:Film ;
#     rdfs:label "The Deer Hunter"@en ;
#     dbo:director rsc:michael_cimino ;
#     wdt:P577 "1978-01-01"^^xsd:gYear .
#
# rsc:the_departed a dbo:Film ;
#     rdfs:label "The Departed"@en ;
#     dbo:director rsc:martin_scorsese ;
#     wdt:P577 "2006-01-01"^^xsd:gYear .
#
# rsc:the_elephant_man a dbo:Film ;
#     rdfs:label "The Elephant Man"@en ;
#     dbo:director rsc:david_lynch ;
#     wdt:P577 "1980-01-01"^^xsd:gYear .
#
# rsc:the_exorcist a dbo:Film ;
#     rdfs:label "The Exorcist"@en ;
#     dbo:director rsc:william_friedkin ;
#     wdt:P577 "1973-01-01"^^xsd:gYear .
#
# rsc:the_general a dbo:Film ;
#     rdfs:label "The General"@en ;
#     dbo:director rsc:buster_keaton,
#         rsc:clyde_bruckman ;
#     wdt:P577 "1926-01-01"^^xsd:gYear .
#
# rsc:the_godfather a dbo:Film ;
#     rdfs:label "The Godfather"@en ;
#     dbo:director rsc:francis_ford_coppola ;
#     wdt:P577 "1972-01-01"^^xsd:gYear .
#
# rsc:the_godfather:_part_ii a dbo:Film ;
#     rdfs:label "The Godfather: Part II"@en ;
#     dbo:director rsc:francis_ford_coppola ;
#     wdt:P577 "1974-01-01"^^xsd:gYear .
#
# rsc:the_gold_rush a dbo:Film ;
#     rdfs:label "The Gold Rush"@en ;
#     dbo:director rsc:charles_chaplin ;
#     wdt:P577 "1925-01-01"^^xsd:gYear .
#
# rsc:the_graduate a dbo:Film ;
#     rdfs:label "The Graduate"@en ;
#     dbo:director rsc:mike_nichols ;
#     wdt:P577 "1967-01-01"^^xsd:gYear .
#
# rsc:the_grand_budapest_hotel a dbo:Film ;
#     rdfs:label "The Grand Budapest Hotel"@en ;
#     dbo:director rsc:wes_anderson ;
#     wdt:P577 "2014-01-01"^^xsd:gYear .
#
# rsc:the_grapes_of_wrath a dbo:Film ;
#     rdfs:label "The Grapes of Wrath"@en ;
#     dbo:director rsc:john_ford ;
#     wdt:P577 "1940-01-01"^^xsd:gYear .
#
# rsc:the_great_dictator a dbo:Film ;
#     rdfs:label "The Great Dictator"@en ;
#     dbo:director rsc:charles_chaplin ;
#     wdt:P577 "1940-01-01"^^xsd:gYear .
#
# rsc:the_great_escape a dbo:Film ;
#     rdfs:label "The Great Escape"@en ;
#     dbo:director rsc:john_sturges ;
#     wdt:P577 "1963-01-01"^^xsd:gYear .
#
# rsc:the_green_mile a dbo:Film ;
#     rdfs:label "The Green Mile"@en ;
#     dbo:director rsc:frank_darabont ;
#     wdt:P577 "1999-01-01"^^xsd:gYear .
#
# rsc:the_help a dbo:Film ;
#     rdfs:label "The Help"@en ;
#     dbo:director rsc:tate_taylor ;
#     wdt:P577 "2011-01-01"^^xsd:gYear .
#
# rsc:the_hustler a dbo:Film ;
#     rdfs:label "The Hustler"@en ;
#     dbo:director rsc:robert_rossen ;
#     wdt:P577 "1961-01-01"^^xsd:gYear .
#
# rsc:the_imitation_game a dbo:Film ;
#     rdfs:label "The Imitation Game"@en ;
#     dbo:director rsc:morten_tyldum ;
#     wdt:P577 "2014-01-01"^^xsd:gYear .
#
# rsc:the_kid a dbo:Film ;
#     rdfs:label "The Kid"@en ;
#     dbo:director rsc:charles_chaplin ;
#     wdt:P577 "1921-01-01"^^xsd:gYear .
#
# rsc:the_killing a dbo:Film ;
#     rdfs:label "The Killing"@en ;
#     dbo:director rsc:stanley_kubrick ;
#     wdt:P577 "1956-01-01"^^xsd:gYear .
#
# <http://philip-broehl.org/resource/the_king's_speech> a dbo:Film ;
#     rdfs:label "The King's Speech"@en ;
#     dbo:director rsc:tom_hooper ;
#     wdt:P577 "2010-01-01"^^xsd:gYear .
#
# rsc:the_last_picture_show a dbo:Film ;
#     rdfs:label "The Last Picture Show"@en ;
#     dbo:director rsc:peter_bogdanovich ;
#     wdt:P577 "1971-01-01"^^xsd:gYear .
#
# rsc:the_legend_of_1900 a dbo:Film ;
#     rdfs:label "The Legend of 1900"@en ;
#     dbo:director rsc:giuseppe_tornatore ;
#     wdt:P577 "1998-01-01"^^xsd:gYear .
#
# rsc:the_lion_king a dbo:Film ;
#     rdfs:label "The Lion King"@en ;
#     dbo:director rsc:rob_minkoff,
#         rsc:roger_allers ;
#     wdt:P577 "1994-01-01"^^xsd:gYear .
#
# rsc:the_lord_of_the_rings:_the_fellowship_of_the_ring a dbo:Film ;
#     rdfs:label "The Lord of the Rings: The Fellowship of the Ring"@en ;
#     dbo:director rsc:peter_jackson ;
#     wdt:P577 "2001-01-01"^^xsd:gYear .
#
# rsc:the_lord_of_the_rings:_the_return_of_the_king a dbo:Film ;
#     rdfs:label "The Lord of the Rings: The Return of the King"@en ;
#     dbo:director rsc:peter_jackson ;
#     wdt:P577 "2003-01-01"^^xsd:gYear .
#
# rsc:the_lord_of_the_rings:_the_two_towers a dbo:Film ;
#     rdfs:label "The Lord of the Rings: The Two Towers"@en ;
#     dbo:director rsc:peter_jackson ;
#     wdt:P577 "2002-01-01"^^xsd:gYear .
#
# rsc:the_lost_weekend a dbo:Film ;
#     rdfs:label "The Lost Weekend"@en ;
#     dbo:director rsc:billy_wilder ;
#     wdt:P577 "1945-01-01"^^xsd:gYear .
#
# rsc:the_maltese_falcon a dbo:Film ;
#     rdfs:label "The Maltese Falcon"@en ;
#     dbo:director rsc:john_huston ;
#     wdt:P577 "1941-01-01"^^xsd:gYear .
#
# rsc:the_man_who_shot_liberty_valance a dbo:Film ;
#     rdfs:label "The Man Who Shot Liberty Valance"@en ;
#     dbo:director rsc:john_ford ;
#     wdt:P577 "1962-01-01"^^xsd:gYear .
#
# rsc:the_manchurian_candidate a dbo:Film ;
#     rdfs:label "The Manchurian Candidate"@en ;
#     dbo:director rsc:john_frankenheimer ;
#     wdt:P577 "1962-01-01"^^xsd:gYear .
#
# rsc:the_martian a dbo:Film ;
#     rdfs:label "The Martian"@en ;
#     dbo:director rsc:ridley_scott ;
#     wdt:P577 "2015-01-01"^^xsd:gYear .
#
# rsc:the_matrix a dbo:Film ;
#     rdfs:label "The Matrix"@en ;
#     dbo:director rsc:lana_wachowski,
#         rsc:lilly_wachowski ;
#     wdt:P577 "1999-01-01"^^xsd:gYear .
#
# rsc:the_message a dbo:Film ;
#     rdfs:label "The Message"@en ;
#     dbo:director rsc:moustapha_akkad ;
#     wdt:P577 "1976-01-01"^^xsd:gYear .
#
# rsc:the_night_of_the_hunter a dbo:Film ;
#     rdfs:label "The Night of the Hunter"@en ;
#     dbo:director rsc:charles_laughton ;
#     wdt:P577 "1955-01-01"^^xsd:gYear .
#
# rsc:the_nightmare_before_christmas a dbo:Film ;
#     rdfs:label "The Nightmare Before Christmas"@en ;
#     dbo:director rsc:henry_selick ;
#     wdt:P577 "1993-01-01"^^xsd:gYear .
#
# rsc:the_philadelphia_story a dbo:Film ;
#     rdfs:label "The Philadelphia Story"@en ;
#     dbo:director rsc:george_cukor ;
#     wdt:P577 "1940-01-01"^^xsd:gYear .
#
# rsc:the_pianist a dbo:Film ;
#     rdfs:label "The Pianist"@en ;
#     dbo:director rsc:roman_polanski ;
#     wdt:P577 "2002-01-01"^^xsd:gYear .
#
# rsc:the_prestige a dbo:Film ;
#     rdfs:label "The Prestige"@en ;
#     dbo:director rsc:christopher_nolan ;
#     wdt:P577 "2006-01-01"^^xsd:gYear .
#
# rsc:the_princess_bride a dbo:Film ;
#     rdfs:label "The Princess Bride"@en ;
#     dbo:director rsc:rob_reiner ;
#     wdt:P577 "1987-01-01"^^xsd:gYear .
#
# rsc:the_revenant a dbo:Film ;
#     rdfs:label "The Revenant"@en ;
#     dbo:director <http://philip-broehl.org/resource/alejandro_gonzã¡lez_iã±ã¡rritu> ;
#     wdt:P577 "2015-01-01"^^xsd:gYear .
#
# rsc:the_shawshank_redemption a dbo:Film ;
#     rdfs:label "The Shawshank Redemption"@en ;
#     dbo:director rsc:frank_darabont ;
#     wdt:P577 "1994-01-01"^^xsd:gYear .
#
# rsc:the_shining a dbo:Film ;
#     rdfs:label "The Shining"@en ;
#     dbo:director rsc:stanley_kubrick ;
#     wdt:P577 "1980-01-01"^^xsd:gYear .
#
# rsc:the_silence_of_the_lambs a dbo:Film ;
#     rdfs:label "The Silence of the Lambs"@en ;
#     dbo:director rsc:jonathan_demme ;
#     wdt:P577 "1991-01-01"^^xsd:gYear .
#
# rsc:the_sixth_sense a dbo:Film ;
#     rdfs:label "The Sixth Sense"@en ;
#     dbo:director rsc:m._night_shyamalan ;
#     wdt:P577 "1999-01-01"^^xsd:gYear .
#
# rsc:the_sting a dbo:Film ;
#     rdfs:label "The Sting"@en ;
#     dbo:director rsc:george_roy_hill ;
#     wdt:P577 "1973-01-01"^^xsd:gYear .
#
# rsc:the_straight_story a dbo:Film ;
#     rdfs:label "The Straight Story"@en ;
#     dbo:director rsc:david_lynch ;
#     wdt:P577 "1999-01-01"^^xsd:gYear .
#
# rsc:the_terminator a dbo:Film ;
#     rdfs:label "The Terminator"@en ;
#     dbo:director rsc:james_cameron ;
#     wdt:P577 "1984-01-01"^^xsd:gYear .
#
# rsc:the_thing a dbo:Film ;
#     rdfs:label "The Thing"@en ;
#     dbo:director rsc:john_carpenter ;
#     wdt:P577 "1982-01-01"^^xsd:gYear .
#
# rsc:the_third_man a dbo:Film ;
#     rdfs:label "The Third Man"@en ;
#     dbo:director rsc:carol_reed ;
#     wdt:P577 "1949-01-01"^^xsd:gYear .
#
# rsc:the_treasure_of_the_sierra_madre a dbo:Film ;
#     rdfs:label "The Treasure of the Sierra Madre"@en ;
#     dbo:director rsc:john_huston ;
#     wdt:P577 "1948-01-01"^^xsd:gYear .
#
# rsc:the_truman_show a dbo:Film ;
#     rdfs:label "The Truman Show"@en ;
#     dbo:director rsc:peter_weir ;
#     wdt:P577 "1998-01-01"^^xsd:gYear .
#
# rsc:the_usual_suspects a dbo:Film ;
#     rdfs:label "The Usual Suspects"@en ;
#     dbo:director rsc:bryan_singer ;
#     wdt:P577 "1995-01-01"^^xsd:gYear .
#
# rsc:the_wild_bunch a dbo:Film ;
#     rdfs:label "The Wild Bunch"@en ;
#     dbo:director rsc:sam_peckinpah ;
#     wdt:P577 "1969-01-01"^^xsd:gYear .
#
# rsc:the_wizard_of_oz a dbo:Film ;
#     rdfs:label "The Wizard of Oz"@en ;
#     dbo:director rsc:george_cukor,
#         rsc:king_vidor,
#         rsc:mervyn_leroy,
#         rsc:norman_taurog,
#         rsc:victor_fleming ;
#     wdt:P577 "1939-01-01"^^xsd:gYear .
#
# rsc:the_wolf_of_wall_street a dbo:Film ;
#     rdfs:label "The Wolf of Wall Street"@en ;
#     dbo:director rsc:martin_scorsese ;
#     wdt:P577 "2013-01-01"^^xsd:gYear .
#
# rsc:there_will_be_blood a dbo:Film ;
#     rdfs:label "There Will Be Blood"@en ;
#     dbo:director rsc:paul_thomas_anderson ;
#     wdt:P577 "2007-01-01"^^xsd:gYear .
#
# rsc:to_kill_a_mockingbird a dbo:Film ;
#     rdfs:label "To Kill a Mockingbird"@en ;
#     dbo:director rsc:robert_mulligan ;
#     wdt:P577 "1962-01-01"^^xsd:gYear .
#
# rsc:touch_of_evil a dbo:Film ;
#     rdfs:label "Touch of Evil"@en ;
#     dbo:director rsc:orson_welles ;
#     wdt:P577 "1958-01-01"^^xsd:gYear .
#
# rsc:toy_story a dbo:Film ;
#     rdfs:label "Toy Story"@en ;
#     dbo:director rsc:john_lasseter ;
#     wdt:P577 "1995-01-01"^^xsd:gYear .
#
# rsc:toy_story_3 a dbo:Film ;
#     rdfs:label "Toy Story 3"@en ;
#     dbo:director rsc:lee_unkrich ;
#     wdt:P577 "2010-01-01"^^xsd:gYear .
#
# rsc:trainspotting a dbo:Film ;
#     rdfs:label "Trainspotting"@en ;
#     dbo:director rsc:danny_boyle ;
#     wdt:P577 "1996-01-01"^^xsd:gYear .
#
# rsc:twelve_monkeys a dbo:Film ;
#     rdfs:label "Twelve Monkeys"@en ;
#     dbo:director rsc:terry_gilliam ;
#     wdt:P577 "1995-01-01"^^xsd:gYear .
#
# rsc:unforgiven a dbo:Film ;
#     rdfs:label "Unforgiven"@en ;
#     dbo:director rsc:clint_eastwood ;
#     wdt:P577 "1992-01-01"^^xsd:gYear .
#
# rsc:up a dbo:Film ;
#     rdfs:label "Up"@en ;
#     dbo:director rsc:bob_peterson,
#         rsc:pete_docter ;
#     wdt:P577 "2009-01-01"^^xsd:gYear .
#
# rsc:v_for_vendetta a dbo:Film ;
#     rdfs:label "V for Vendetta"@en ;
#     dbo:director rsc:james_mcteigue ;
#     wdt:P577 "2005-01-01"^^xsd:gYear .
#
# rsc:vertigo a dbo:Film ;
#     rdfs:label "Vertigo"@en ;
#     dbo:director rsc:alfred_hitchcock ;
#     wdt:P577 "1958-01-01"^^xsd:gYear .
#
# rsc:wallâ·e a dbo:Film ;
#     rdfs:label "WALLÂ·E"@en ;
#     dbo:director rsc:andrew_stanton ;
#     wdt:P577 "2008-01-01"^^xsd:gYear .
#
# rsc:warrior a dbo:Film ;
#     rdfs:label "Warrior"@en ;
#     dbo:director <http://philip-broehl.org/resource/gavin_o'connor> ;
#     wdt:P577 "2011-01-01"^^xsd:gYear .
#
# <http://philip-broehl.org/resource/what_ever_happened_to_baby_jane?> a dbo:Film ;
#     rdfs:label "What Ever Happened to Baby Jane?"@en ;
#     dbo:director rsc:robert_aldrich ;
#     wdt:P577 "1962-01-01"^^xsd:gYear .
#
# rsc:whiplash a dbo:Film ;
#     rdfs:label "Whiplash"@en ;
#     dbo:director rsc:damien_chazelle ;
#     wdt:P577 "2014-01-01"^^xsd:gYear .
#
# <http://philip-broehl.org/resource/who's_afraid_of_virginia_woolf?> a dbo:Film ;
#     rdfs:label "Who's Afraid of Virginia Woolf?"@en ;
#     dbo:director rsc:mike_nichols ;
#     wdt:P577 "1966-01-01"^^xsd:gYear .
#
# rsc:witness_for_the_prosecution a dbo:Film ;
#     rdfs:label "Witness for the Prosecution"@en ;
#     dbo:director rsc:billy_wilder ;
#     wdt:P577 "1957-01-01"^^xsd:gYear .
#
# rsc:young_frankenstein a dbo:Film ;
#     rdfs:label "Young Frankenstein"@en ;
#     dbo:director rsc:mel_brooks ;
#     wdt:P577 "1974-01-01"^^xsd:gYear .
#
# rsc:zootopia a dbo:Film ;
#     rdfs:label "Zootopia"@en ;
#     dbo:director rsc:byron_howard,
#         rsc:jared_bush,
#         rsc:rich_moore ;
#     wdt:P577 "2016-01-01"^^xsd:gYear .
#
# rsc:adam_elliot a dbo:Person ;
#     foaf:name "Adam Elliot"@en .
#
# rsc:alan_parker a dbo:Person ;
#     foaf:name "Alan Parker"@en .
#
# <http://philip-broehl.org/resource/alejandro_gonzã¡lez_iã±ã¡rritu> a dbo:Person ;
#     foaf:name "Alejandro GonzÃ¡lez IÃ±Ã¡rritu"@en .
#
# rsc:barry_levinson a dbo:Person ;
#     foaf:name "Barry Levinson"@en .
#
# rsc:billy_bob_thornton a dbo:Person ;
#     foaf:name "Billy Bob Thornton"@en .
#
# rsc:bob_clark a dbo:Person ;
#     foaf:name "Bob Clark"@en .
#
# rsc:bob_peterson a dbo:Person ;
#     foaf:name "Bob Peterson"@en .
#
# rsc:brian_de_palma a dbo:Person ;
#     foaf:name "Brian De Palma"@en .
#
# rsc:bryan_singer a dbo:Person ;
#     foaf:name "Bryan Singer"@en .
#
# rsc:buster_keaton a dbo:Person ;
#     foaf:name "Buster Keaton"@en .
#
# rsc:byron_howard a dbo:Person ;
#     foaf:name "Byron Howard"@en .
#
# rsc:carol_reed a dbo:Person ;
#     foaf:name "Carol Reed"@en .
#
# rsc:charles_laughton a dbo:Person ;
#     foaf:name "Charles Laughton"@en .
#
# rsc:chris_sanders a dbo:Person ;
#     foaf:name "Chris Sanders"@en .
#
# rsc:clyde_bruckman a dbo:Person ;
#     foaf:name "Clyde Bruckman"@en .
#
# rsc:curtis_hanson a dbo:Person ;
#     foaf:name "Curtis Hanson"@en .
#
# rsc:darren_aronofsky a dbo:Person ;
#     foaf:name "Darren Aronofsky"@en .
#
# rsc:david_silverman a dbo:Person ;
#     foaf:name "David Silverman"@en .
#
# rsc:david_yates a dbo:Person ;
#     foaf:name "David Yates"@en .
#
# rsc:dean_deblois a dbo:Person ;
#     foaf:name "Dean DeBlois"@en .
#
# rsc:denis_villeneuve a dbo:Person ;
#     foaf:name "Denis Villeneuve"@en .
#
# rsc:destin_daniel_cretton a dbo:Person ;
#     foaf:name "Destin Daniel Cretton"@en .
#
# rsc:edgar_wright a dbo:Person ;
#     foaf:name "Edgar Wright"@en .
#
# rsc:edmund_goulding a dbo:Person ;
#     foaf:name "Edmund Goulding"@en .
#
# rsc:edward_zwick a dbo:Person ;
#     foaf:name "Edward Zwick"@en .
#
# rsc:eli_roth a dbo:Person ;
#     foaf:name "Eli Roth"@en .
#
# rsc:frank_miller a dbo:Person ;
#     foaf:name "Frank Miller"@en .
#
# rsc:fred_zinnemann a dbo:Person ;
#     foaf:name "Fred Zinnemann"@en .
#
# rsc:garth_davis a dbo:Person ;
#     foaf:name "Garth Davis"@en .
#
# rsc:gary_trousdale a dbo:Person ;
#     foaf:name "Gary Trousdale"@en .
#
# <http://philip-broehl.org/resource/gavin_o'connor> a dbo:Person ;
#     foaf:name "Gavin O'Connor"@en .
#
# rsc:gene_kelly a dbo:Person ;
#     foaf:name "Gene Kelly"@en .
#
# rsc:george_lucas a dbo:Person ;
#     foaf:name "George Lucas"@en .
#
# rsc:george_miller a dbo:Person ;
#     foaf:name "George Miller"@en .
#
# rsc:giuseppe_tornatore a dbo:Person ;
#     foaf:name "Giuseppe Tornatore"@en .
#
# rsc:gore_verbinski a dbo:Person ;
#     foaf:name "Gore Verbinski"@en .
#
# rsc:gus_van_sant a dbo:Person ;
#     foaf:name "Gus Van Sant"@en .
#
# rsc:harold_ramis a dbo:Person ;
#     foaf:name "Harold Ramis"@en .
#
# rsc:henry_koster a dbo:Person ;
#     foaf:name "Henry Koster"@en .
#
# rsc:henry_selick a dbo:Person ;
#     foaf:name "Henry Selick"@en .
#
# rsc:irvin_kershner a dbo:Person ;
#     foaf:name "Irvin Kershner"@en .
#
# rsc:j.j._abrams a dbo:Person ;
#     foaf:name "J.J. Abrams"@en .
#
# rsc:jacques_tourneur a dbo:Person ;
#     foaf:name "Jacques Tourneur"@en .
#
# rsc:james_mangold a dbo:Person ;
#     foaf:name "James Mangold"@en .
#
# rsc:james_mcteigue a dbo:Person ;
#     foaf:name "James McTeigue"@en .
#
# rsc:jared_bush a dbo:Person ;
#     foaf:name "Jared Bush"@en .
#
# rsc:jim_sheridan a dbo:Person ;
#     foaf:name "Jim Sheridan"@en .
#
# rsc:john_carpenter a dbo:Person ;
#     foaf:name "John Carpenter"@en .
#
# rsc:john_frankenheimer a dbo:Person ;
#     foaf:name "John Frankenheimer"@en .
#
# rsc:john_g._avildsen a dbo:Person ;
#     foaf:name "John G. Avildsen"@en .
#
# rsc:john_lasseter a dbo:Person ;
#     foaf:name "John Lasseter"@en .
#
# rsc:john_mctiernan a dbo:Person ;
#     foaf:name "John McTiernan"@en .
#
# rsc:john_musker a dbo:Person ;
#     foaf:name "John Musker"@en .
#
# rsc:john_sturges a dbo:Person ;
#     foaf:name "John Sturges"@en .
#
# rsc:jon_watts a dbo:Person ;
#     foaf:name "Jon Watts"@en .
#
# rsc:jonathan_demme a dbo:Person ;
#     foaf:name "Jonathan Demme"@en .
#
# rsc:joss_whedon a dbo:Person ;
#     foaf:name "Joss Whedon"@en .
#
# rsc:king_vidor a dbo:Person ;
#     foaf:name "King Vidor"@en .
#
# rsc:kirk_wise a dbo:Person ;
#     foaf:name "Kirk Wise"@en .
#
# rsc:lana_wachowski a dbo:Person ;
#     foaf:name "Lana Wachowski"@en .
#
# rsc:lars_von_trier a dbo:Person ;
#     foaf:name "Lars von Trier"@en .
#
# <http://philip-broehl.org/resource/lasse_hallstrã¶m> a dbo:Person ;
#     foaf:name "Lasse HallstrÃ¶m"@en .
#
# rsc:lenny_abrahamson a dbo:Person ;
#     foaf:name "Lenny Abrahamson"@en .
#
# rsc:lewis_milestone a dbo:Person ;
#     foaf:name "Lewis Milestone"@en .
#
# rsc:lilly_wachowski a dbo:Person ;
#     foaf:name "Lilly Wachowski"@en .
#
# rsc:loveleen_tandan a dbo:Person ;
#     foaf:name "Loveleen Tandan"@en .
#
# rsc:luc_besson a dbo:Person ;
#     foaf:name "Luc Besson"@en .
#
# rsc:m._night_shyamalan a dbo:Person ;
#     foaf:name "M. Night Shyamalan"@en .
#
# rsc:mel_brooks a dbo:Person ;
#     foaf:name "Mel Brooks"@en .
#
# rsc:mervyn_leroy a dbo:Person ;
#     foaf:name "Mervyn LeRoy"@en .
#
# rsc:michael_cimino a dbo:Person ;
#     foaf:name "Michael Cimino"@en .
#
# rsc:michael_curtiz a dbo:Person ;
#     foaf:name "Michael Curtiz"@en .
#
# rsc:michael_mann a dbo:Person ;
#     foaf:name "Michael Mann"@en .
#
# rsc:michel_gondry a dbo:Person ;
#     foaf:name "Michel Gondry"@en .
#
# rsc:morten_tyldum a dbo:Person ;
#     foaf:name "Morten Tyldum"@en .
#
# rsc:moustapha_akkad a dbo:Person ;
#     foaf:name "Moustapha Akkad"@en .
#
# rsc:norman_taurog a dbo:Person ;
#     foaf:name "Norman Taurog"@en .
#
# rsc:paul_greengrass a dbo:Person ;
#     foaf:name "Paul Greengrass"@en .
#
# rsc:peter_bogdanovich a dbo:Person ;
#     foaf:name "Peter Bogdanovich"@en .
#
# rsc:rich_moore a dbo:Person ;
#     foaf:name "Rich Moore"@en .
#
# rsc:richard_attenborough a dbo:Person ;
#     foaf:name "Richard Attenborough"@en .
#
# rsc:richard_brooks a dbo:Person ;
#     foaf:name "Richard Brooks"@en .
#
# rsc:richard_kelly a dbo:Person ;
#     foaf:name "Richard Kelly"@en .
#
# rsc:richard_marquand a dbo:Person ;
#     foaf:name "Richard Marquand"@en .
#
# rsc:rob_minkoff a dbo:Person ;
#     foaf:name "Rob Minkoff"@en .
#
# rsc:robert_aldrich a dbo:Person ;
#     foaf:name "Robert Aldrich"@en .
#
# rsc:robert_hamer a dbo:Person ;
#     foaf:name "Robert Hamer"@en .
#
# rsc:robert_mulligan a dbo:Person ;
#     foaf:name "Robert Mulligan"@en .
#
# rsc:robert_rodriguez a dbo:Person ;
#     foaf:name "Robert Rodriguez"@en .
#
# rsc:robert_rossen a dbo:Person ;
#     foaf:name "Robert Rossen"@en .
#
# rsc:roger_allers a dbo:Person ;
#     foaf:name "Roger Allers"@en .
#
# rsc:ron_clements a dbo:Person ;
#     foaf:name "Ron Clements"@en .
#
# rsc:ronnie_del_carmen a dbo:Person ;
#     foaf:name "Ronnie Del Carmen"@en .
#
# rsc:sam_mendes a dbo:Person ;
#     foaf:name "Sam Mendes"@en .
#
# rsc:sam_peckinpah a dbo:Person ;
#     foaf:name "Sam Peckinpah"@en .
#
# rsc:sean_penn a dbo:Person ;
#     foaf:name "Sean Penn"@en .
#
# rsc:sergio_leone a dbo:Person ;
#     foaf:name "Sergio Leone"@en .
#
# rsc:stanley_donen a dbo:Person ;
#     foaf:name "Stanley Donen"@en .
#
# rsc:stanley_kramer a dbo:Person ;
#     foaf:name "Stanley Kramer"@en .
#
# rsc:steve_mcqueen a dbo:Person ;
#     foaf:name "Steve McQueen"@en .
#
# rsc:stuart_rosenberg a dbo:Person ;
#     foaf:name "Stuart Rosenberg"@en .
#
# rsc:tate_taylor a dbo:Person ;
#     foaf:name "Tate Taylor"@en .
#
# rsc:terry_george a dbo:Person ;
#     foaf:name "Terry George"@en .
#
# rsc:tim_burton a dbo:Person ;
#     foaf:name "Tim Burton"@en .
#
# rsc:tim_miller a dbo:Person ;
#     foaf:name "Tim Miller"@en .
#
# rsc:tom_hooper a dbo:Person ;
#     foaf:name "Tom Hooper"@en .
#
# rsc:tom_mccarthy a dbo:Person ;
#     foaf:name "Tom McCarthy"@en .
#
# rsc:tomm_moore a dbo:Person ;
#     foaf:name "Tomm Moore"@en .
#
# rsc:tony_kaye a dbo:Person ;
#     foaf:name "Tony Kaye"@en .
#
# rsc:wes_anderson a dbo:Person ;
#     foaf:name "Wes Anderson"@en .
#
# rsc:william_friedkin a dbo:Person ;
#     foaf:name "William Friedkin"@en .
#
# rsc:wim_wenders a dbo:Person ;
#     foaf:name "Wim Wenders"@en .
#
# rsc:woody_allen a dbo:Person ;
#     foaf:name "Woody Allen"@en .
#
# rsc:andrew_stanton a dbo:Person ;
#     foaf:name "Andrew Stanton"@en .
#
# rsc:damien_chazelle a dbo:Person ;
#     foaf:name "Damien Chazelle"@en .
#
# rsc:danny_boyle a dbo:Person ;
#     foaf:name "Danny Boyle"@en .
#
# rsc:david_lynch a dbo:Person ;
#     foaf:name "David Lynch"@en .
#
# rsc:elia_kazan a dbo:Person ;
#     foaf:name "Elia Kazan"@en .
#
# rsc:frank_darabont a dbo:Person ;
#     foaf:name "Frank Darabont"@en .
#
# rsc:franklin_j._schaffner a dbo:Person ;
#     foaf:name "Franklin J. Schaffner"@en .
#
# rsc:george_roy_hill a dbo:Person ;
#     foaf:name "George Roy Hill"@en .
#
# rsc:guy_ritchie a dbo:Person ;
#     foaf:name "Guy Ritchie"@en .
#
# rsc:james_gunn a dbo:Person ;
#     foaf:name "James Gunn"@en .
#
# rsc:john_ford a dbo:Person ;
#     foaf:name "John Ford"@en .
#
# rsc:john_huston a dbo:Person ;
#     foaf:name "John Huston"@en .
#
# rsc:joseph_l._mankiewicz a dbo:Person ;
#     foaf:name "Joseph L. Mankiewicz"@en .
#
# rsc:mel_gibson a dbo:Person ;
#     foaf:name "Mel Gibson"@en .
#
# rsc:mike_nichols a dbo:Person ;
#     foaf:name "Mike Nichols"@en .
#
# rsc:milos_forman a dbo:Person ;
#     foaf:name "Milos Forman"@en .
#
# rsc:oliver_stone a dbo:Person ;
#     foaf:name "Oliver Stone"@en .
#
# rsc:orson_welles a dbo:Person ;
#     foaf:name "Orson Welles"@en .
#
# rsc:otto_preminger a dbo:Person ;
#     foaf:name "Otto Preminger"@en .
#
# rsc:paul_thomas_anderson a dbo:Person ;
#     foaf:name "Paul Thomas Anderson"@en .
#
# rsc:peter_weir a dbo:Person ;
#     foaf:name "Peter Weir"@en .
#
# rsc:richard_linklater a dbo:Person ;
#     foaf:name "Richard Linklater"@en .
#
# rsc:rob_reiner a dbo:Person ;
#     foaf:name "Rob Reiner"@en .
#
# rsc:robert_zemeckis a dbo:Person ;
#     foaf:name "Robert Zemeckis"@en .
#
# rsc:roman_polanski a dbo:Person ;
#     foaf:name "Roman Polanski"@en .
#
# rsc:ron_howard a dbo:Person ;
#     foaf:name "Ron Howard"@en .
#
# rsc:sam_wood a dbo:Person ;
#     foaf:name "Sam Wood"@en .
#
# rsc:terry_gilliam a dbo:Person ;
#     foaf:name "Terry Gilliam"@en .
#
# rsc:terry_jones a dbo:Person ;
#     foaf:name "Terry Jones"@en .
#
# rsc:victor_fleming a dbo:Person ;
#     foaf:name "Victor Fleming"@en .
#
# rsc:clint_eastwood a dbo:Person ;
#     foaf:name "Clint Eastwood"@en .
#
# rsc:david_fincher a dbo:Person ;
#     foaf:name "David Fincher"@en .
#
# rsc:david_lean a dbo:Person ;
#     foaf:name "David Lean"@en .
#
# rsc:ethan_coen a dbo:Person ;
#     foaf:name "Ethan Coen"@en .
#
# rsc:francis_ford_coppola a dbo:Person ;
#     foaf:name "Francis Ford Coppola"@en .
#
# rsc:george_cukor a dbo:Person ;
#     foaf:name "George Cukor"@en .
#
# rsc:howard_hawks a dbo:Person ;
#     foaf:name "Howard Hawks"@en .
#
# rsc:james_cameron a dbo:Person ;
#     foaf:name "James Cameron"@en .
#
# rsc:joel_coen a dbo:Person ;
#     foaf:name "Joel Coen"@en .
#
# rsc:lee_unkrich a dbo:Person ;
#     foaf:name "Lee Unkrich"@en .
#
# rsc:pete_docter a dbo:Person ;
#     foaf:name "Pete Docter"@en .
#
# rsc:peter_jackson a dbo:Person ;
#     foaf:name "Peter Jackson"@en .
#
# rsc:sidney_lumet a dbo:Person ;
#     foaf:name "Sidney Lumet"@en .
#
# rsc:william_wyler a dbo:Person ;
#     foaf:name "William Wyler"@en .
#
# rsc:frank_capra a dbo:Person ;
#     foaf:name "Frank Capra"@en .
#
# rsc:ridley_scott a dbo:Person ;
#     foaf:name "Ridley Scott"@en .
#
# rsc:charles_chaplin a dbo:Person ;
#     foaf:name "Charles Chaplin"@en .
#
# rsc:quentin_tarantino a dbo:Person ;
#     foaf:name "Quentin Tarantino"@en .
#
# rsc:billy_wilder a dbo:Person ;
#     foaf:name "Billy Wilder"@en .
#
# rsc:christopher_nolan a dbo:Person ;
#     foaf:name "Christopher Nolan"@en .
#
# rsc:martin_scorsese a dbo:Person ;
#     foaf:name "Martin Scorsese"@en .
#
# rsc:steven_spielberg a dbo:Person ;
#     foaf:name "Steven Spielberg"@en .
#
# rsc:stanley_kubrick a dbo:Person ;
#     foaf:name "Stanley Kubrick"@en .
#
# rsc:alfred_hitchcock a dbo:Person ;
#     foaf:name "Alfred Hitchcock"@en .
